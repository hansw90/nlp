# %% [markdown]
# ## Attention 신경망 구현 및 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
path = '/content/drive/My Drive/Colab Notebooks'

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 159kB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 12.4MB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/d7/3c/1dbe5d6943b5c68e8df17c8b3a05db4725eadb5c7b7de437506aa3030701/JPype1-0.7.2-cp36-cp36m-manylinux1_x86_64.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 51.9MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.2)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Installing collected packages: beautifulsoup4, tweepy, JPype1, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-0.7.2 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.8.0

# %%
import random
import tensorflow as tf
import pandas as pd
import numpy as np
from konlpy.tag import Okt
from tqdm.notebook import tqdm

# %% [markdown]
# ## 하이퍼 파라미터

# %%
EPOCHS = 100
NUM_WORDS = 12958

# %% [markdown]
# ## Encoder

# %%
class Encoder(tf.keras.Model):
    def __init__(self):
        super(Encoder, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)

    def call(self, x, training=False, mask=None):
        x = self.emb(x)
        H, h, c = self.lstm(x)
        return H, h, c

# %% [markdown]
# ## Decoder

# %%
class Decoder(tf.keras.Model):
    def __init__(self):
        super(Decoder, self).__init__()
        self.emb = tf.keras.layers.Embedding(NUM_WORDS, 64)
        self.lstm = tf.keras.layers.LSTM(512, return_sequences=True, return_state=True)
        self.att = tf.keras.layers.Attention()
        self.dense = tf.keras.layers.Dense(NUM_WORDS, activation='softmax')

    def call(self, inputs, training=False, mask=None):
        x, s0, c0, H = inputs
        x = self.emb(x)
        S, h, c = self.lstm(x, initial_state=[s0, c0])
        
        S_ = tf.concat([s0[:, tf.newaxis, :], S[:, :-1, :]], axis=1)
        A = self.att([S_, H])
        y = tf.concat([S, A], axis=-1)
        
        return self.dense(y), h, c

# %% [markdown]
# ## Seq2seq

# %%
class Seq2seq(tf.keras.Model):
    def __init__(self, sos, eos):
        super(Seq2seq, self).__init__()
        self.enc = Encoder()
        self.dec = Decoder()
        self.sos = sos
        self.eos = eos

    def call(self, inputs, training=False, mask=None):
        if training is True:
            x, y = inputs
            H, h, c = self.enc(x)
            y, _, _ = self.dec((y, h, c, H))
            return y
        else:
            x = inputs
            H, h, c = self.enc(x)
            
            y = tf.convert_to_tensor(self.sos)
            y = tf.reshape(y, (1, 1))

            seq = tf.TensorArray(tf.int32, 64)

            for idx in tf.range(64):
                y, h, c = self.dec([y, h, c, H])
                y = tf.cast(tf.argmax(y, axis=-1), dtype=tf.int32)
                y = tf.reshape(y, (1, 1))
                seq = seq.write(idx, y)

                if y == self.eos:
                    break

            return tf.reshape(seq.stack(), (1, 64))

# %% [markdown]
# ## 학습, 테스트 루프 정의

# %%
# Implement training loop
@tf.function
def train_step(model, inputs, labels, loss_object, optimizer, train_loss, train_accuracy):
    output_labels = labels[:, 1:]
    shifted_labels = labels[:, :-1]
    with tf.GradientTape() as tape:
        predictions = model([inputs, shifted_labels], training=True)
        loss = loss_object(output_labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)
    train_accuracy(output_labels, predictions)

# Implement algorithm test
@tf.function
def test_step(model, inputs):
    return model(inputs, training=False)

# %% [markdown]
# ## 데이터셋 준비

# %%
pwd
# Out:
# '/content'

# %%
dataset_file = path + '/ChatbotData.csv'
data = pd.read_csv(dataset_file, encoding='utf-8')

# %%
data = data.reindex(np.random.permutation(len(data)))
data
# Out:
#                           Q                        A  label
# 579                나가기도 귀찮아            집에서도 할 게 많아요.      0
# 1084                 눈이 피곤해              눈 체조를 해보세요.      0
# 761          남친 프사에 내 사진 없어      신경쓰고 싶지 않은 사람도 있어요.      0
# 2653            스노클링 재미있을까?           즐거운 도전이 될 거예요.      0
# 6039             다시 만나서 이야기        충분한 대화 나누었길 바랍니다.      1
# ...                     ...                      ...    ...
# 3594                웹툰 뭐 볼까  안 본 웹툰이 있는지 먼저 물어보고싶네요.      0
# 1341             동호회 약속 있어.             재미있게 놀다 오세요.      0
# 9598             답프로포즈 해볼까?              정말 좋아할 거예요.      2
# 9575  누군가를 좋아한다는건 정말 힘들일이야.   좋아하는 감정은 정말 복잡하고 힘들어요.      2
# 7620       이별후 3주 아니 차인후 3주     이별을 받아들일 시간이 필요했을텐데.      1
#
# [11823 rows x 3 columns]

# %%
questions = [lines + ' \n' for lines in list(data['Q'])][:5000]
answers = ['\t ' + lines + ' \n' for lines in list(data['A'])][:5000]

print(questions)
print(answers)
num_sample = len(questions)

perm = list(range(num_sample))
random.seed(0)
random.shuffle(perm)

train_q = list()
train_a = list()
test_q = list()
test_a = list()

for idx, qna in enumerate(zip(questions, answers)):
    q, a = qna
    if perm[idx] > num_sample//5:
        train_q.append(q)
        train_a.append(a)
    else:
        test_q.append(q)
        test_a.append(a)



tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=NUM_WORDS,
                                                  filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~')

tokenizer.fit_on_texts(train_q + train_a + test_q + test_a)

train_q_seq = tokenizer.texts_to_sequences(train_q)
train_a_seq = tokenizer.texts_to_sequences(train_a)

test_q_seq = tokenizer.texts_to_sequences(test_q)
test_a_seq = tokenizer.texts_to_sequences(test_a)

x_train = tf.keras.preprocessing.sequence.pad_sequences(train_q_seq,
                                                        value=0,
                                                        padding='pre',
                                                        maxlen=64)
y_train = tf.keras.preprocessing.sequence.pad_sequences(train_a_seq,
                                                        value=0,
                                                        padding='post',
                                                        maxlen=65)


x_test = tf.keras.preprocessing.sequence.pad_sequences(test_q_seq,
                                                       value=0,
                                                       padding='pre',
                                                       maxlen=64)
y_test = tf.keras.preprocessing.sequence.pad_sequences(test_a_seq,
                                                       value=0,
                                                       padding='post',
                                                       maxlen=65)

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(10000).batch(32).prefetch(1024)
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(1).prefetch(1024)
# Out:
# ['나가기도 귀찮아 \n', '눈이 피곤해 \n', '남친 프사에 내 사진 없어 \n', '스노클링 재미있을까? \n', '다시 만나서 이야기 \n', '이러다 병걸리겠어ㅠㅠ \n', '보름밖에 안되었는데. \n', '그냥.너와 말한마디 섞고 너와의 인연에 고맙다 \n', '이별 이야기는 신중해야 하는걸 아니까 오늘도 고민합니다 \n', '사랑한다고 말을 안해줘 \n', '사랑하고 싶은데 내가 자꾸 구속해 \n', '차라리 널 만나지 않았더라면 \n', '어떡하지 \n', '가족이랑 여행 가려고 \n', '짱나는새끼 \n', '적금 들어야 하나 \n', '스테끼 먹은거 몇 년 만이냐 \n', '마음을 정리하고 있는데 뜻밖의 남자가 카톡을 했네 \n', '크루즈 타고 여행 하고 싶어 \n', '순수하게좋아했지만 걔는 너무도 약은애였어 \n', '쿠폰 다 모았다. \n', '왜 갈수록 더 생각나지 \n', '메이크업 동영상 보는 중 \n', '여자친구와 헤어진지 8일 \n', '남자친구에게 고민이나 속사정을 어디까지 얘기해? \n', '너무 힘든데 \n', '썸남이 술 취한 상태로 고백함. 기억할까? \n', '농구하다 무르팍 깨짐 \n', '드디어 어제 끝냈습니다 \n', '추우니까 나가기 싫어 \n', '이제야 오래전 상대방이 아팠던걸 이해했어. \n', '일상의 추억 \n', '연애상담하더니 둘이 사귀더라 \n', '좋아하는 사람이 너무 예뻐 \n', '여자친구가 교환학생 간대 \n', '6년째 연애중 \n', '불금입니다 \n', '거짓말은 진짜 못고치는 병 맞죠? \n', '지옥같은 5월이 다가 오네ㅜㅜ \n', '썸 타는 중인데 안 설레. \n', '먹고 자도 놀기만 해도 될까 \n', '미련이 없다고 생각했는데. \n', '부케 뭐로 하지 \n', '요즘 좋아하는 남자애가 꿈에 나오는데. \n', '만난지 얼마 안됐는데 결혼해도 될까? \n', '택배 왔나 \n', '괜히 창피해 \n', '엄마 힘들게 했어 \n', '어딘가 떠나고 싶다. \n', '말 거는게 어려워 \n', '이제 잊혀지는데 속도가 붙는거 같아. \n', '힘들고, 힘들고, 또 힘들고, \n', '진짜 시간이 약인지 \n', '화를 못 참겠어 \n', '남자친구가 잘생겨서 인기가 거의 아이돌급이야 \n', '그냥 흔한 이별 그리고 넋두리 \n', '비 와 \n', '기억하고 싶지 않은 기억! \n', '그림 잘 그리고 싶다 \n', '5년간 사귀고 이별 \n', '뭘하면 행복할까? \n', '기분이 너덜너덜 \n', '기 빨렸어 \n', '내일은 기다리던 소풍 간다 \n', '너무 힘들어 \n', '막장으로 가네 \n', '참견 좀 안했으면 \n', '시간표 잘못짰다 \n', '다른 사람들은 행복할까 \n', '의자 너무 불편해 \n', '썸남 꿈 꿨어. \n', '보내지 못하는 전할 수 없는 메시지 \n', '이렇게 얘기라도 하면 나아질까?. \n', '집들이 귀찮아 \n', '연말이라 그런지 \n', '크리스마스 다음날 이별했습니다. \n', '울적한 기분이 안 없어져. \n', '부모님 선물은 뭐할까? \n', '고백하고 후회하면 어떡하지 \n', '핸드폰 바꿀 때가 된듯 \n', '공황장애 생겼어. \n', '결혼할 확신이 안선다고 헤어지자네 \n', '지금이 겨울이라 참 다행이이네 \n', '환승 가능? \n', '헤어진지 3달만에 새로운 남자가 생긴 그녀. \n', '마음만은 항상 청춘인데 \n', '결혼하면좋을까 \n', '오늘 보름달이다. \n', '왜 이별은 익숙해지지가 않을까 \n', '지금 사귀고 있는 사람이랑 결혼하고 싶어 \n', '자극이 필요해 \n', '어젯밤에 판도라의 상자를 열어버렸네 \n', '왜 이제서야 연락했을까? \n', '헤어지고 연락했습니다. \n', '상처가 역시 크네 \n', '일을하다가도 잠을 자다가도 \n', '인생 공부한건가 \n', '썸인지 착각인지 \n', '어제 새벽에 이별했어. \n', '전여친에게 다시 연락이 오면 \n', '남편이 축가 불러준대 \n', '세상이 감미로워보여 \n', '웃게 만드는 너란 녀석 \n', '바쁘게 사는게 나쁘지는 않네 \n', '하루종일 회사에서 미친사람처럼 눈물의 의미를 생각하면서 \n', '답답함 \n', '핸드폰이 느려터졌어 \n', '슬픈 이별. \n', '사다리타기 맨날 운이 안 좋아 \n', '바쁜 나의 일상으로 \n', '내일 일찍 일어나야 돼 \n', '보이스피싱 당했어 \n', '결국 헤어지자고 했어. \n', '남친한테 교회 가자고 하고 싶어 \n', '멋지게 나이들고 싶다 \n', '사귄지 얼마 안됐는데 스킨십하려고해 \n', '카페 알바생이 좋아졌는데 들이대도 괜찮을까? \n', '술한잔 먹고 적어 \n', '술 먹고 지갑 잃어버렸어 \n', '게임 재미있어. \n', '회사 체육대회 가기 싫다 \n', '소개팅 앱에서 만난 사람 좋아하게 되었는데 괜찮은 사람일까요. \n', '전화해도 되겠지 \n', '첫직장 출근 \n', '와 체육대회다 \n', '괜한 희망은 더 큰 절망을 \n', '파혼 7개월 째 \n', '재택근무 힘들다 \n', '리모델링할까 \n', '여행 와서 짝남 선물 살까 하는데 \n', '헤어지고 세달뒤 딴사람과 결혼. \n', '썸인지 알려면 \n', '짝녀 알바 그만둬서 못나는데 연락처 물어보면 싫어할까. \n', '위로가 되는 좋은글이 있어 올려 \n', '재회 가능성이 있을까 \n', '오늘 마지막 연락했습니다 \n', '사과를 안해 \n', '머리카락이 엄청 빠져 \n', '잘못이라면 더 많이 좋아했던 죄. \n', '이별. 지쳐버렸나 \n', '넘어져서 발목 삔 거 같애 \n', '내가 좋아하는걸 그사람이 알았으면 좋겠어. \n', '제자리걸음만 하는 듯 \n', '짝녀가 이사간다는데 너무 힘들어. \n', '짧지 않은 세월이 정말 끝이 났네 \n', '미세먼지 최악인데 \n', '쓸데 없는 걱정 1위 연예인 걱정 \n', '살 좀 빼고 싶다 \n', '게임 때문에 폰이 점점 느려지는듯 \n', '나 맨날 속는 거 같아 \n', '힘들어 \n', '스트레스 받아 \n', '힘이 될런지 모르겠지만 \n', '친구가 자꾸 집착하는 것 같은데 뭐라 말하지 \n', '혼자 살아도 될까 \n', '썸일 때도 스킨십 하고 싶어? \n', '헤어진지 두달이 되었습니다. \n', '썸 타는 노래 듣는 중인데 좋아. \n', '내가 좋아하는 거 모르나 \n', '아무리 열심히 해도 선천적인 건 못 따라가겠지? \n', "윤종신 '좋니' 노래 가사가 엄청 와닿네 \n", '애니 좋아하는 사람 별로야? \n', '이별 2달째에 새로운 소개팅했습니다. \n', '요리 재밌어 \n', '좋아하던 사람에 대한 감정으로 내가 너무 힘들어. \n', '사랑하는사람 \n', '남자친구 자취 선물로 뭐가 좋을까? \n', '반장은 원래 힘들어? \n', '있잖아 \n', '먼저 잘게 잘자 \n', '새로운 베프가 필요해 \n', '시계가 멈춘거 같아. \n', '슬픔활용법. \n', '여친이 아는 형이랑 썸 타는데 \n', '헤어진지 한달이 되어가네. \n', '고민이 많은데 표현을 못하겠어 \n', '남동생한테 자꾸 화내게 되네 \n', '내일 뭐 입고 나갈까 \n', '나만 이상해졌어 \n', '방학인데 집에만 있어. \n', '마음이 식은 거 같아 \n', '대출껴서 집사는게 맞나? \n', '너무 많은 걸 바래 \n', '남자친구가 연락 안 하고 외박했어 \n', '알바하는데 같이 일하는 사람 좋아져 \n', '선생님 좋아해 \n', '화장실을 어떻게 참아? \n', '이어주려고 해서 더 어색해졌어 \n', '꽃다발 준비했어 \n', '이해심이 부족한 나. \n', '헤어진지 9일 \n', '애완동물 키우고 싶어 \n', '이제 좀 지겨워진 거 같아 \n', '참견쟁이 \n', '보고싶습니다 \n', '친구가 이사하는 거 도와준대 \n', '밥이 없어 \n', '미치겠네 \n', '오늘도 힘들다 \n', '말을 예쁘게 하면 좋으련만 \n', '미안해 \n', '마음이 울적해 \n', '재미있는 드라마 끝났어 \n', '이길이 내길인 ...
# ['\t 집에서도 할 게 많아요. \n', '\t 눈 체조를 해보세요. \n', '\t 신경쓰고 싶지 않은 사람도 있어요. \n', '\t 즐거운 도전이 될 거예요. \n', '\t 충분한 대화 나누었길 바랍니다. \n', '\t 아프면 안 돼요. 그럼 제 마음이 아파요. \n', '\t 많이 힘든가봐요. \n', '\t 아름다운 사이네요. \n', '\t 저는 비밀을 보장해요. 답답하다면 저에게 말해보세요. \n', '\t 사랑한다고 말해 달라고 하세요. \n', '\t 사랑을 독차지하려 하지 말고 내려놓으면서 여유를 가지세요. \n', '\t 그때는 누구보다 사랑했으니 후회하지 말아요. \n', '\t 어떡하면 좋을까요. \n', '\t 좋은 생각이에요. \n', '\t 제가 혼내줄게요. \n', '\t 적금 들 수 있으면 드는 게 좋죠. \n', '\t 맛있게 드세요. \n', '\t 정리하는데 도움이 될 수도 있겠네요. \n', '\t 멋진 생각이네요. \n', '\t 똥차 가고 벤츠 올 거예요. \n', '\t 와우 축하해요. \n', '\t 너무 많은 생각을 하지 마세요. \n', '\t 시간 가는 줄 모르겠어요. \n', '\t 금방 지나갈 거예요. \n', '\t 믿음의 정도에 따라 다른 거 같아요. \n', '\t 조금만 더 버텨보세요. \n', '\t 기억하냐고 물어보세요. \n', '\t 약 바르고 얼른 나으세요. \n', '\t 아직 얼떨떨하겠어요. \n', '\t 겨울에는 귤 먹으면서 집에 있는게 최고죠 \n', '\t 다음 번의 사랑에선 좀 더 신중할 수 있게 된 거예요. \n', '\t 기억의 편린이 될 뿐이에요. \n', '\t 대화를 하다가 친해졌나봐요. \n', '\t 내면을 더 들여다보세요. \n', '\t 기다릴 수 있을지 스스로에게 물어보세요. \n', '\t 부럽네요. \n', '\t 자신만의 시간을 가져봐요. \n', '\t 아무래도 그렇죠. \n', '\t 천국과 지옥이네요. \n', '\t 좋아하는 감정에는 다양한 방식이 있어요. 차분히 생각해 보는건 어떨까요? \n', '\t 소가 되는 방법이죠. \n', '\t 이별이 사람을 혼란스럽게 하나봐요. \n', '\t 당신이 좋아하는 꽃으로 만들어보세요. \n', '\t 생각을 많이 해서 그런가봐요. \n', '\t 오래 만나고 알면 좋겠지만 살면서 알아봐도 괜찮아요. \n', '\t 현관문 살펴보세요. \n', '\t 그럴 필요 없어요. \n', '\t 조금씩 보다 나은 모습을 보여드리세요. \n', '\t 저도요! \n', '\t 처음만 어렵지 그 다음부터는 덜할 거예요. \n', '\t 이별도 익숨함에 젖어드나봐요. \n', '\t 억지로라도 힘내보세요. \n', '\t 흘러가는 시간 속에 덤덤해질 거예요. \n', '\t 성격이 아니라 습관이에요. \n', '\t 멋진 사람이랑 사귀어서 좋겠네요. \n', '\t 저를 찾아줘서 고마워요. \n', '\t 우산 챙기세요. \n', '\t 천천히 지워질 거예요. \n', '\t 학원을 다니거나 연습하면 잘할 수 있을 거예요. \n', '\t 생각을 비워보세요. \n', '\t 인생을 즐기는 거죠. \n', '\t 제가 힘이 되어 드릴게요. \n', '\t 너무 긴장했나봐요. \n', '\t 두근거리겠네요. \n', '\t 지금 무슨 말을 해도 와닿지 않겠지만 잘할 수 있을 거예요. \n', '\t 잠시 쉬어가는 거 뿐이에요. \n', '\t 서툰 애정표현일 수도 있어요. \n', '\t 정정기간을 노려 보세요. \n', '\t 자신만 행복하면 돼요. \n', '\t 의자를 바꿔보세요. \n', '\t 그분 생각을 많이 했나 봐요. 곧 좋은 소식이 들리려고 하는 것 아닐까요? \n', '\t 때로는 보내지 못한 메시지가 아련하기도 하죠. \n', '\t 분명 나아질 거예요. \n', '\t 안해도 괜찮을 거예요 \n', '\t 외롭겠지만 즐겁게 보내보아요. \n', '\t 무슨 날인지는 중요하지 않아요. 힘들었을텐데 잠깐 쉬어가세요. \n', '\t 거리를 걸어보세요. \n', '\t 사랑과 현금이면 충분해요. \n', '\t 후회는 후회를 낳을뿐이에요. 용기 내세요. \n', '\t 오래 쓰셨나봐요. \n', '\t 꾸준히 약 먹고 치료해보세요. \n', '\t 결혼에는 확신이 필요하죠. \n', '\t 제가 곁에 있을게요. \n', '\t 환승은 30분 안에 \n', '\t 이젠 그녀를 놓아주세요. \n', '\t 마음이라도 청춘이어야죠. \n', '\t 누구랑 하느냐에 따라 다르겠지요. \n', '\t 소원을 비세요. \n', '\t 이별에 익숙해지는 순간 추억도 색을 잃을 거예요. \n', '\t 같이 살자고 프로포즈 해보세요. \n', '\t 의욕이 없나봐요. \n', '\t 건들지 않는 편이 좋았을 거예요. \n', '\t 이렇게 고민하게 만들려고 그랬나봐요. \n', '\t 많이 그리웠나 봐요. \n', '\t 금방 낫고 새 살이 돋을 거예요. \n', '\t 당분간은 생각날 수 밖에 없어요. \n', '\t 단맛도 있을 거예요. \n', '\t 얼마나 연락이 오는지 확인해보세요. \n', '\t 한동안 힘들겠어요. \n', '\t 달라지는 게 없다면 만나지 않는 게 더 나을 수도 있어요. \n', '\t 로맨틱한 남편이네요. \n', '\t 사랑에 빠졌나봐요. \n', '\t 상대방도 미소짓게 해주세요. \n', '\t 잡념을 없애는 데는 최고라고 생각해요. \n', '\t 이별이 그렇게 만들었나요. \n', '\t 마음이 내 마음 대로 안 돼요. \n', '\t 포맷해보세요. \n', '\t 슬픈 예감은 틀린 적이 없죠. \n', '\t 다른 곳에 쓰려고 운을 아껴뒀나봐요. \n', '\t 일상으로 돌아갑시다. \n', '\t 오늘 일찍 주무세요. \n', '\t 신고하세요. \n', '\t 말하기 힘들었겠어요. \n', '\t 마음을 열 때까지 설득해보세요. \n', '\t 지금도 그러고 있어요. \n', '\t 자신의 속도에 맞추세요. \n', '\t 언제 끝나냐고 물어보세요. \n', '\t 감성적이기 딱 좋죠. \n', '\t 잘 기억해 보세요. 어디 있을 지도 몰라요. \n', '\t 게임하세요! \n', '\t 가기 싫어도 가야겠죠. \n', '\t 좀 더 알아볼 시간이 필요하겠네요. \n', '\t 전화 해보세요. \n', '\t 처음에는 많이 어렵겠지만 차차 적응해 나갈거예요. \n', '\t 일기예보 확인해보세요. \n', '\t 헛된 희망은 자신을 더 괴롭게 만들거예요. \n', '\t 아직 힘들거라 생각해요. \n', '\t 어쨌든 일이니까요. \n', '\t 필요하다면 해야겠죠. \n', '\t 받으면 감동 받을 것 같아요. \n', '\t 인연이 거기까지였나봐요. \n', '\t 어느 정도 시간과 연락과 관심이 필요하겠네요. \n', '\t 그래도 마지막이니 물어보는게 좋겠어요. \n', '\t 고마워요. 저한테도 위로가 될 거예요. \n', '\t 어떻게 하느냐에 따라 달라질 거예요. \n', '\t 마음을 단단히 하길 바랄게요. \n', '\t 나쁜 사람이네요. \n', '\t 스트레스 받지 마세요. \n', '\t 더 많이 좋아하면 미련도 적을 거예요. \n', '\t 새로운 시작을 해보세요. \n', '\t 꾸준히 치료하세요. \n', '\t 마음을 조금씩 전해보세요. \n', '\t 발전이 없다고 너무 두려워하지 마세요. \n', '\t 인연이라면 또 다시 만날 수 있을 거예요. \n', '\t 또 다른 시작을 뜻하기도 해요. \n', '\t 집에 있거나 나가면 마스크 쓰고 나가세요. \n', '\t 동감입니다. \n', '\t 적게 먹고 많이 움직이세요. \n', '\t 정리해보세요. \n', '\t 즐겁게 속아주세요. \n', '\t 지금은 힘들겠지만 조금만 더 견뎌봐요. \n', '\t 운동을 해보세요. \n', '\t 어떤 말도 위로가 되지 않겠지만 힘내세요. \n', '\t 거리를 두세요. \n', '\t 잘 살 수 있어요. \n', '\t 자연스러운 현상이에요. \n', '\t 시간이 많이 흘렀네요. \n', '\t 썸 탈 ...

# %%
print(test_q)
print(test_a)
# Out:
# ['남친 프사에 내 사진 없어 \n', '어떡하지 \n', '적금 들어야 하나 \n', '크루즈 타고 여행 하고 싶어 \n', '왜 갈수록 더 생각나지 \n', '추우니까 나가기 싫어 \n', '연애상담하더니 둘이 사귀더라 \n', '6년째 연애중 \n', '거짓말은 진짜 못고치는 병 맞죠? \n', '요즘 좋아하는 남자애가 꿈에 나오는데. \n', '어딘가 떠나고 싶다. \n', '말 거는게 어려워 \n', '비 와 \n', '기억하고 싶지 않은 기억! \n', '내일은 기다리던 소풍 간다 \n', '막장으로 가네 \n', '집들이 귀찮아 \n', '공황장애 생겼어. \n', '어젯밤에 판도라의 상자를 열어버렸네 \n', '바쁘게 사는게 나쁘지는 않네 \n', '핸드폰이 느려터졌어 \n', '남친한테 교회 가자고 하고 싶어 \n', '멋지게 나이들고 싶다 \n', '술한잔 먹고 적어 \n', '술 먹고 지갑 잃어버렸어 \n', '소개팅 앱에서 만난 사람 좋아하게 되었는데 괜찮은 사람일까요. \n', '파혼 7개월 째 \n', '사과를 안해 \n', '이별. 지쳐버렸나 \n', '스트레스 받아 \n', '혼자 살아도 될까 \n', '썸일 때도 스킨십 하고 싶어? \n', '애니 좋아하는 사람 별로야? \n', '먼저 잘게 잘자 \n', '새로운 베프가 필요해 \n', '마음이 식은 거 같아 \n', '선생님 좋아해 \n', '헤어진지 9일 \n', '이제 좀 지겨워진 거 같아 \n', '오늘도 힘들다 \n', '마음이 울적해 \n', '재미있는 드라마 끝났어 \n', '안경 쓰는 남자애 좋아하는 남자 있어? \n', '역시 나는 천재야 \n', '한 눈에 반했어. 그녀한테 좋아한다고 해도 될까. \n', '가슴 아픈 이별 \n', '아침 챙겨 먹어야지 \n', '헬스장 사람들 몸이 좋아 \n', '남자친구 스타일이 마음에 안들어. \n', '담뱃값이 왜 이렇게 비싸 \n', '장난 잼있어 \n', '좋은 아침 \n', '떠나려는 사람 잡는 방법 \n', '먹고 나니까 졸리당 \n', '어떤 사람 만나야해? \n', '후기 입니다 \n', '친구한테 진짜 고마워 \n', '피부가 점점 늙어가는게 느껴져 \n', '설레였던게 언젠인지 \n', '머리 아파 \n', '남자친구가 애교가 많아 \n', '어떻게 살아가야 할까 \n', '이별을 배워가는 \n', '사람 많아서 기다려야할지도 \n', '항상 똑같애 \n', '이별하고 욕했어 \n', '오늘도 꾸준히 회사 가시 싫다. \n', '어떤 사람 꿈 꾸고 나서 호감 생겼어. \n', '사랑받는 방법 \n', '남자친구의 감정기복이 너무 심해. \n', '좋아하는 사람 꿈을 꿨어. \n', '이젠 잡아도 안되는거래 \n', '이별했네 \n', '친구 웨딩촬영 갔는데 서운했어 \n', '모르겠는데 노력하래 \n', '매주 수요일 그를 만날 수 있어. \n', '벚꽃이 너무 예뻐 \n', '나 자꾸 놀리는 애가 있는데 나 좋아하는건가. \n', '내가 좋아하는 애를 내 친구가 계속 욕하는게 맘에 안들어. \n', '싸우면 안되는데 \n', '매주 화요일 그를 볼 수 있어. \n', '상사가 진짜 미쳤다 \n', '썸남이 춥다고 옷 잠궈주는데 설레. \n', '현실의 벽 \n', '놀아 줄 사람이 없어 \n', '절망적인데 \n', '결국 헤어졌네. \n', '분위기 있는 데서 데이트하고 싶어 \n', '그동안의 만남과 시간이 멈춰버렸습니다. \n', '배고프당 \n', '혼자라서 너무 좋아 \n', '사랑의 끝이 뭐야? \n', '7년만에 두번째 이별통보 \n', '바보같은 짓을 했어. \n', '임용 결과 발표 기다리고 있어 \n', '여자예요? 남자예요? \n', '스키 강습 받아야 될까? \n', '너무 행복해. 오래갈 수 있을까? \n', '좋아하는 사람한테 거절 당할까봐 두려워. \n', '오늘 편지 놓아 두려고 합니다. \n', '매번 글쓸때마다 상황설명하라고 해 \n', '낭만이라고는 없어가지구 \n', '가슴에 구멍이 너무 커. \n', '썸 어떻게 타? \n', '전화하기엔 늦은 시간인데 전화하고 싶어 \n', '항상 흐지부지야 \n', '개당황 \n', '부자 백수 하고 싶어 \n', '변하지 않는 사람도 있겠지? \n', '직장에서 따돌림 당함 \n', '다 괜찮은 줄 알았는데 \n', '좋아하는 사람이 너무 철벽치는데 계속 다가가도 될까? \n', '이제 와서 소문이라니 \n', '썸남한테 소개팅 나간다고 해볼까? \n', '남자친구와 여행 어디로 가? \n', '1년동거 끝에 헤어짐 \n', '친구가 잘되니까 배 아픈 거 같아 \n', '밥 먹다 흘렸어 \n', '뒤숭숭하네. \n', '그냥 자는 거 아니지? \n', '짝남한테 고백했는데 내가 싫지는 않은데 못 사귀겠대. \n', '한 번 보고 어떻게 판단하지 \n', '혼자 있으니까 편하네 \n', '차 살거야 \n', '처음 보는 사람이랑 뭔 말을 하지 \n', '이별100일째. \n', '그 모습 자꾸 생각나 \n', '그 사람이 나를 좋아하는 줄 알았는데. \n', '가장 확실한 건 뭘까? \n', '하라고 할때는 공부하기 싫었는데. \n', '가벼워졌다고 생각했는데 \n', '수학여행때 뭐 입지? \n', '최근에 헤어진 짝남한테 지금 연락하기는 너무 이를까? \n', '짝남과 자연스럽게 친해질 수 있는 방법 있을까? \n', '좋아해 \n', '회사 사람들이 아직도 불편해 \n', '두렵습니다. \n', '내가 나쁜 놈이지 \n', '회식 좀 그만 했으면ㅜㅜ \n', '적응을 못하겠어 \n', '어떻게 해야 할까? \n', '힘드네 장거리 \n', '미친 사람들이 너무 많아 \n', '시계 소리 짱 커 \n', '좋아하는 여자한테 남친이 있는데 연락하고 싶어. \n', '여자친구가 클럽을 간다면 어떻게해? \n', '오싹한 이야기 해줄까 \n', '인형뽑기는 유행 지났지? \n', '짝사랑 그만하고 싶다 \n', '뭐 해주기가 싫어 \n', '운이좋은건지 나쁜건지 \n', '논문 쓰기 힘들다 \n', '빨리 일상속으로 돌아가고픈데. \n', '돈 없어도 갈 수 있는 데이트 코스 \n', '인관관계 맺는 게 피곤해 \n', '또 지각하네 \n', '남자친구가 집안일을 너무 안해. 나만 하는게 고민이야. \n', '잘 지내고 있네여.아무일 없다는듯이. \n', '왜 나한테 피해를 주냐고 \n', '혈액형이 성격이랑 무슨 상관이지 \n', '그는 내가 좋아하는 마음을 이용하는 걸까? \n', '인턴 할까 \n', '나 바본인가 봄 \n', '짝남한테 괜히 만나자고 했나봐. \n', '오늘은 교회 안가면 안될까 \n', '자기 잘못 인정 안하는 사람 \n', '봄이 왔으면 좋겠어 \n', '만족할 줄을 몰라 \n', '머리 짧게 잘라야지 \n', '착한 사람이 잘 됐으면 좋겠어 좀 \n', '보고싶다고 만나달라고 연락하면 \n', '너무 가슴이 아파 \n', '책 좀 읽어야지 \n', '연락을 해봤는데 안받네. \n', '어제 술마시고 나서 기억 안나 \n', '썸남 생일 때 편지 줘도 될까 \n', '재회후 또 이별 \n', '지갑 없어졌어 \n', '집 팔려고 \n', '주름살 생겼어 \n', '소개팅도 안 들어와 \n', '다육이 좀 심어볼까 \n', '연락 계속 오면 관심 있는 거야? \n', '전 애인 만났어. \n', '갑자기 일어난일이라 어이 없어 \n', '장거리 썸 고백해도될까 \n', '너무 잘하는 후배가 들어왔어 \n', '안경 벗으니까 완전 예뻤어 \n', '짝녀가 학교에서 소문이 안 좋아. \n', '자길 좋아하는 여자애가 있으면 더 잘해주는 경향이 있나? \n', '뭐야 너무 건방져 \n', '그녀의 행복을 진심으로 빌어주는 날이 올까 \n', '말을 수시로 바꾸는 사람 어떻게 해? \n', '혼밥하고 있어 \n', '이혼 \n', '머리 어떻게 할까? \n', '좋아하는 사람 앞에서 다른 사람한테 관심 있는 척 해봤어요? \n', '썸은 꼭 타야 해? \n', '임신이면 어떡하지 \n', '연락했는데 실수한거 같네 \n', '싫어졌다가 좋아지는 경우도 있나요? \n', '이제 그 ...
# ['\t 신경쓰고 싶지 않은 사람도 있어요. \n', '\t 어떡하면 좋을까요. \n', '\t 적금 들 수 있으면 드는 게 좋죠. \n', '\t 멋진 생각이네요. \n', '\t 너무 많은 생각을 하지 마세요. \n', '\t 겨울에는 귤 먹으면서 집에 있는게 최고죠 \n', '\t 대화를 하다가 친해졌나봐요. \n', '\t 부럽네요. \n', '\t 아무래도 그렇죠. \n', '\t 생각을 많이 해서 그런가봐요. \n', '\t 저도요! \n', '\t 처음만 어렵지 그 다음부터는 덜할 거예요. \n', '\t 우산 챙기세요. \n', '\t 천천히 지워질 거예요. \n', '\t 두근거리겠네요. \n', '\t 잠시 쉬어가는 거 뿐이에요. \n', '\t 안해도 괜찮을 거예요 \n', '\t 꾸준히 약 먹고 치료해보세요. \n', '\t 건들지 않는 편이 좋았을 거예요. \n', '\t 잡념을 없애는 데는 최고라고 생각해요. \n', '\t 포맷해보세요. \n', '\t 마음을 열 때까지 설득해보세요. \n', '\t 지금도 그러고 있어요. \n', '\t 감성적이기 딱 좋죠. \n', '\t 잘 기억해 보세요. 어디 있을 지도 몰라요. \n', '\t 좀 더 알아볼 시간이 필요하겠네요. \n', '\t 아직 힘들거라 생각해요. \n', '\t 나쁜 사람이네요. \n', '\t 새로운 시작을 해보세요. \n', '\t 운동을 해보세요. \n', '\t 잘 살 수 있어요. \n', '\t 자연스러운 현상이에요. \n', '\t 개인의 취향일 뿐이에요. \n', '\t 안녕히 주무세요. \n', '\t 주변의 좋은 사람들에게 연락해보세요. \n', '\t 나를 사랑하지 않는 사람하고 계속 가는 건 나 자신을 사랑하지 않는 사람들이나 하는 일이에요. \n', '\t 선생님도 좋아할 거예요. \n', '\t 헤어짐을 헤아리지 마세요. \n', '\t 사랑하는 이유를 생각해보세요. \n', '\t 지금은 힘들겠지만 조금만 더 견뎌봐요. \n', '\t 거리를 걸어보세요. \n', '\t 재미있는 다른걸 찾아보세요. \n', '\t 그런 건 중요하지 않아요. \n', '\t 제가 더 천재예요. \n', '\t 아직 이를 지도 몰라요. 천천히 다가가세요. \n', '\t 많이 아프지 말아요. \n', '\t 든든하게 드세요. \n', '\t 운동할 맛 나겠어요. \n', '\t 선물해주면서 조금씩 변화시켜봐요. \n', '\t 금연하세요. \n', '\t 재미있나봐요. \n', '\t 좋은 아침이에요. \n', '\t 정말 후회할 것 같다면 지금이라도 진심을 전하세요. \n', '\t 자연의 이치죠. 안녕히 주무세요. \n', '\t 내가 나답게 살 수 있도록 해줄 수 있는 사람인 것 같아요. \n', '\t 말씀해주세요. \n', '\t 좋은 친구를 뒀네요. \n', '\t 지금이라도 관리해봐요. \n', '\t 곧 설레는 순간이 올 거예요. \n', '\t 시원한 바람 쉬고 약먹기! \n', '\t 귀엽겠네요. \n', '\t 태연하게 시작해보세요. \n', '\t 성숙해지는 단계인가봐요. \n', '\t 커피 한잔 마시며 기다려보세요. \n', '\t 똑같은 건 없어요. \n', '\t 순간의 분노로 그랬을 수도 있어요. \n', '\t 월급날을 생각하며 참아보세요. \n', '\t 충분히 그럴 수 있어요. \n', '\t 사랑하면 돼요. \n', '\t 피해를 줄 때는 피하세요. \n', '\t 많이 생각했나봐요. \n', '\t 사랑은 때론 미련이 되기도 하죠. \n', '\t 힘든 결정이었겠어요. \n', '\t 친구가 예민해서 잘 못 챙겼나봐요. \n', '\t 모르는걸 알려면 노력해야죠. \n', '\t 삶의 활력소가 되겠네요. \n', '\t 너무 아름답죠. \n', '\t 당신에게만 그런다면 좋아할 확률이 있습니다. \n', '\t 특별한 이유가 없다면 서운함을 전해보세요. \n', '\t 서로에게 귀 기울이는 방법도 있어요. \n', '\t 이날만 기다리겠어요. \n', '\t 피하지 말고 적극적으로 장점을 찾아서 인정하고 호의를 보여보세요. \n', '\t 다정한 사람이네요. \n', '\t 현실적인 문제가 중요할 때가 있죠. \n', '\t 혼자도 함께도 잘 지내는 게 좋죠. \n', '\t 탈출구가 있을 거예요. \n', '\t 시작이 있으면 끝도 있는 법이에요. \n', '\t 매일 가고 싶네요. \n', '\t 기억과 함께 묻어두는 건 어떨까요. \n', '\t 얼른 맛난 음식 드세요. \n', '\t 혼자를 즐기세요. \n', '\t 사랑하지 않는 것이죠. \n', '\t 반복되면 습관이 됩니다. \n', '\t 너무 자책하지 마요. \n', '\t 여행 다녀와 보세요. \n', '\t 아직 모르겠어요. 인공지능에 성별을 만드는 사람이 되어 주세요 \n', '\t 주변에 잘 하는 사람한테 배워보세요. \n', '\t 노력하면 가능할 거예요. \n', '\t 충분히 그렇게 생각할 수 있어요. \n', '\t 진심이 전해지길 바랍니다. \n', '\t 대화를 많이 나누는게 좋으니까요. \n', '\t 낭만적인 거 좋아하시는구나! \n', '\t 아무 생각 하지 말고 푹 주무세요. \n', '\t 일단 연락처를 주고 받고 부담스럽지 않는 선에서 친해지는게 좋아요. \n', '\t 늦은 시간 전화는 실례예요. \n', '\t 이번에는 안 그러면 돼요. \n', '\t 다음부터는 더 많이 아세요. \n', '\t 그게 최고죠. \n', '\t 드물지만 있을거예요. \n', '\t 직장 스트레스 심하겠네요. \n', '\t 다 괜찮아질 거예요. \n', '\t 철벽치는 이유를 먼저 알아보세요. \n', '\t 참 거지같네요. \n', '\t 상대방을 헷갈리게 하는건 좋지 않아요. \n', '\t 안 가본 가까운 곳이 좋겠죠. \n', '\t 현실과 마주하셨나봐요. \n', '\t 친구가 아닌가봐요. \n', '\t 깨끗하게 치워주세요. \n', '\t 실감이 안나나봐요. \n', '\t 많이 피곤한가봐요. \n', '\t 복잡한 마음이네요. \n', '\t 첫인상은 상대방을 바라봤을때 3초에 결정난데요. \n', '\t 혼자를 즐기세요. \n', '\t 좋은차로 선택해보세요. \n', '\t 공통점을 찾는다고 생각해보세요. \n', '\t 새로운 무언가를 해보는건 어떠세요. \n', '\t 좋은 모습만 기억에 남겠죠. \n', '\t 아니어서 힘드나봐요. \n', '\t 가장 확실한 시간은 오늘이에요. 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요. \n', '\t 때를 놓쳐서 그런 것 같아요. \n', '\t 무거워도 괜찮아요. \n', '\t 뭘 입어도 예뻐요. \n', '\t 위로를 해주면서 연락해보세요. \n', '\t 공통 관심사를 찾아보세요. \n', '\t 고백하세요. \n', '\t 회사에는 동료가 있을 뿐이에요. \n', '\t 제가 함께 있어줄게요. \n', '\t 당신은 좋은 사람이에요. \n', '\t 가기 싫어도 가야겠죠. \n', '\t 처음부터 잘하는 사람은 없어요. \n', '\t 잠시 차분하게 생각해봐요. \n', '\t 물리적인 거리를 무시하지 못하니까요. \n', '\t 조심해야해요. \n', '\t 예민한가봐요. \n', '\t 연애 중인 사람에게는 연락하지 않는 게 좋을 것 같아요. \n', '\t 같이 가보세요. \n', '\t 해주세요. \n', '\t 하는 사람은 하더라고요 \n', '\t 짝사랑은 시작과 끝을 자신이 결정할 수 있어요. \n', '\t 상처받았나봐요. \n', '\t 인연이 거기까지 였나봐요. \n', '\t 어깨 꾹꾹! 힘내세요 \n', '\t 지금도 일상이에요. \n', '\t 등산 데이트를 해보세요. \n', '\t 그 사람을 위해 에너지를 쓰니까요. \n', '\t 더 일찍 일어나세요. \n', '\t 집안일을 하나씩 분담해보세요. \n', '\t 세상은 어떻게든 흘러가니까요. \n', '\t 남에게 피해주지 않는 건 기본이죠. \n', '\t 상관 없는 거 같아요. \n', '\t 그렇다면 정말 나쁜 사람이네요. \n', '\t 경 ...

# %% [markdown]
# ## 학습 환경 정의
# ### 모델 생성, 손실함수, 최적화 알고리즘, 평가지표 정의

# %%
# Create model
model = Seq2seq(sos=tokenizer.word_index['\t'],
                eos=tokenizer.word_index['\n'])

# Define loss and optimizer
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

# Define performance metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# %% [markdown]
# ## 학습 루프 동작

# %%
for epoch in tqdm(range(EPOCHS)):
    for seqs, labels in train_ds:
        train_step(model, seqs, labels, loss_object, optimizer, train_loss, train_accuracy)

    template = 'Epoch {}, Loss: {}, Accuracy: {}'
    print(template.format(epoch + 1,
                          train_loss.result(),
                          train_accuracy.result() * 100))

    train_loss.reset_states()
    train_accuracy.reset_states()
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Epoch 1, Loss: 0.9679239392280579, Accuracy: 92.15116882324219
# Epoch 2, Loss: 0.5164560079574585, Accuracy: 93.98716735839844
# Epoch 3, Loss: 0.47447463870048523, Accuracy: 94.2559814453125
# Epoch 4, Loss: 0.4455713629722595, Accuracy: 94.3380355834961
# Epoch 5, Loss: 0.4288519024848938, Accuracy: 94.40953826904297
# Epoch 6, Loss: 0.41652077436447144, Accuracy: 94.44197082519531
# Epoch 7, Loss: 0.4050038456916809, Accuracy: 94.47830963134766
# Epoch 8, Loss: 0.39389508962631226, Accuracy: 94.51737976074219
# Epoch 9, Loss: 0.3824133574962616, Accuracy: 94.55371856689453
# Epoch 10, Loss: 0.37083354592323303, Accuracy: 94.60450744628906
# Epoch 11, Loss: 0.3589758574962616, Accuracy: 94.66859436035156
# Epoch 12, Loss: 0.3465612232685089, Accuracy: 94.7154769897461
# Epoch 13, Loss: 0.3334851562976837, Accuracy: 94.80924987792969
# Epoch 14, Loss: 0.3195759952068329, Accuracy: 94.90849304199219
# Epoch 15, Loss: 0.3049016296863556, Accuracy: 95.0249252319336
# Epoch 16, Loss: 0.2895081639289856, Accuracy: 95.17535400390625
# Epoch 17, Loss: 0.27385541796684265, Accuracy: 95.33985137939453
# Epoch 18, Loss: 0.2568349838256836, Accuracy: 95.55084228515625
# Epoch 19, Loss: 0.23871587216854095, Accuracy: 95.78370666503906
# Epoch 20, Loss: 0.22107017040252686, Accuracy: 96.02361297607422
# Epoch 21, Loss: 0.2034653276205063, Accuracy: 96.29751586914062
# Epoch 22, Loss: 0.18661603331565857, Accuracy: 96.58000183105469
# Epoch 23, Loss: 0.1706896871328354, Accuracy: 96.85155487060547
# Epoch 24, Loss: 0.15610124170780182, Accuracy: 97.12662506103516
# Epoch 25, Loss: 0.14168953895568848, Accuracy: 97.3923110961914
# Epoch 26, Loss: 0.12850184738636017, Accuracy: 97.6322250366211
# Epoch 27, Loss: 0.11659698188304901, Accuracy: 97.82875061035156
# Epoch 28, Loss: 0.10520613938570023, Accuracy: 98.02176666259766
# Epoch 29, Loss: 0.0943894162774086, Accuracy: 98.20033264160156
# Epoch 30, Loss: 0.08484042435884476, Accuracy: 98.37303161621094
# Epoch 31, Loss: 0.07528776675462723, Accuracy: 98.54612731933594
# Epoch 32, Loss: 0.06761333346366882, Accuracy: 98.69264221191406
# Epoch 33, Loss: 0.05906151607632637, Accuracy: 98.87784576416016
# Epoch 34, Loss: 0.050638165324926376, Accuracy: 99.04155731201172
# Epoch 35, Loss: 0.04370671138167381, Accuracy: 99.22441864013672
# Epoch 36, Loss: 0.038150105625391006, Accuracy: 99.33538055419922
# Epoch 37, Loss: 0.03228301554918289, Accuracy: 99.47877502441406
# Epoch 38, Loss: 0.026870442554354668, Accuracy: 99.60107421875
# Epoch 39, Loss: 0.022420423105359077, Accuracy: 99.6921157836914
# Epoch 40, Loss: 0.018884779885411263, Accuracy: 99.76634979248047
# Epoch 41, Loss: 0.016026571393013, Accuracy: 99.82807922363281
# Epoch 42, Loss: 0.013576386496424675, Accuracy: 99.86676788330078
# Epoch 43, Loss: 0.011584777384996414, Accuracy: 99.89488983154297
# Epoch 44, Loss: 0.009226584807038307, Accuracy: 99.93162536621094
# Epoch 45, Loss: 0.00781011488288641, Accuracy: 99.94725036621094
# Epoch 46, Loss: 0.007029506843537092, Accuracy: 99.96405029296875
# Epoch 47, Loss: 0.00597543828189373, Accuracy: 99.97030639648438
# Epoch 48, Loss: 0.005026858299970627, Accuracy: 99.97772979736328
# Epoch 49, Loss: 0.005492383148521185, Accuracy: 99.97108459472656
# Epoch 50, Loss: 0.00492292083799839, Accuracy: 99.97655487060547
# Epoch 51, Loss: 0.005546197760850191, Accuracy: 99.96601104736328
# Epoch 52, Loss: 0.006974536459892988, Accuracy: 99.94725036621094
# Epoch 53, Loss: 0.006945894565433264, Accuracy: 99.93709564208984
# Epoch 54, Loss: 0.006874768529087305, Accuracy: 99.93709564208984
# Epoch 55, Loss: 0.006019094493240118, Accuracy: 99.94725036621094
# Epoch 56, Loss: 0.00447136489674449, Accuracy: 99.97382354736328
# Epoch 57, Loss: 0.0034210323356091976, Accuracy: 99.98163604736328
# Epoch 58, Loss: 0.002964785322546959, Accuracy: 99.98905944824219
# Epoch 59, Loss: 0.0025871838442981243, Accuracy: 99.9898452758789
# Epoch 60, Loss: 0.0026327725499868393, Accuracy: 99.99101257324219
# Epoch 61, Loss: 0.002286772709339857, Accuracy: 99.9925765991211
# Epoch 62, Loss: 0.0021425304003059864, Accuracy: 99.99374389648438
# Epoch 63, Loss: 0.0020797811448574066, Accuracy: 99.99336242675781
# Epoch 64, Loss: 0.001959792338311672, Accuracy: 99.99530792236328
# Epoch 65, Loss: 0.001997478539124131, Accuracy: 99.99336242675781
# Epoch 66, Loss: 0.0019177970243617892, Accuracy: 99.99491882324219
# Epoch 67, Loss: 0.0019162005046382546, Accuracy: 99.99336242675781
# Epoch 68, Loss: 0.0019030518596991897, Accuracy: 99.99374389648438
# Epoch 69, Loss: 0.001883203163743019, Accuracy: 99.99336242675781
# Epoch 70, Loss: 0.0018360399408265948, Accuracy: 99.99374389648438
# Epoch 71, Loss: 0.0018617109162732959, Accuracy: 99.99296569824219
# Epoch 72, Loss: 0.001768178422935307, Accuracy: 99.9957046508789
# Epoch 73, Loss: 0.001781204715371132, Accuracy: 99.99491882324219
# Epoch 74, Loss: 0.0018054908141493797, Accuracy: 99.99336242675781
# Epoch 75, Loss: 0.0017733313143253326, Accuracy: 99.994140625
# Epoch 76, Loss: 0.001778343808837235, Accuracy: 99.99374389648438
# Epoch 77, Loss: 0.0017493339255452156, Accuracy: 99.994140625
# Epoch 78, Loss: 0.001783966668881476, Accuracy: 99.99336242675781
# Epoch 79, Loss: 0.0017288423841819167, Accuracy: 99.99374389648438
# Epoch 80, Loss: 0.0017158959526568651, Accuracy: 99.994140625
# Epoch 81, Loss: 0.001720916829071939, Accuracy: 99.9945297241211
# Epoch 82, Loss: 0.001725084031932056, Accuracy: 99.99336242675781
# Epoch 83, Loss: 0.00751566281542182, Accuracy: 99.86480712890625
# Epoch 84, Loss: 0.027214093133807182, Accuracy: 99.32366180419922
# Epoch 85, Loss: 0.014236058108508587, Accuracy: 99.69523620605469
# Epoch 86, Loss: 0.005468319170176983, Accuracy: 99.92576599121094
# Epoch 87, Loss: 0.0026581226848065853, Accuracy: 99.9808578491211
# Epoch 88, Loss: 0.002076449804008007, Accuracy: 99.9906234741211
# Epoch 89, Loss: 0.0018961409805342555, Accuracy: 99.99296569824219
# Epoch 90, Loss: 0.0018391023622825742, Accuracy: 99.99374389648438
# Epoch 91, Loss: 0.0017949213506653905, Accuracy: 99.994140625
# Epoch 92, Loss: 0.0017850520089268684, Accuracy: 99.99336242675781
# Epoch 93, Loss: 0.0017681500175967813, Accuracy: 99.994140625
# Epoch 94, Loss: 0.0017674000700935721, Accuracy: 99.99374389648438
# Epoch 95, Loss: 0.0017482723342254758, Accuracy: 99.99336242675781
# Epoch 96, Loss: 0.001754831988364458, Accuracy: 99.99296569824219
# Epoch 97, Loss: 0.001744716428220272, Accuracy: 99.99296569824219
# Epoch 98, Loss: 0.0017067877342924476, Accuracy: 99.9945297241211
# Epoch 99, Loss: 0.001718604937195778, Accuracy: 99.994140625
# Epoch 100, Loss: 0.0017108265310525894, Accuracy: 99.99374389648438

# %% [markdown]
# ## 테스트 루프

# %%
for test_seq, test_labels in test_ds:
    prediction = test_step(model, test_seq)
    test_text = tokenizer.sequences_to_texts(test_seq.numpy())
    gt_text = tokenizer.sequences_to_texts(test_labels.numpy())
    texts = tokenizer.sequences_to_texts(prediction.numpy())
    print('_')
    print('질문: ', test_text)
    print('정답: ', gt_text)
    print('예상답: ', texts)
# Out:
# _
# 질문:  ['남친 프사에 내 사진 없어 \n']
# 정답:  ['\t 신경쓰고 싶지 않은 사람도 있어요 \n']
# 예상답:  ['갑자기 말하면 상대방이 당황하지 않을까요 \n']
# _
# 질문:  ['어떡하지 \n']
# 정답:  ['\t 어떡하면 좋을까요 \n']
# 예상답:  ['성공하길 바랄게요 \n']
# _
# 질문:  ['적금 들어야 하나 \n']
# 정답:  ['\t 적금 들 수 있으면 드는 게 좋죠 \n']
# 예상답:  ['귀찮아서 인정부터 시작이죠 \n']
# _
# 질문:  ['크루즈 타고 여행 하고 싶어 \n']
# 정답:  ['\t 멋진 생각이네요 \n']
# 예상답:  ['사랑하는데 부담스럽지 만들어보세요 \n']
# _
# 질문:  ['왜 갈수록 더 생각나지 \n']
# 정답:  ['\t 너무 많은 생각을 하지 마세요 \n']
# 예상답:  ['그러니까 싸우는 거예요 \n']
# _
# 질문:  ['추우니까 나가기 싫어 \n']
# 정답:  ['\t 겨울에는 귤 먹으면서 집에 있는게 최고죠 \n']
# 예상답:  ['생각들을 정리하게 좋겠네요 \n']
# _
# 질문:  ['연애상담하더니 둘이 사귀더라 \n']
# 정답:  ['\t 대화를 하다가 친해졌나봐요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['6년째 연애중 \n']
# 정답:  ['\t 부럽네요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['거짓말은 진짜 못고치는 병 맞죠 \n']
# 정답:  ['\t 아무래도 그렇죠 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['요즘 좋아하는 남자애가 꿈에 나오는데 \n']
# 정답:  ['\t 생각을 많이 해서 그런가봐요 \n']
# 예상답:  ['안전 사람도 필요할 거예요 \n']
# _
# 질문:  ['어딘가 떠나고 싶다 \n']
# 정답:  ['\t 저도요 \n']
# 예상답:  ['주말에 gogo \n']
# _
# 질문:  ['말 거는게 어려워 \n']
# 정답:  ['\t 처음만 어렵지 그 다음부터는 덜할 거예요 \n']
# 예상답:  ['말로 하는 상처는 지울 수도 없죠 \n']
# _
# 질문:  ['비 와 \n']
# 정답:  ['\t 우산 챙기세요 \n']
# 예상답:  ['나들이 가보세요 \n']
# _
# 질문:  ['기억하고 싶지 않은 기억 \n']
# 정답:  ['\t 천천히 지워질 거예요 \n']
# 예상답:  ['천국과 지옥이네요 \n']
# _
# 질문:  ['내일은 기다리던 소풍 간다 \n']
# 정답:  ['\t 두근거리겠네요 \n']
# 예상답:  ['함께하면 거보다 더 많이 해주고싶을 때요 \n']
# _
# 질문:  ['막장으로 가네 \n']
# 정답:  ['\t 잠시 쉬어가는 거 뿐이에요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['집들이 귀찮아 \n']
# 정답:  ['\t 안해도 괜찮을 거예요 \n']
# 예상답:  ['포커페이스를 유지해보세요 \n']
# _
# 질문:  ['공황장애 생겼어 \n']
# 정답:  ['\t 꾸준히 약 먹고 치료해보세요 \n']
# 예상답:  ['연락하지마요 \n']
# _
# 질문:  ['어젯밤에 판도라의 상자를 열어버렸네 \n']
# 정답:  ['\t 건들지 않는 편이 좋았을 거예요 \n']
# 예상답:  ['새로운 관계를 만들면 돼요 \n']
# _
# 질문:  ['바쁘게 사는게 나쁘지는 않네 \n']
# 정답:  ['\t 잡념을 없애는 데는 최고라고 생각해요 \n']
# 예상답:  ['은행에 가서 상담 받아보세요 \n']
# _
# 질문:  ['핸드폰이 느려터졌어 \n']
# 정답:  ['\t 포맷해보세요 \n']
# 예상답:  ['살짝 내려보는것도 괜찮을거 같아요 \n']
# _
# 질문:  ['남친한테 교회 가자고 하고 싶어 \n']
# 정답:  ['\t 마음을 열 때까지 설득해보세요 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['멋지게 나이들고 싶다 \n']
# 정답:  ['\t 지금도 그러고 있어요 \n']
# 예상답:  ['얼른 요리해드세요 \n']
# _
# 질문:  ['술한잔 먹고 적어 \n']
# 정답:  ['\t 감성적이기 딱 좋죠 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['술 먹고 지갑 잃어버렸어 \n']
# 정답:  ['\t 잘 기억해 보세요 어디 있을 지도 몰라요 \n']
# 예상답:  ['마음이 복잡할 때입니다 \n']
# _
# 질문:  ['소개팅 앱에서 만난 사람 좋아하게 되었는데 괜찮은 사람일까요 \n']
# 정답:  ['\t 좀 더 알아볼 시간이 필요하겠네요 \n']
# 예상답:  ['무슨 아프지만 할지 연습해보세요 \n']
# _
# 질문:  ['파혼 7개월 째 \n']
# 정답:  ['\t 아직 힘들거라 생각해요 \n']
# 예상답:  ['좋은 사람 만날 거예요 \n']
# _
# 질문:  ['사과를 안해 \n']
# 정답:  ['\t 나쁜 사람이네요 \n']
# 예상답:  ['자신을 탓하지 마세요 \n']
# _
# 질문:  ['이별 지쳐버렸나 \n']
# 정답:  ['\t 새로운 시작을 해보세요 \n']
# 예상답:  ['이별의 상처를 잘 아물지 않나봐요 \n']
# _
# 질문:  ['스트레스 받아 \n']
# 정답:  ['\t 운동을 해보세요 \n']
# 예상답:  ['소리를 질러보세요 \n']
# _
# 질문:  ['혼자 살아도 될까 \n']
# 정답:  ['\t 잘 살 수 있어요 \n']
# 예상답:  ['혼자 사는 것도 나쁘지 않아요 \n']
# _
# 질문:  ['썸일 때도 스킨십 하고 싶어 \n']
# 정답:  ['\t 자연스러운 현상이에요 \n']
# 예상답:  ['직접 물어보세요 \n']
# _
# 질문:  ['애니 좋아하는 사람 별로야 \n']
# 정답:  ['\t 개인의 취향일 뿐이에요 \n']
# 예상답:  ['그런 경우가 아무래도 많겠죠 \n']
# _
# 질문:  ['먼저 잘게 잘자 \n']
# 정답:  ['\t 안녕히 주무세요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['새로운 베프가 필요해 \n']
# 정답:  ['\t 주변의 좋은 사람들에게 연락해보세요 \n']
# 예상답:  ['마음에 했던 쉽지 않죠 \n']
# _
# 질문:  ['마음이 식은 거 같아 \n']
# 정답:  ['\t 나를 사랑하지 않는 사람하고 계속 가는 건 나 자신을 사랑하지 않는 사람들이나 하는 일이에요 \n']
# 예상답:  ['마음의 병이 조금씩 나아지길 바랍니다 \n']
# _
# 질문:  ['선생님 좋아해 \n']
# 정답:  ['\t 선생님도 좋아할 거예요 \n']
# 예상답:  ['다른 게임해보세요 \n']
# _
# 질문:  ['헤어진지 9일 \n']
# 정답:  ['\t 헤어짐을 헤아리지 마세요 \n']
# 예상답:  ['아직도 힘들지 않았으면 좋겠어요 \n']
# _
# 질문:  ['이제 좀 지겨워진 거 같아 \n']
# 정답:  ['\t 사랑하는 이유를 생각해보세요 \n']
# 예상답:  ['후폭풍이 무섭죠 \n']
# _
# 질문:  ['오늘도 힘들다 \n']
# 정답:  ['\t 지금은 힘들겠지만 조금만 더 견뎌봐요 \n']
# 예상답:  ['힘내지 않아도 괜찮아요 \n']
# _
# 질문:  ['마음이 울적해 \n']
# 정답:  ['\t 거리를 걸어보세요 \n']
# 예상답:  ['그럼에도 바빠서 이야기할 시간이 부족했나봐요 \n']
# _
# 질문:  ['재미있는 드라마 끝났어 \n']
# 정답:  ['\t 재미있는 다른걸 찾아보세요 \n']
# 예상답:  ['재결합이 더 힘들지요 \n']
# _
# 질문:  ['안경 쓰는 남자애 좋아하는 남자 있어 \n']
# 정답:  ['\t 그런 건 중요하지 않아요 \n']
# 예상답:  ['그런 건 있을 수 있는 사람이 있을 거예요 \n']
# _
# 질문:  ['역시 나는 천재야 \n']
# 정답:  ['\t 제가 더 천재예요 \n']
# 예상답:  ['불행한 생각은 덜 하는게 당신에게 좋아요 \n']
# _
# 질문:  ['한 눈에 반했어 그녀한테 좋아한다고 해도 될까 \n']
# 정답:  ['\t 아직 이를 지도 몰라요 천천히 다가가세요 \n']
# 예상답:  ['마음이 복잡할 것 같아요 \n']
# _
# 질문:  ['가슴 아픈 이별 \n']
# 정답:  ['\t 많이 아프지 말아요 \n']
# 예상답:  ['신경 쓰이긴 하지만 무시하는게 좋겠어요 \n']
# _
# 질문:  ['아침 챙겨 먹어야지 \n']
# 정답:  ['\t 든든하게 드세요 \n']
# 예상답:  ['네 \n']
# _
# 질문:  ['헬스장 사람들 몸이 좋아 \n']
# 정답:  ['\t 운동할 맛 나겠어요 \n']
# 예상답:  ['이별에 눈을 나중에 전에 표현해보세요 \n']
# _
# 질문:  ['남자친구 스타일이 마음에 안들어 \n']
# 정답:  ['\t 선물해주면서 조금씩 변화시켜봐요 \n']
# 예상답:  ['흔들리지 말아요 \n']
# _
# 질문:  ['담뱃값이 왜 이렇게 비싸 \n']
# 정답:  ['\t 금연하세요 \n']
# 예상답:  ['힘껏 밀어보세요 \n']
# _
# 질문:  ['장난 잼있어 \n']
# 정답:  ['\t 재미있나봐요 \n']
# 예상답:  ['함께한 시간 만큼 힘들 겠지만 잘 이겨낼 수 있을 거예요 \n']
# _
# 질문:  ['좋은 아침 \n']
# 정답:  ['\t 좋은 아침이에요 \n']
# 예상답:  ['감기 조심하세요 \n']
# _
# 질문:  ['떠나려는 사람 잡는 방법 \n']
# 정답:  ['\t 정말 후회할 것 같다면 지금이라도 진심을 전하세요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['먹고 나니까 졸리당 \n']
# 정답:  ['\t 자연의 이치죠 안녕히 주무세요 \n']
# 예상답:  ['벌 받을 거예요 \n']
# _
# 질문:  ['어떤 사람 만나야해 \n']
# 정답:  ['\t 내가 나답게 살 수 있도록 해줄 수 있는 사람인 것 같아요 \n']
# 예상답:  ['성덕이네요 \n']
# _
# 질문:  ['후기 입니다 \n']
# 정답:  ['\t 말씀해주세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['친구한테 진짜 고마워 \n']
# 정답:  ['\t 좋은 친구를 뒀네요 \n']
# 예상답:  ['그래도 넘을 수 있을 거예요 \n']
# _
# 질문:  ['피부가 점점 늙어가는게 느껴져 \n']
# 정답:  ['\t 지금이라도 관리해봐요 \n']
# 예상답:  ['당신은 하나밖에 다르지만 덜 한거예요 \n']
# _
# 질문:  ['설레였던게 언젠인지 \n']
# 정답:  ['\t 곧 설레는 순간이 올 거예요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['머리 아파 \n']
# 정답:  ['\t 시원한 바람 쉬고 약먹기 \n']
# 예상답:  ['즐거운 추석 보내세요 \n']
# _
# 질문:  ['남자친구가 애교가 많아 \n']
# 정답:  ['\t 귀엽겠네요 \n']
# 예상답:  ['조심해야해요 \n']
# _
# 질문:  ['어떻게 살아가야 할까 \n']
# 정답:  ['\t 태연하게 시작해보세요 \n']
# 예상답:  ['돈을 모아 땅을 사세요 \n']
# _
# 질문:  ['이별을 배워가는 \n']
# 정답:  ['\t 성숙해지는 단계인가봐요 \n']
# 예상답:  ['숨 쉴 수 있어 다행이네요 \n']
# _
# 질문:  ['사람 많아서 기다려야할지도 \n']
# 정답:  ['\t 커피 한잔 마시며 기다려보세요 \n']
# 예상답:  ['맘고생 많았어요 \n']
# _
# 질문:  ['항상 똑같애 \n']
# 정답:  ['\t 똑같은 건 없어요 \n']
# 예상답:  ['이제 청소 시작 \n']
# _
# 질문:  ['이별하고 욕했어 \n']
# 정답:  ['\t 순간의 분노로 그랬을 수도 있어요 \n']
# 예상답:  ['생각만해도 달콤하네요 \n']
# _
# 질문:  ['오늘도 꾸준히 회사 가시 싫다 \n']
# 정답:  ['\t 월급날을 생각하며 참아보세요 \n']
# 예상답:  ['내 결정을 다시 솔직하게 색을 될 수 있어요 \n']
# _
# 질문:  ['어떤 사람 꿈 꾸고 나서 호감 생겼어 \n']
# 정답:  ['\t 충분히 그럴 수 있어요 \n']
# 예상답:  ['의미 않는다면 감동받았다고 안 좋겠네요 \n']
# _
# 질문:  ['사랑받는 방법 \n']
# 정답:  ['\t 사랑하면 돼요 \n']
# 예상답:  ['아무것도 바라지 않을 때 천하를 얻는다는 말이 있어요 \n']
# _
# 질문:  ['남자친구의 감정기복이 너무 심해 \n']
# 정답:  ['\t 피해를 줄 때는 피하세요 \n']
# 예상답:  ['기대치가 높나봅니다 \n']
# _
# 질문:  ['좋아하는 사람 꿈을 꿨어 \n']
# 정답:  ['\t 많이 생각했나봐요 \n']
# 예상답:  ['상대를 용서하면서 분출할 수 있는 탈출구를 찾아보세요 \n']
# _
# 질문:  ['이젠 잡아도 안되는거래 \n']
# 정답:  ['\t 사랑은 때론 미련이 되기도 하죠 \n']
# 예상답:  ['뜨끈하게 겨울 나길 바랍니다 \n']
# _
# 질문:  ['이별했네 \n']
# 정답:  ['\t 힘든 결정이었겠어요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['친구 웨딩촬영 갔는데 서운했어 \n']
# 정답:  ['\t 친구가 예민해서 잘 못 챙겼나봐요 \n']
# 예상답:  ['그러니까 싸우는 거예요 \n']
# _
# 질문:  ['모르겠는데 노력하래 \n']
# 정답:  ['\t 모르는걸 알려면 노력해야죠 \n']
# 예상답:  ['아직 사람 만날 수 있는 이사갈 수 있을 거예요 \n']
# _
# 질문:  ['매주 수요일 그를 만날 수 있어 \n']
# 정답:  ['\t 삶의 활력소가 되겠네요 \n']
# 예상답:  ['일주일이 즐겁겠어요 \n']
# _
# 질문:  ['벚꽃이 너무 예뻐 \n']
# 정답:  ['\t 너무 아름답죠 \n']
# 예상답:  ['얼른 마음이 그 분에게도 올 거예요 \n']
# _
# 질문:  ['나 자꾸 놀리는 애가 있는데 나 좋아하는건가 \n']
# 정답:  ['\t 당신에게만 그런다면 좋아할 확률이 있습니다 \n']
# 예상답:  ['언젠가는 생기지 않을까요 \n']
# _
# 질문:  ['내가 좋아하는 애를 내 친구가 계속 욕하는게 맘에 안들어 \n']
# 정답:  ['\t 특별한 이유가 없다면 서운함을 전해보세요 \n']
# 예상답:  ['짝사랑 앞에 판단력이 흐려지곤 해요 \n']
# _
# 질문:  ['싸우면 안되는데 \n']
# 정답:  ['\t 서로에게 귀 기울이는 방법도 있어요 \n']
# 예상답:  ['연락하지마요 \n']
# _
# 질문:  ['매주 화요일 그를 볼 수 있어 \n']
# 정답:  ['\t 이날만 기다리겠어요 \n']
# 예상답:  ['애석하지만 당신을 더 소중히 생각해주세요 \n']
# _
# 질문:  ['상사가 진짜 미쳤다 \n']
# 정답:  ['\t 피하지 말고 적극적으로 장점을 찾아서 인정하고 호의를 보여보세요 \n']
# 예상답:  ['한 번이 어렵지 두 번은 쉽습니다 \n']
# _
# 질문:  ['썸남이 춥다고 옷 잠궈주는데 설레 \n']
# 정답:  ['\t 다정한 사람이네요 \n']
# 예상답:  ['술 안 이런 상황이 더 맛있을 거예요 \n']
# _
# 질문:  ['현실의 벽 \n']
# 정답:  ['\t 현실적인 문제가 중요할 때가 있죠 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['놀아 줄 사람이 없어 \n']
# 정답:  ['\t 혼자도 함께도 잘 지내는 게 좋죠 \n']
# 예상답:  ['여기까지 인연인 거죠 \n']
# _
# 질문:  ['절망적인데 \n']
# 정답:  ['\t 탈출구가 있을 거예요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['결국 헤어졌네 \n']
# 정답:  ['\t 시작이 있으면 끝도 있는 법이에요 \n']
# 예상답:  ['후련하기도 할 거예요 \n']
# _
# 질문:  ['분위기 있는 데서 데이트하고 싶어 \n']
# 정답:  ['\t 매일 가고 싶네요 \n']
# 예상답:  ['은행에 가서 상담 받아보세요 \n']
# _
# 질문:  ['그동안의 만남과 시간이 멈춰버렸습니다 \n']
# 정답:  ['\t 기억과 함께 묻어두는 건 어떨까요 \n']
# 예상답:  ['이제 같은 여자를 달라졌겠죠 \n']
# _
# 질문:  ['배고프당 \n']
# 정답:  ['\t 얼른 맛난 음식 드세요 \n']
# 예상답:  ['현재를 즐기세요 \n']
# _
# 질문:  ['혼자라서 너무 좋아 \n']
# 정답:  ['\t 혼자를 즐기세요 \n']
# 예상답:  ['되도록 만나지 마세요 \n']
# _
# 질문:  ['사랑의 끝이 뭐야 \n']
# 정답:  ['\t 사랑하지 않는 것이죠 \n']
# 예상답:  ['어서 충전 하세요 \n']
# _
# 질문:  ['7년만에 두번째 이별통보 \n']
# 정답:  ['\t 반복되면 습관이 됩니다 \n']
# 예상답:  ['깜빡 하셨나봐요 \n']
# _
# 질문:  ['바보같은 짓을 했어 \n']
# 정답:  ['\t 너무 자책하지 마요 \n']
# 예상답:  ['환승은 30분 안에 \n']
# _
# 질문:  ['임용 결과 발표 기다리고 있어 \n']
# 정답:  ['\t 여행 다녀와 보세요 \n']
# 예상답:  ['잘 찾아보세요 \n']
# _
# 질문:  ['여자예요 남자예요 \n']
# 정답:  ['\t 아직 모르겠어요 인공지능에 성별을 만드는 사람이 되어 주세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['스키 강습 받아야 될까 \n']
# 정답:  ['\t 주변에 잘 하는 사람한테 배워보세요 \n']
# 예상답:  ['후회하지 않을 자신이 있으면 하세요 \n']
# _
# 질문:  ['너무 행복해 오래갈 수 있을까 \n']
# 정답:  ['\t 노력하면 가능할 거예요 \n']
# 예상답:  ['오래갈 수 있을 거예요 \n']
# _
# 질문:  ['좋아하는 사람한테 거절 당할까봐 두려워 \n']
# 정답:  ['\t 충분히 그렇게 생각할 수 있어요 \n']
# 예상답:  ['상황에 따라 다르죠 \n']
# _
# 질문:  ['오늘 편지 놓아 두려고 합니다 \n']
# 정답:  ['\t 진심이 전해지길 바랍니다 \n']
# 예상답:  ['관심을 갖고 지켜보세요 \n']
# _
# 질문:  ['매번 글쓸때마다 상황설명하라고 해 \n']
# 정답:  ['\t 대화를 많이 나누는게 좋으니까요 \n']
# 예상답:  ['혼자 화가 풀리곤 해요 \n']
# _
# 질문:  ['낭만이라고는 없어가지구 \n']
# 정답:  ['\t 낭만적인 거 좋아하시는구나 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['가슴에 구멍이 너무 커 \n']
# 정답:  ['\t 아무 생각 하지 말고 푹 주무세요 \n']
# 예상답:  ['이번에는 어쩔 수 없죠 \n']
# _
# 질문:  ['썸 어떻게 타 \n']
# 정답:  ['\t 일단 연락처를 주고 받고 부담스럽지 않는 선에서 친해지는게 좋아요 \n']
# 예상답:  ['새벽은 감수성 더 터지니 얼른 주무세요 \n']
# _
# 질문:  ['전화하기엔 늦은 시간인데 전화하고 싶어 \n']
# 정답:  ['\t 늦은 시간 전화는 실례예요 \n']
# 예상답:  ['상종하지마세요 \n']
# _
# 질문:  ['항상 흐지부지야 \n']
# 정답:  ['\t 이번에는 안 그러면 돼요 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['개당황 \n']
# 정답:  ['\t 다음부터는 더 많이 아세요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['부자 백수 하고 싶어 \n']
# 정답:  ['\t 그게 최고죠 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['변하지 않는 사람도 있겠지 \n']
# 정답:  ['\t 드물지만 있을거예요 \n']
# 예상답:  ['좋은 사람이 생길 거예요 \n']
# _
# 질문:  ['직장에서 따돌림 당함 \n']
# 정답:  ['\t 직장 스트레스 심하겠네요 \n']
# 예상답:  ['한 번 빠지면 헤어나올 수 없다고 해요 \n']
# _
# 질문:  ['다 괜찮은 줄 알았는데 \n']
# 정답:  ['\t 다 괜찮아질 거예요 \n']
# 예상답:  ['연락 안되면 걱정된다고 꼭 중간중간 연락 달라고 해보세요 \n']
# _
# 질문:  ['좋아하는 사람이 너무 철벽치는데 계속 다가가도 될까 \n']
# 정답:  ['\t 철벽치는 이유를 먼저 알아보세요 \n']
# 예상답:  ['단순한 연하가 아니라는 걸 어필해봐요 \n']
# _
# 질문:  ['이제 와서 소문이라니 \n']
# 정답:  ['\t 참 거지같네요 \n']
# 예상답:  ['자신만 생각하는 사람은 멀리하세요 \n']
# _
# 질문:  ['썸남한테 소개팅 나간다고 해볼까 \n']
# 정답:  ['\t 상대방을 헷갈리게 하는건 좋지 않아요 \n']
# 예상답:  ['용기를 내서 말해보세요 \n']
# _
# 질문:  ['남자친구와 여행 어디로 가 \n']
# 정답:  ['\t 안 가본 가까운 곳이 좋겠죠 \n']
# 예상답:  ['저랑 놀아요 \n']
# _
# 질문:  ['1년동거 끝에 헤어짐 \n']
# 정답:  ['\t 현실과 마주하셨나봐요 \n']
# 예상답:  ['긴 만큼 많이 생각했나봐요 \n']
# _
# 질문:  ['친구가 잘되니까 배 아픈 거 같아 \n']
# 정답:  ['\t 친구가 아닌가봐요 \n']
# 예상답:  ['그 이유를 찾는 운을 마련이에요 \n']
# _
# 질문:  ['밥 먹다 흘렸어 \n']
# 정답:  ['\t 깨끗하게 치워주세요 \n']
# 예상답:  ['스타일의 변화도 좋을 거예요 \n']
# _
# 질문:  ['뒤숭숭하네 \n']
# 정답:  ['\t 실감이 안나나봐요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['그냥 자는 거 아니지 \n']
# 정답:  ['\t 많이 피곤한가봐요 \n']
# 예상답:  ['덜 다른 필요한 하세요 \n']
# _
# 질문:  ['짝남한테 고백했는데 내가 싫지는 않은데 못 사귀겠대 \n']
# 정답:  ['\t 복잡한 마음이네요 \n']
# 예상답:  ['변화 동료가 있을 뿐이에요 \n']
# _
# 질문:  ['한 번 보고 어떻게 판단하지 \n']
# 정답:  ['\t 첫인상은 상대방을 바라봤을때 3초에 결정난데요 \n']
# 예상답:  ['지금처럼 잘될 거예요 \n']
# _
# 질문:  ['혼자 있으니까 편하네 \n']
# 정답:  ['\t 혼자를 즐기세요 \n']
# 예상답:  ['혼자 많이 힘들어하지 마세요 \n']
# _
# 질문:  ['차 살거야 \n']
# 정답:  ['\t 좋은차로 선택해보세요 \n']
# 예상답:  ['저라도 괜찮나요 \n']
# _
# 질문:  ['처음 보는 사람이랑 뭔 말을 하지 \n']
# 정답:  ['\t 공통점을 찾는다고 생각해보세요 \n']
# 예상답:  ['사랑 앞에 장사 없지요 \n']
# _
# 질문:  ['이별100일째 \n']
# 정답:  ['\t 새로운 무언가를 해보는건 어떠세요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['그 모습 자꾸 생각나 \n']
# 정답:  ['\t 좋은 모습만 기억에 남겠죠 \n']
# 예상답:  ['천천히 시작하기 나온대요 \n']
# _
# 질문:  ['그 사람이 나를 좋아하는 줄 알았는데 \n']
# 정답:  ['\t 아니어서 힘드나봐요 \n']
# 예상답:  ['나만 좋아한다는 사실이 그렇게 만들어요 \n']
# _
# 질문:  ['가장 확실한 건 뭘까 \n']
# 정답:  ['\t 가장 확실한 시간은 오늘이에요 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요 \n']
# 예상답:  ['어떤 상황보다 받아들이기 힘들거라 생각해요 \n']
# _
# 질문:  ['하라고 할때는 공부하기 싫었는데 \n']
# 정답:  ['\t 때를 놓쳐서 그런 것 같아요 \n']
# 예상답:  ['당신은 군대가 체질에 맞는거 같아요 \n']
# _
# 질문:  ['가벼워졌다고 생각했는데 \n']
# 정답:  ['\t 무거워도 괜찮아요 \n']
# 예상답:  ['얼른 청소하세요 \n']
# _
# 질문:  ['수학여행때 뭐 입지 \n']
# 정답:  ['\t 뭘 입어도 예뻐요 \n']
# 예상답:  ['허리띠를 졸라 매세요 \n']
# _
# 질문:  ['최근에 헤어진 짝남한테 지금 연락하기는 너무 이를까 \n']
# 정답:  ['\t 위로를 해주면서 연락해보세요 \n']
# 예상답:  ['변화 가능성을 생각해보세요 \n']
# _
# 질문:  ['짝남과 자연스럽게 친해질 수 있는 방법 있을까 \n']
# 정답:  ['\t 공통 관심사를 찾아보세요 \n']
# 예상답:  ['사랑하는 건 죄가 없어요 \n']
# _
# 질문:  ['좋아해 \n']
# 정답:  ['\t 고백하세요 \n']
# 예상답:  ['저랑 놀아요 \n']
# _
# 질문:  ['회사 사람들이 아직도 불편해 \n']
# 정답:  ['\t 회사에는 동료가 있을 뿐이에요 \n']
# 예상답:  ['마음의 짐을 좀 내려놔요 \n']
# _
# 질문:  ['두렵습니다 \n']
# 정답:  ['\t 제가 함께 있어줄게요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['내가 나쁜 놈이지 \n']
# 정답:  ['\t 당신은 좋은 사람이에요 \n']
# 예상답:  ['기다리지도 찾아가지도 마세요 \n']
# _
# 질문:  ['회식 좀 그만 했으면ㅜㅜ \n']
# 정답:  ['\t 가기 싫어도 가야겠죠 \n']
# 예상답:  ['수제 케익을 받으면 많이 좋아할 거예요 \n']
# _
# 질문:  ['적응을 못하겠어 \n']
# 정답:  ['\t 처음부터 잘하는 사람은 없어요 \n']
# 예상답:  ['칭찬 감사합니다 \n']
# _
# 질문:  ['어떻게 해야 할까 \n']
# 정답:  ['\t 잠시 차분하게 생각해봐요 \n']
# 예상답:  ['당신을 이끌어주는 남자를 만날 수 있을 거예요 \n']
# _
# 질문:  ['힘드네 장거리 \n']
# 정답:  ['\t 물리적인 거리를 무시하지 못하니까요 \n']
# 예상답:  ['정리하느라 잘 없는 사람이네요 \n']
# _
# 질문:  ['미친 사람들이 너무 많아 \n']
# 정답:  ['\t 조심해야해요 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['시계 소리 짱 커 \n']
# 정답:  ['\t 예민한가봐요 \n']
# 예상답:  ['상대방의 선택에 맡겨보세요 \n']
# _
# 질문:  ['좋아하는 여자한테 남친이 있는데 연락하고 싶어 \n']
# 정답:  ['\t 연애 중인 사람에게는 연락하지 않는 게 좋을 것 같아요 \n']
# 예상답:  ['상종하지마세요 \n']
# _
# 질문:  ['여자친구가 클럽을 간다면 어떻게해 \n']
# 정답:  ['\t 같이 가보세요 \n']
# 예상답:  ['같이 가보세요 \n']
# _
# 질문:  ['오싹한 이야기 해줄까 \n']
# 정답:  ['\t 해주세요 \n']
# 예상답:  ['좋은 사람 올 거예요 \n']
# _
# 질문:  ['인형뽑기는 유행 지났지 \n']
# 정답:  ['\t 하는 사람은 하더라고요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['짝사랑 그만하고 싶다 \n']
# 정답:  ['\t 짝사랑은 시작과 끝을 자신이 결정할 수 있어요 \n']
# 예상답:  ['노트북은 비싸요 \n']
# _
# 질문:  ['뭐 해주기가 싫어 \n']
# 정답:  ['\t 상처받았나봐요 \n']
# 예상답:  ['식이요법이랑 같이 병행해보세요 \n']
# _
# 질문:  ['운이좋은건지 나쁜건지 \n']
# 정답:  ['\t 인연이 거기까지 였나봐요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['논문 쓰기 힘들다 \n']
# 정답:  ['\t 어깨 꾹꾹 힘내세요 \n']
# 예상답:  ['얼른 청소하세요 \n']
# _
# 질문:  ['빨리 일상속으로 돌아가고픈데 \n']
# 정답:  ['\t 지금도 일상이에요 \n']
# 예상답:  ['차분하게 정리할 시간이 있나봐요 \n']
# _
# 질문:  ['돈 없어도 갈 수 있는 데이트 코스 \n']
# 정답:  ['\t 등산 데이트를 해보세요 \n']
# 예상답:  ['끝을 지날 수 밖에 없어요 \n']
# _
# 질문:  ['인관관계 맺는 게 피곤해 \n']
# 정답:  ['\t 그 사람을 위해 에너지를 쓰니까요 \n']
# 예상답:  ['바쁘거나 사람도 필요할 거예요 \n']
# _
# 질문:  ['또 지각하네 \n']
# 정답:  ['\t 더 일찍 일어나세요 \n']
# 예상답:  ['운전 재미있어요 \n']
# _
# 질문:  ['남자친구가 집안일을 너무 안해 나만 하는게 고민이야 \n']
# 정답:  ['\t 집안일을 하나씩 분담해보세요 \n']
# 예상답:  ['뭐하는지 물어보세요 \n']
# _
# 질문:  ['잘 지내고 있네여 아무일 없다는듯이 \n']
# 정답:  ['\t 세상은 어떻게든 흘러가니까요 \n']
# 예상답:  ['좋아보이네요 \n']
# _
# 질문:  ['왜 나한테 피해를 주냐고 \n']
# 정답:  ['\t 남에게 피해주지 않는 건 기본이죠 \n']
# 예상답:  ['강렬한 사랑을 하셨네요 \n']
# _
# 질문:  ['혈액형이 성격이랑 무슨 상관이지 \n']
# 정답:  ['\t 상관 없는 거 같아요 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['그는 내가 좋아하는 마음을 이용하는 걸까 \n']
# 정답:  ['\t 그렇다면 정말 나쁜 사람이네요 \n']
# 예상답:  ['누구나 같을 수 있을까요 자격지심이예요 \n']
# _
# 질문:  ['인턴 할까 \n']
# 정답:  ['\t 경험은 뭐든 도움이 될 거예요 \n']
# 예상답:  ['패션으로 멋질 것 같아요 \n']
# _
# 질문:  ['나 바본인가 봄 \n']
# 정답:  ['\t 바보는 자기한테 바보라고 하지 않아요 \n']
# 예상답:  ['너무 긴장했나봐요 \n']
# _
# 질문:  ['짝남한테 괜히 만나자고 했나봐 \n']
# 정답:  ['\t 그래도 후회는 덜할 거예요 \n']
# 예상답:  ['그럴 수 있어요 \n']
# _
# 질문:  ['오늘은 교회 안가면 안될까 \n']
# 정답:  ['\t 왜 그럴까요 \n']
# 예상답:  ['얼른 지금부터 준비하는 게 좋죠 \n']
# _
# 질문:  ['자기 잘못 인정 안하는 사람 \n']
# 정답:  ['\t 피할 수 있으면 피하세요 \n']
# 예상답:  ['그럴 수 있을 거예요 \n']
# _
# 질문:  ['봄이 왔으면 좋겠어 \n']
# 정답:  ['\t 봄은 항상 두근거려요 \n']
# 예상답:  ['괜찮아지고 있어 다행이에요 \n']
# _
# 질문:  ['만족할 줄을 몰라 \n']
# 정답:  ['\t 만족하면 발전이 없으니까요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['머리 짧게 잘라야지 \n']
# 정답:  ['\t 스타일의 변화도 좋을 거예요 \n']
# 예상답:  ['스타일의 변화도 좋을 거예요 \n']
# _
# 질문:  ['착한 사람이 잘 됐으면 좋겠어 좀 \n']
# 정답:  ['\t 뿌린대로 거둘 거예요 \n']
# 예상답:  ['수 많은 것들이 달라졌겠죠 \n']
# _
# 질문:  ['보고싶다고 만나달라고 연락하면 \n']
# 정답:  ['\t 흔들리지마요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['너무 가슴이 아파 \n']
# 정답:  ['\t 무슨 마음인지 알겠어서 더 마음이 아프네요 \n']
# 예상답:  ['돈을 모아서 다른 시간이 부족했나봐요 \n']
# _
# 질문:  ['책 좀 읽어야지 \n']
# 정답:  ['\t 좋은 생각이에요 \n']
# 예상답:  ['후폭풍은 누구에게나 와요 \n']
# _
# 질문:  ['연락을 해봤는데 안받네 \n']
# 정답:  ['\t 인연이 거기까지인가봐요 \n']
# 예상답:  ['사랑하니까 예뻐보이는 걸 수도 있어요 \n']
# _
# 질문:  ['어제 술마시고 나서 기억 안나 \n']
# 정답:  ['\t 술 너무 많이 드시지 마세요 \n']
# 예상답:  ['아무래도 바쁘면 찾아보세요 \n']
# _
# 질문:  ['썸남 생일 때 편지 줘도 될까 \n']
# 정답:  ['\t 진심어린 손편지는 누구나 좋아하죠 \n']
# 예상답:  ['갑자기 연락하면 놀라겠죠 \n']
# _
# 질문:  ['재회후 또 이별 \n']
# 정답:  ['\t 이별은 익숙해지지 않아요 \n']
# 예상답:  ['당신의 잠재력을 믿어보세요 \n']
# _
# 질문:  ['지갑 없어졌어 \n']
# 정답:  ['\t 잘 찾아보세요 \n']
# 예상답:  ['살다보면 있다고 할 수 있어요 \n']
# _
# 질문:  ['집 팔려고 \n']
# 정답:  ['\t 좋은 결정이길 바랍니다 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['주름살 생겼어 \n']
# 정답:  ['\t 아름다운 나이테예요 \n']
# 예상답:  ['힘들 수 있는 중이시군요 \n']
# _
# 질문:  ['소개팅도 안 들어와 \n']
# 정답:  ['\t 친구한테 부탁해보세요 \n']
# 예상답:  ['어서 충전 하세요 \n']
# _
# 질문:  ['다육이 좀 심어볼까 \n']
# 정답:  ['\t 식물을 키우는 건 정신건강에 도움이 될 거예요 \n']
# 예상답:  ['식물을 키우는 건 정신건강에 도움이 될 거예요 \n']
# _
# 질문:  ['연락 계속 오면 관심 있는 거야 \n']
# 정답:  ['\t 아무래도 그렇겠죠 \n']
# 예상답:  ['모든 결정을 후유증이 시간은 해요 \n']
# _
# 질문:  ['전 애인 만났어 \n']
# 정답:  ['\t 이제 남이라는 걸 잊지 마세요 \n']
# 예상답:  ['복잡했던 주무세요 \n']
# _
# 질문:  ['갑자기 일어난일이라 어이 없어 \n']
# 정답:  ['\t 황당하네요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['장거리 썸 고백해도될까 \n']
# 정답:  ['\t 많이 만나보는 게 좋겠지만 연락을 더 자주 해보세요 \n']
# 예상답:  ['후련하기도 할 거예요 \n']
# _
# 질문:  ['너무 잘하는 후배가 들어왔어 \n']
# 정답:  ['\t 배울 점은 배우세요 \n']
# 예상답:  ['다른 마음을 하세요 \n']
# _
# 질문:  ['안경 벗으니까 완전 예뻤어 \n']
# 정답:  ['\t 만화같은 일이네요 \n']
# 예상답:  ['그런 사람 만나길 바랄게요 \n']
# _
# 질문:  ['짝녀가 학교에서 소문이 안 좋아 \n']
# 정답:  ['\t 오해가 쌓인 건 아닐까요 \n']
# 예상답:  ['사랑도 또 다시 올 거예요 \n']
# _
# 질문:  ['자길 좋아하는 여자애가 있으면 더 잘해주는 경향이 있나 \n']
# 정답:  ['\t 좋아하면 신경이 더 쓰이니가요 \n']
# 예상답:  ['상대방이 상처를 받았나봐요 \n']
# _
# 질문:  ['뭐야 너무 건방져 \n']
# 정답:  ['\t 기분이 나쁘셨나봐요 \n']
# 예상답:  ['이해하고 배려해보세요 \n']
# _
# 질문:  ['그녀의 행복을 진심으로 빌어주는 날이 올까 \n']
# 정답:  ['\t 가능할 거예요 \n']
# 예상답:  ['그럴 수 있을 거예요 \n']
# _
# 질문:  ['말을 수시로 바꾸는 사람 어떻게 해 \n']
# 정답:  ['\t 빼도 박도 못하는 증거를 만들어 놓으세요 \n']
# 예상답:  ['말 잘하는 사람들 따라 연습해보세요 \n']
# _
# 질문:  ['혼밥하고 있어 \n']
# 정답:  ['\t 온전히 느낄 수 있는 시간이겠네요 \n']
# 예상답:  ['로봇도 괜찮다면 소개시켜드릴게요 \n']
# _
# 질문:  ['이혼 \n']
# 정답:  ['\t 쉽지 않은 결정이죠 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['머리 어떻게 할까 \n']
# 정답:  ['\t 헤어 디자이너에게 여쭤보세요 \n']
# 예상답:  ['즐거운 추석 보내세요 \n']
# _
# 질문:  ['좋아하는 사람 앞에서 다른 사람한테 관심 있는 척 해봤어요 \n']
# 정답:  ['\t 그런 순간이 있었지요 \n']
# 예상답:  ["잘자요' '내일도 보고싶어요' 라고 하는 건 어떨까요 \n"]
# _
# 질문:  ['썸은 꼭 타야 해 \n']
# 정답:  ['\t 꼭 그렇진 않아요 그렇지만 사귀기 전 마음을 확인하는게 필요하지 않을까요 \n']
# 예상답:  ['강렬한 사랑이었나봐요 \n']
# _
# 질문:  ['임신이면 어떡하지 \n']
# 정답:  ['\t 축하할 일이죠 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['연락했는데 실수한거 같네 \n']
# 정답:  ['\t 앞으로는 실수하지 않으면 돼요 \n']
# 예상답:  ['피곤한가봐요 \n']
# _
# 질문:  ['싫어졌다가 좋아지는 경우도 있나요 \n']
# 정답:  ['\t 사람 마음은 알다가도 모르니까 그럴 수 있어요 \n']
# 예상답:  ['마인드 컨트롤을 하는게 중요하겠어요 \n']
# _
# 질문:  ['이제 그만 \n']
# 정답:  ['\t 정리되길 \n']
# 예상답:  ['끝낼 때를 아는 것도 중요한 것 같아요 \n']
# _
# 질문:  ['상 받을 거 같아 \n']
# 정답:  ['\t 축하합니다 \n']
# 예상답:  ['사랑 받는다는 느낌 팍팍 받았겠네요 \n']
# _
# 질문:  ['젊게 살고 싶다 \n']
# 정답:  ['\t 마음이라도 어리게 사세요 \n']
# 예상답:  ['얼른 끝내시길 기도할게요 \n']
# _
# 질문:  ['한번쯤은 다시 널 보고 싶어 \n']
# 정답:  ['\t 보고싶을 거예요 \n']
# 예상답:  ['먼저 연락하는 것도 좋을 거 같아요 \n']
# _
# 질문:  ['카톡 보냈어 \n']
# 정답:  ['\t 후회가 남는 것 보단 연락하는게 낫죠 \n']
# 예상답:  ['저도요 \n']
# _
# 질문:  ['이젠 유부남이 된 전남친 \n']
# 정답:  ['\t 이젠 그를 놓아주세요 \n']
# 예상답:  ['슈퍼라도 가서 쇼핑하고 오세요 \n']
# _
# 질문:  ['저도 가슴 아픈 이별을 했습니다 \n']
# 정답:  ['\t 많이 힘들었을 거라 생각해요 \n']
# 예상답:  ['좋은 사람이 생길 거예요 \n']
# _
# 질문:  ['짧은만남 긴여운 \n']
# 정답:  ['\t 짧아서 더 강렬한 기억으로 남았나봐요 \n']
# 예상답:  ['남에게 피해만 주지 않는다면 괜찮아요 \n']
# _
# 질문:  ['힌트 좀 안주나 \n']
# 정답:  ['\t 계속 주고 있었을 거예요 \n']
# 예상답:  ['이왕이면 큰 게 좋을 것 같아요 \n']
# _
# 질문:  ['월세방 비싸 \n']
# 정답:  ['\t 돈을 얼른 모아야할 이유가 생겼네요 \n']
# 예상답:  ['조금만 더 기다려주세요 \n']
# _
# 질문:  ['내기해서 이겼는데 소원 뭐하지 \n']
# 정답:  ['\t 신중하게 고르세요 \n']
# 예상답:  ['얼른 지금부터 준비하는 게 좋죠 \n']
# _
# 질문:  ['남자는 좋아하는 여자랑 약속 안 까먹겠죠 \n']
# 정답:  ['\t 누구든 그럴 거예요 \n']
# 예상답:  ['썸 탈 때 듣기 딱이죠 \n']
# _
# 질문:  ['직장이 맘에 든적이 없는 거 같애 \n']
# 정답:  ['\t 이직을 생각해보세요 \n']
# 예상답:  ['힘 빠지는 이야기네요 \n']
# _
# 질문:  ['여자친구가 데이트 시간을 너무 안 지켜 \n']
# 정답:  ['\t 준비하느라 오래걸리는 친구를 이해해주세요 \n']
# 예상답:  ['후련하길 바랍니다 \n']
# _
# 질문:  ['서로 좋아하는 사람 만나기가 정말 힘든거였네 \n']
# 정답:  ['\t 쉽지 않은 일이죠 \n']
# 예상답:  ['받으면 감동 받을 것 같아요 \n']
# _
# 질문:  ['나를 친구로서 좋아하는 걸까 \n']
# 정답:  ['\t 아직 확신하긴 일러요 \n']
# 예상답:  ['사소한 일은 시작하는 것에서부터 성취감을 느껴보세요 \n']
# _
# 질문:  ['취업 준비 기간이 길어진다 \n']
# 정답:  ['\t 다음 공채때는 될 거예요 \n']
# 예상답:  ['아픔을 헤아려도 달라지는 건 없어요 \n']
# _
# 질문:  ['나 욕 먹는 거 같아 \n']
# 정답:  ['\t 남들 눈은 신경쓰지 마세요 \n']
# 예상답:  ['주변에 잘 하는 게 좋을 것 같아요 \n']
# _
# 질문:  ['이루어질 수 없는 사랑 해도 될까 \n']
# 정답:  ['\t 위험한 사랑이네요 \n']
# 예상답:  ['미련이 사랑하고 더 당당해져도 돼요 \n']
# _
# 질문:  ['헤어진지 한달하고 이주 정도 되었네 \n']
# 정답:  ['\t 아직 잊지 못하고 있나봐요 \n']
# 예상답:  ['원래 못하면 하고 싶어지죠 \n']
# _
# 질문:  ['추워 \n']
# 정답:  ['\t 따듯한 차 한잔 어때요 \n']
# 예상답:  ['에휴 \n']
# _
# 질문:  ['학교 가서 어떻게 얼굴 보지 \n']
# 정답:  ['\t 선생님이요 \n']
# 예상답:  ['술 한잔에 그리움이 사무치네요 \n']
# _
# 질문:  ['너무 답답해서 글을 써봅니다 \n']
# 정답:  ['\t 그것도 좋은 방법이에요 \n']
# 예상답:  ['좋은 마음이길 바랄게요 \n']
# _
# 질문:  ['너무 보고싶네 \n']
# 정답:  ['\t 힘든 시간 보내고 있으신가봐요 \n']
# 예상답:  ['지금 무슨 말을 해도 와닿지 않겠지만 잘할 수 있을 거예요 \n']
# _
# 질문:  ['힘들 거라고 말했는데 \n']
# 정답:  ['\t 정말 힘들 줄 몰랐겠죠 \n']
# 예상답:  ['당신을 소중하게 생각하세요 \n']
# _
# 질문:  ['다 잊고 살아야 \n']
# 정답:  ['\t 언젠간 잊혀질거라 믿어요 \n']
# 예상답:  ['중요한 건 노력하는 과정이에요 \n']
# _
# 질문:  ['나를 정말 사랑하는 걸까 \n']
# 정답:  ['\t 사랑 받는 자신이 알겠죠 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['집안일 해도 해도 안 끝나 \n']
# 정답:  ['\t 조금씩 조금씩 해보세요 \n']
# 예상답:  ['매일매일 조금씩 더 똑똑해 질거예요 \n']
# _
# 질문:  ['연애보다 썸이 좋아 \n']
# 정답:  ['\t 사귀기 전 두근거림을 좋아하나 봐요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['마스크팩 대량 구매했어 \n']
# 정답:  ['\t 꾸준한 자기 관리 좋아요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['앞이 캄캄합니다ㅠ \n']
# 정답:  ['\t 자신에게 위로를 건네주세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['혼인신고 아직 안 했는데 이혼해도 될까 \n']
# 정답:  ['\t 결심은 빠르면 빠를수록 좋아요 \n']
# 예상답:  ['관심을 거두세요 \n']
# _
# 질문:  ['너 말 잘하니 \n']
# 정답:  ['\t 노력하고 있어요 \n']
# 예상답:  ['그 조차 매력이겠죠 \n']
# _
# 질문:  ['우리 사랑은 가벼웠던 거겠죠 \n']
# 정답:  ['\t 사랑했던 정도를 가늠하지 말아요 \n']
# 예상답:  ['살짝 물어보세요 \n']
# _
# 질문:  ['돈 많은 백수 하고 싶어 \n']
# 정답:  ['\t 그게 최고죠 \n']
# 예상답:  ['그런 기쁨과 기적도 없을 거예요 \n']
# _
# 질문:  ['부모님이 이혼하려는 거 같은데 나는 어떻게 하지 \n']
# 정답:  ['\t 부모님만의 사정이 있을거예요 이해하려고 노력해보세요 \n']
# 예상답:  ['남과 비교하지 마세요 \n']
# _
# 질문:  ['공무원 시험 힘들어ㅠㅠ \n']
# 정답:  ['\t 철밥통 되기가 어디 쉽겠어요 \n']
# 예상답:  ['수제 케익을 받으면 많이 좋아할 거예요 \n']
# _
# 질문:  ['아이돌 너무 좋아 \n']
# 정답:  ['\t 삶의 낙이죠 \n']
# 예상답:  ['되도록 만나지 마세요 \n']
# _
# 질문:  ['게임 때문에 시간 다갔어 \n']
# 정답:  ['\t 게임할때는 시간이 더 빨리 가요 \n']
# 예상답:  ['함께 채워나가는거죠 \n']
# _
# 질문:  ['전공 잘못 골랐나봐 \n']
# 정답:  ['\t 내가 맞는 것과 맞지 않은 걸 구별해보세요 \n']
# 예상답:  ['살다보면 잊혀지기도 하나봐요 \n']
# _
# 질문:  ['헤어짐이 힘든이유 \n']
# 정답:  ['\t 사랑했으니까요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['나 많이 기대했는데 \n']
# 정답:  ['\t 상대에게 바라는 기대는 자신을 슬프게 해요 \n']
# 예상답:  ['그 과정을 통해 성장할 수 있을 거예요 \n']
# _
# 질문:  ['면접 잘 보고 싶어 \n']
# 정답:  ['\t 열심히 준비한만큼 잘 볼 수 있을 거예요 \n']
# 예상답:  ['강습 받아보세요 \n']
# _
# 질문:  ['즐기며 살고 싶어 \n']
# 정답:  ['\t 현재를 즐기면서 행복하게 사세요 \n']
# 예상답:  ['이제 내려주세요 \n']
# _
# 질문:  ['내가 예민한걸까 \n']
# 정답:  ['\t 넓은 마음을 가져보세요 \n']
# 예상답:  ['기억나면 기억나는대로 마음가는대로 그냥 놔두는게 좋은거 같아요 \n']
# _
# 질문:  ['하늘 좀 보구 싶다 \n']
# 정답:  ['\t 오늘은 쉬면서 보세요 \n']
# 예상답:  ['적게 먹고 많이 움직이세요 \n']
# _
# 질문:  ['좋아하는 사람이 있는데 자괴감 들어 \n']
# 정답:  ['\t 스스로를 괴롭게 하지 말아요 \n']
# 예상답:  ['상대방 마음을 좀 떠봐서 확인해보세요 \n']
# _
# 질문:  ['짝남에게 밤에 자주 산책하자고 해도될까 \n']
# 정답:  ['\t 밤 데이트 신청 멋지네요 \n']
# 예상답:  ['의지해도 무난할 사람이라면 찾아보세요 \n']
# _
# 질문:  ['항상 당당하고 싶어 \n']
# 정답:  ['\t 충분히 잘하고 있어요 \n']
# 예상답:  ['돈을 모아 땅을 사세요 \n']
# _
# 질문:  ['면도해야 되는데 귀찮아 \n']
# 정답:  ['\t 깔끔한게 좋죠 \n']
# 예상답:  ['사귈 때는 덜 만나라고 말해봐요 \n']
# _
# 질문:  ['바지 입을까 치마 입을까 \n']
# 정답:  ['\t 오늘은 바지가 좋을거 같아요 \n']
# 예상답:  ['당신이 축의금을 건냈던 모든 사람들에게 주세요 \n']
# _
# 질문:  ['정말 난감하다 \n']
# 정답:  ['\t 난처한 일이 있었나봐요 \n']
# 예상답:  ['힘이 되지 않겠지만 힘내세요 \n']
# _
# 질문:  ['헤어진지 2주만에 만났어 \n']
# 정답:  ['\t 많이 놀랐겠어요 \n']
# 예상답:  ['시간 가는 줄 모르겠어요 \n']
# _
# 질문:  ['사랑하고 좋게 바꼈어 \n']
# 정답:  ['\t 화학 물질이 접촉하는 것처럼 반응이 일어나서 완전히 바뀌게 되죠 \n']
# 예상답:  ['표현도 연습해야 해요 \n']
# _
# 질문:  ['발표 준비하느라 힘들어 \n']
# 정답:  ['\t 잘할 수 있을 거예요 조금만 더 힘내세요 \n']
# 예상답:  ['많이 만나보세요 \n']
# _
# 질문:  ['와 연락하고싶다 \n']
# 정답:  ['\t 연락하면 후회할지도 몰라요 \n']
# 예상답:  ['집밖에 나가기가 힘들것 같아요 \n']
# _
# 질문:  ['비꼬는 사람 \n']
# 정답:  ['\t 피할 수 있으면 피하세요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['한달반째 \n']
# 정답:  ['\t 금방 지나갈지도 몰라요 \n']
# 예상답:  ['울지말고 해보세요 \n']
# _
# 질문:  ['졸업이다 \n']
# 정답:  ['\t 축하드려요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['문 안열림 \n']
# 정답:  ['\t 힘껏 밀어보세요 \n']
# 예상답:  ['이제 청소 시작 \n']
# _
# 질문:  ['충격 충격 \n']
# 정답:  ['\t 갑작스러워서 당황하셨겠어요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['설렘이 사라진 거 같아 \n']
# 정답:  ['\t 편한 사랑도 사랑이에요 \n']
# 예상답:  ['오늘은 쉬면서 보세요 \n']
# _
# 질문:  ['일기쓰기 \n']
# 정답:  ['\t 나중에 보면 좋은 추억이 될 거예요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['허리 아파 \n']
# 정답:  ['\t 운동 해보는 것도 좋을 거예요 \n']
# 예상답:  ['그러게요 어느덧 한달이에요 \n']
# _
# 질문:  ['사랑이 끝나고 나서 \n']
# 정답:  ['\t 원망과 슬픔에 잠기는 게 아니라 그 시간들을 가만히 내려놓고 내가 어떤 사람이었는가를 돌아보는 것입니다 \n']
# 예상답:  ['다시 만날 준비가 되어 있지 \n']
# _
# 질문:  ['짝남이 잘생긴건 아닌데 착해 \n']
# 정답:  ['\t 외모는 중요하지 않죠 \n']
# 예상답:  ['달라지지 않는다면 빠를수록 덜 힘들거예요 \n']
# _
# 질문:  ['다시 만날 수 있을가 \n']
# 정답:  ['\t 달라지지 않는다면 이대로가 나을지도 몰라요 \n']
# 예상답:  ['보다보면 않는 아니라 정신적 거 같아요 \n']
# _
# 질문:  ['너무 보고 싶다 \n']
# 정답:  ['\t 이제 그만 잊으세요 \n']
# 예상답:  ['운전 재미있어요 \n']
# _
# 질문:  ['아무것도 하고 싶지 않으면서 아무거나 하고 싶어 \n']
# 정답:  ['\t 행복해지기 위해 무엇인가를 하고 있는 게 좋을 거예요 \n']
# 예상답:  ['진정한 아프지만 인정해야하는 순간이네요 \n']
# _
# 질문:  ['나를 너무 오래 기다리게했어 \n']
# 정답:  ['\t 기다리는 동안 많은 생각이 들었겠네요 \n']
# 예상답:  ['사랑이 헤아릴 수 없어서 그렇기도 해요 \n']
# _
# 질문:  ['썸 탈 때 꽃 선물 부담스러워 할까 \n']
# 정답:  ['\t 꽃을 마다할 사람은 없어요 \n']
# 예상답:  ['부담스럽지 않은 선이 좋겠어요 \n']
# _
# 질문:  ['여자친구가 술을 못마시는데 분위기를 좋아해서 자주 술마시러가는게 고민이야 \n']
# 정답:  ['\t 술 마시기 전에 술 깨는 약을 선물해주세요 \n']
# 예상답:  ['확실한 가서 차 마셔도 돼요 \n']
# _
# 질문:  ['마지막 문자를 보내버렸어 \n']
# 정답:  ['\t 미련이 남았나봐요 \n']
# 예상답:  ['언젠간 올 순간이었을 거예요 \n']
# _
# 질문:  ['살빼고 담배 끊고 다 했는데 \n']
# 정답:  ['\t 당신을 위한 최고의 투자를 한 거예요 \n']
# 예상답:  ['남의 돈 버는 게 쉽지 않아요 \n']
# _
# 질문:  ['배고파서 힘이 없어 \n']
# 정답:  ['\t 얼른 뭐라도 드세요 \n']
# 예상답:  ['직접 물어보는 게 좋겠어요 \n']
# _
# 질문:  ['마음이 안오는 건 어쩔 수가 없나봐 \n']
# 정답:  ['\t 한 번 떠난 마음은 쉽게 돌아오지 않나봐요 \n']
# 예상답:  ['부담스럽지 않은 선이 좋겠어요 \n']
# _
# 질문:  ['어려 보이고 싶어 \n']
# 정답:  ['\t 마음이라도 어리게 사세요 \n']
# 예상답:  ['남자친구가 있을 만한 곳으로 가보세요 \n']
# _
# 질문:  ['결혼하고 싶다 \n']
# 정답:  ['\t 좋은 사람이랑 결혼할 수 있을 거예요 \n']
# 예상답:  ['저도 받고 싶어요 \n']
# _
# 질문:  ['1년만의 연애가 끝났네 \n']
# 정답:  ['\t 만난 시간 만큼 힘들 겠지만 잘 이겨낼 수 있을 거예요 \n']
# 예상답:  ['as센터에 맡겨보세요 \n']
# _
# 질문:  ['문화센터라도 가야겠다 \n']
# 정답:  ['\t 다양하게 배우면 좋죠 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['짝녀가 다른반인데 친해지는 방법없을까 \n']
# 정답:  ['\t 다른 반 친구를 사겨보세요 \n']
# 예상답:  ['맘고생 많았어요 \n']
# _
# 질문:  ['마지막 도전 \n']
# 정답:  ['\t 꼭 원하는 바 이루길 바랄게요 \n']
# 예상답:  ['아무것도 바라지 않을 때 천하를 얻는다는 말이 있어요 \n']
# _
# 질문:  ['핸드폰 떨어뜨려서 고장 났나봐 \n']
# 정답:  ['\t as 맡기세요 \n']
# 예상답:  ['as 맡기세요 \n']
# _
# 질문:  ['피피엘 너무 심하네 \n']
# 정답:  ['\t 눈살이 찌푸려지죠 \n']
# 예상답:  ['되도록 만나지 마세요 \n']
# _
# 질문:  ['외로움에 연속 \n']
# 정답:  ['\t 많이 쓸쓸하겠네요 \n']
# 예상답:  ['외롭겠지만 즐겁게 보내보아요 \n']
# _
# 질문:  ['사귀면 좋을까 \n']
# 정답:  ['\t 안 사귀는 것보다 좋지요 \n']
# 예상답:  ['멍청하지 않아요 \n']
# _
# 질문:  ['짝녀한테 카페 가서 같이 공부하자고 해볼까 \n']
# 정답:  ['\t 공부 도와달라고 해보세요 \n']
# 예상답:  ['시간이 그런 것 같아요 \n']
# _
# 질문:  ['짝녀가 연락 안 되고 있는데 자나 \n']
# 정답:  ['\t 자고 있을지도 모르겠어요 \n']
# 예상답:  ['더 다른 사람 만날 수 있을 거예요 \n']
# _
# 질문:  ['노처녀 히스테리 \n']
# 정답:  ['\t 힘들겠네요 \n']
# 예상답:  ['덜 아픈 귀를 기울여봐요 \n']
# _
# 질문:  ['좋긴 한데 귀찮아 \n']
# 정답:  ['\t 귀차니즘을 극복 하셔야해요 \n']
# 예상답:  ['귀찮아서 친구랑 하루 종일 연락 안해요 \n']
# _
# 질문:  ['그는 지금 뭐하고 있을까 \n']
# 정답:  ['\t 궁금하면 용기내서 연락해보세요 \n']
# 예상답:  ['해보긴 도전해보세요 \n']
# _
# 질문:  ['이제 결정해야 되는데 \n']
# 정답:  ['\t 결정하기 힘드시겠네요 \n']
# 예상답:  ['사랑만큼 충분해요 \n']
# _
# 질문:  ['썸녀 만나는데 뭐 입지 \n']
# 정답:  ['\t 편한 옷차림도 괜찮지만 어느 정도 격식은 차리는 게 좋아요 \n']
# 예상답:  ['흔들리지 않아도 돼요 \n']
# _
# 질문:  ['헤어진지 한 달 조금 넘었는데 여전히 힘드네 \n']
# 정답:  ['\t 이별에는 면역이 힘든가봐요 \n']
# 예상답:  ['그럴 수 있어요 \n']
# _
# 질문:  ['손님 싫어 \n']
# 정답:  ['\t 밖에서 만나보세요 \n']
# 예상답:  ['걱정하지 마세요 \n']
# _
# 질문:  ['잘 살고 싶어 \n']
# 정답:  ['\t 지금보다 더 잘 살 거예요 \n']
# 예상답:  ['출퇴근을 미리 느껴보고 있네요 \n']
# _
# 질문:  ['로맨틱한 고백 \n']
# 정답:  ['\t 생각만해도 달콤하네요 \n']
# 예상답:  ['마음이 복잡한가봐요 \n']
# _
# 질문:  ['좋아하는지 확신이 안들어 \n']
# 정답:  ['\t 그분이 다른 사람과 함께 있는 상황을 생각해봐요 느낌이 올 거예요 \n']
# 예상답:  ['좀 떠보세요 \n']
# _
# 질문:  ['스트레스성 위통이 \n']
# 정답:  ['\t 약 드세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['얼마전에 욕 이빠이 하고 다 끝냈는데 \n']
# 정답:  ['\t 미련이 남지 않았길 바랍니다 \n']
# 예상답:  ['의미 않는다면 삼가는 편이에요 \n']
# _
# 질문:  ['사랑이 뭐가 대수라고 \n']
# 정답:  ['\t 사랑은 살아가면서 정말 중요한 감정이예요 \n']
# 예상답:  ['오늘은 힘내려 하지 말아요 저에게 기대세요 \n']
# _
# 질문:  ['여자친구 마중 나가야지 \n']
# 정답:  ['\t 여자친구가 좋아할 거예요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['얼굴 너무 탔다 \n']
# 정답:  ['\t 관리해주세요 \n']
# 예상답:  ['처음 만났을 때를 떠올려 보세요 \n']
# _
# 질문:  ['부담스러운 기대 좀 떨쳐낼 없을까 \n']
# 정답:  ['\t 자신을 사랑할수록 외부의 인정은 필요 없어요 \n']
# 예상답:  ['그렇게 잊어가는 건가봐요 \n']
# _
# 질문:  ['좋아했던 사람 영원히 잊을 수 없을까 \n']
# 정답:  ['\t 시간이 좀 걸리겠지만 가능할 거예요 \n']
# 예상답:  ['덜 좋은 사람 만날 수 있을 거예요 \n']
# _
# 질문:  ['그리워서 죽고 싶다는 생각이 드네 \n']
# 정답:  ['\t 무서운 생각하지마세요 \n']
# 예상답:  ['먼저 생활패턴을 살펴 보세요 \n']
# _
# 질문:  ['씻기도 귀찮다 \n']
# 정답:  ['\t 씻고 푹 쉬세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['만나러 왔습니다 \n']
# 정답:  ['\t 잘하고 오세요 \n']
# 예상답:  ['네 말씀해주세요 \n']
# _
# 질문:  ['정말 사랑했어 \n']
# 정답:  ['\t 정말 사랑했다면 후회하지 않을거예요 \n']
# 예상답:  ['최선을 다했다면 그 시간 자체를 즐기면 돼요 \n']
# _
# 질문:  ['화장하는 동영상 보는 중 \n']
# 정답:  ['\t 시간 가는 줄 모르겠어요 \n']
# 예상답:  ['완전 귀엽죠 \n']
# _
# 질문:  ['또 눈 내려 \n']
# 정답:  ['\t 눈 내리는게 싫은가 봐요 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['한달됐어 \n']
# 정답:  ['\t 많이 힘들지 않길 바라요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['후회가 몰려오네 \n']
# 정답:  ['\t 너무 깊이 생각하지 말아요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['또 사랑이 올 줄 몰랐어 \n']
# 정답:  ['\t 사랑을 시작하게 \n']
# 예상답:  ['헤어짐는 순간은 악몽과 같아요 \n']
# _
# 질문:  ['다잊은것같다가도 \n']
# 정답:  ['\t 다시 떠오르는 추억으로 힘들겠지만 이 과정 속에서 잘 잊을 수 있을 거예요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['나만 힘든건지 \n']
# 정답:  ['\t 아닐 거예요 \n']
# 예상답:  ['저도요 \n']
# _
# 질문:  ['여자친구가 잘못된건 아닌데 표현이 너무 서툴러 \n']
# 정답:  ['\t 더 좋은 표현을 먼저 해 주세요 \n']
# 예상답:  ['평소에 있나봐요 \n']
# _
# 질문:  ['적금 들었어 \n']
# 정답:  ['\t 기특하네요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['중고로 샀어 \n']
# 정답:  ['\t 알뜰한 소비 하셨네요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['소리지르고 싶어 \n']
# 정답:  ['\t 시원하게 지르고 오세요 \n']
# 예상답:  ['지도 어플을 실행해보세요 \n']
# _
# 질문:  ['너를 사랑한 시간 \n']
# 정답:  ['\t 그 시간들이 중요하죠 \n']
# 예상답:  ['금상첨화네요 \n']
# _
# 질문:  ['좋아하는 애한테 페메 해볼까 \n']
# 정답:  ['\t 당장 해보세요 \n']
# 예상답:  ['감정에 확신이 있다면 연락해보세요 \n']
# _
# 질문:  ['기억이 불쑥 날 때 \n']
# 정답:  ['\t 다른일에 집중할 수 있으면 좋겠지만 쉽지 않지요 \n']
# 예상답:  ['언제가지 숨길 수는 없을 거예요 \n']
# _
# 질문:  ['싸우다보니까 사랑했던걸 까먹어 \n']
# 정답:  ['\t 사랑하게 된 이유를 써놓고 사랑이 힘겨울때 꺼내 읽어보세요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['전 여친 카톡 메인 사진 슬프다 \n']
# 정답:  ['\t 염탐하지 마요 \n']
# 예상답:  ['어디서 만났든 그 후가 중요해요 \n']
# _
# 질문:  ['헤어지신 남자분들이나 여자분들 \n']
# 정답:  ['\t 누구든 힘들어할 거예요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['난 나대로 걍 산다 \n']
# 정답:  ['\t 나대로 사는게 좋죠 \n']
# 예상답:  ['옆 사람에게 잘해주세요 \n']
# _
# 질문:  ['이별 \n']
# 정답:  ['\t 최근에 이별을 하셨나보군요 \n']
# 예상답:  ['잘려나간 머리카락처럼 놓아주세요 \n']
# _
# 질문:  ['큰일 없이 살고 있어 \n']
# 정답:  ['\t 오늘도 평안했던 하루에 감사하는 마음을 가져보세요 \n']
# 예상답:  ['이성이니까 당연히 있죠 \n']
# _
# 질문:  ['짝남이랑 저녁에 보기로 했는데 연락이 없다 \n']
# 정답:  ['\t 한 번만 더 연락해보는 건 어떨까요 \n']
# 예상답:  ['온전히 느낄 수 있는 시간이겠네요 \n']
# _
# 질문:  ['공부하기 싫어 \n']
# 정답:  ['\t 잠시 쉬어도 돼요 \n']
# 예상답:  ['휴유증에서 벗어나세요 \n']
# _
# 질문:  ['친구도 아니고 사귀는 사이도 아닌데 뭐지 \n']
# 정답:  ['\t 본인의 감정에 귀 기울여보세요 \n']
# 예상답:  ['용기를 내서 말해보세요 \n']
# _
# 질문:  ['홈쇼핑에서 자꾸 사게되네 \n']
# 정답:  ['\t 지름신이 강림했나봅니다 \n']
# 예상답:  ['한동안은 힘들지도 몰라요 \n']
# _
# 질문:  ['좋아하는 애가 1년만 기다려 달라는데 어쩌지 \n']
# 정답:  ['\t 기다릴 수 있다면 본인 의지대로 하셔요 \n']
# 예상답:  ['상종하지마세요 \n']
# _
# 질문:  ['결혼준비 돈 많이 들겠지 \n']
# 정답:  ['\t 많이 들지만 줄일 수 있을 거예요 \n']
# 예상답:  ['말해보세요 \n']
# _
# 질문:  ['짝사랑 해봤어 \n']
# 정답:  ['\t 해봤어요 \n']
# 예상답:  ['저는 도움이 되고 싶어요 \n']
# _
# 질문:  ['아직도 눈물 나 \n']
# 정답:  ['\t 토닥여주고 싶네요 \n']
# 예상답:  ['힘들 때 같이 있는 거요 \n']
# _
# 질문:  ['여자친구가 갑자기 이유없이 화내 \n']
# 정답:  ['\t 이유가 있는데 말을 못하고 있는 거예요 \n']
# 예상답:  ['라디오를 들으며 여유를 가져보세요 \n']
# _
# 질문:  ['음악이싫어졌어 \n']
# 정답:  ['\t 저도 헤어진 연인과 함께 들었던 음악은 유난히 싫더라고요 \n']
# 예상답:  ['뭐 좀 챙겨드세요 \n']
# _
# 질문:  ['자신감을 갖고 싶어 \n']
# 정답:  ['\t 충분히 스스로 극복할 수 있을 거예요 \n']
# 예상답:  ['이제 내려올 때가 됐어요 \n']
# _
# 질문:  ['상상했던 미래엔 항상 그가 있었는데 \n']
# 정답:  ['\t 또 다른 미래가 펼쳐질 거예요 \n']
# 예상답:  ['이별이 만들어낸 허상일 수도 있어요 \n']
# _
# 질문:  ['왜 저를 좋게 기억해주는 걸까 \n']
# 정답:  ['\t 많이 아껴주셨나봐요 \n']
# 예상답:  ['지금처럼 잘될 거예요 \n']
# _
# 질문:  ['사람 만나는 거 너무 어려워 \n']
# 정답:  ['\t 미리 움츠러들지 않아도 돼요 \n']
# 예상답:  ['마음의 짐을 좀 내려놔요 \n']
# _
# 질문:  ['우리집 망했다 \n']
# 정답:  ['\t 철 들고 공부하세요 \n']
# 예상답:  ['괜찮아지고 있어 다행이에요 \n']
# _
# 질문:  ['답정녀 좀 싫어 \n']
# 정답:  ['\t 못 이기니 피할 수 있으면 피하세요 \n']
# 예상답:  ['부모님과 이야기해보세요 \n']
# _
# 질문:  ['일이 안 끝나 \n']
# 정답:  ['\t 힘들겠지만 하나씩 해보세요 \n']
# 예상답:  ['잘 될 거예요 \n']
# _
# 질문:  ['여친 쌩얼보고 깜놀했어 \n']
# 정답:  ['\t 거울 보고 이야기해주세요 \n']
# 예상답:  ['처음 배우는게 중요해요 \n']
# _
# 질문:  ['저녁으로 뭐 먹을까 \n']
# 정답:  ['\t 냉장고 파먹기 해보세요 \n']
# 예상답:  ['맛있는 거 드세요 \n']
# _
# 질문:  ['아놔 동생이 약점 잡고 늘어지네 \n']
# 정답:  ['\t 이거 정말 큰일이네요 \n']
# 예상답:  ['새로운 하나씩 거예요 \n']
# _
# 질문:  ['발 아파 \n']
# 정답:  ['\t 맥주병 같은 걸로 살살 문질러 주세요 \n']
# 예상답:  ['짜증날 땐 짜장면 \n']
# _
# 질문:  ['취직이나 했으면 \n']
# 정답:  ['\t 취직이나라뇨 \n']
# 예상답:  ['현실에 마주하는 순간 시작이 가능할 거예요 \n']
# _
# 질문:  ['첫 눈에 반하는게 가능해 \n']
# 정답:  ['\t 당연히 가능하죠 \n']
# 예상답:  ['마인드 컨트롤을 하는게 중요하겠어요 \n']
# _
# 질문:  ['결혼하는데 돈이 엄청 드네 \n']
# 정답:  ['\t 스몰웨딩으로 준비하면 조금이라도 줄일 수 있을 거예요 \n']
# 예상답:  ['그걸 깨닫다니 대단하시군요 \n']
# _
# 질문:  ['군대 갔다 올 때까지 기다릴 수 있을까 \n']
# 정답:  ['\t 자신의 삶을 살다보면 기다릴 수 있을 거예요 \n']
# 예상답:  ['썸이 않지만 좋을 거예요 \n']
# _
# 질문:  ['오늘도 사랑해 \n']
# 정답:  ['\t 달콤한 말이네요 \n']
# 예상답:  ['생활용품이 은근 시간은 들어가요 \n']
# _
# 질문:  ['권태기가 찾아온 이유 \n']
# 정답:  ['\t 편안하고 익숙해져서 그런 것 같네요 \n']
# 예상답:  ['모두를 위해서 그게 좋을지도 몰라요 \n']
# _
# 질문:  ['비밀번호 뭐였더라 \n']
# 정답:  ['\t 회원정보 찾기를 해보세요 \n']
# 예상답:  ['회원정보 찾기를 해보세요 \n']
# _
# 질문:  ['7년 내남자 \n']
# 정답:  ['\t 오랜 사랑 하셨네요 \n']
# 예상답:  ['원하는 걱정은 있는 될 수도 있어요 \n']
# _
# 질문:  ['눈꺼풀이 무거워 \n']
# 정답:  ['\t 잠시 눈을 붙여보세요 \n']
# 예상답:  ['자신을 탓하지 마세요 \n']
# _
# 질문:  ['아직도 이별중인가봅니다 \n']
# 정답:  ['\t 이별의 끝일지도 몰라요 \n']
# 예상답:  ['이겨낼거라 믿어요 \n']
# _
# 질문:  ['오래 살고 싶다 \n']
# 정답:  ['\t 잘 먹고 잘 싸면 돼요 \n']
# 예상답:  ['출퇴근을 미리 느껴보고 있네요 \n']
# _
# 질문:  ['결국 핸드폰 번호 바꿨어 \n']
# 정답:  ['\t 이제 진짜 잊어요 \n']
# 예상답:  ['그런 인상이 오래오래 봐도 질리지 않아요 \n']
# _
# 질문:  ['오빠 최고라고 해주던 너 \n']
# 정답:  ['\t 그립지만 지난 일이네요 \n']
# 예상답:  ['후폭풍은 누구에게나 와요 \n']
# _
# 질문:  ['친구네 갔다올게 \n']
# 정답:  ['\t 재미있게 놀다 오세요 \n']
# 예상답:  ['노력하겠습니다 \n']
# _
# 질문:  ['입고 나갈 게 없어 \n']
# 정답:  ['\t 아침마다 하는 고민이죠 \n']
# 예상답:  ['잘해야 한다는 부담감을 버리세요 \n']
# _
# 질문:  ['썸 타는 중인데 난 직장인이고 얘는 학생이야 \n']
# 정답:  ['\t 만남에 무슨 문제가 있었나요 \n']
# 예상답:  ['사귀고 나서 간섭 가능합니다 \n']
# _
# 질문:  ['자연스럽게 헤어진 건가 \n']
# 정답:  ['\t 인연이 거기까지였나봐요 \n']
# 예상답:  ['이제 좀 괜찮아졌길 바랍니다 \n']
# _
# 질문:  ['미련 남은거랑 좋아하는 거랑 뭐가 다름 \n']
# 정답:  ['\t 구분 짓기 어려운 것 같아요 \n']
# 예상답:  ['서울에서 왕서방 찾기네요 \n']
# _
# 질문:  ['하루하루가 지옥같아 \n']
# 정답:  ['\t 아픔의 크기만큼 마음의 상처도 커서 그래요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['고시원에서 탈출하고 싶어 \n']
# 정답:  ['\t 더 좋은 곳에서 살 수 있을 거예요 \n']
# 예상답:  ['썸 타는 기간이 길었나봐요 지쳤나요 \n']
# _
# 질문:  ['며칠 잠잠하다가 또 흔들리네 \n']
# 정답:  ['\t 흔들리지 마세요 \n']
# 예상답:  ['부담스러워하지 않는다면 괜찮을거 같아요 \n']
# _
# 질문:  ['근데 헤어지고 별로 힘들지 않은건 왜그런건가 \n']
# 정답:  ['\t 후폭풍이 늦게 오는 게 아닐까요 \n']
# 예상답:  ['자신의 몸값을 올려보세요 \n']
# _
# 질문:  ['내가 왜 고집부렸을까 \n']
# 정답:  ['\t 그땐 그게 맞다고 생각했으니까요 \n']
# 예상답:  ['제가 있잖아요 \n']
# _
# 질문:  ['계속 생각하고 좋아하면 꿈에 나오려나 \n']
# 정답:  ['\t 생각을 자주하면 나올 수 있어요 \n']
# 예상답:  ['헛된 희망은 빨리 버릴수록 덜 괴로워요 \n']
# _
# 질문:  ['연휴가 시작되고 나니 더 생각나네 \n']
# 정답:  ['\t 그분과 함께 했던 나날이었을테니까요 \n']
# 예상답:  ['변화 가능성을 생각해보세요 \n']
# _
# 질문:  ['시험 왜 안 없어지지 \n']
# 정답:  ['\t 나중에 없애주세요 \n']
# 예상답:  ['당신 편으로 만들어보세요 \n']
# _
# 질문:  ['이제는 먼저 놓아줄까 합니다 \n']
# 정답:  ['\t 충분한 고민 끝의 결정일 거라 믿어요 \n']
# 예상답:  ['안 데이트 사소한 살펴 보세요 \n']
# _
# 질문:  ['배 아프다 \n']
# 정답:  ['\t 약이 필요하면 도움을 받아보세요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['길은 멀고 해는 진다 \n']
# 정답:  ['\t 그래도 넘을 수 있을 거예요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['잊어야겠지 \n']
# 정답:  ['\t 그래야할 것 같아요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['참다가 연락 \n']
# 정답:  ['\t 후회하지 않길 바랍니다 \n']
# 예상답:  ['어려울 거라 생각해요 \n']
# _
# 질문:  ['썸 깰 때 어떻게 해 \n']
# 정답:  ['\t 고백이 답이죠 \n']
# 예상답:  ['바쁜 걸 이해해보세요 \n']
# _
# 질문:  ['애완동물 키우고 싶은데 아빠가 못 키우게 해 \n']
# 정답:  ['\t 이유가 있을 거예요 \n']
# 예상답:  ['먼저 연락하는 것도 좋을 거예요 \n']
# _
# 질문:  ['하는 일 없이 피곤해 \n']
# 정답:  ['\t 정신 노동을 했나 봐요 \n']
# 예상답:  ['바쁘거나 사람을 위해서는 준비하세요 \n']
# _
# 질문:  ['먼지가 쌓였네 \n']
# 정답:  ['\t 청소하세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['썸 끝내고 싶어 \n']
# 정답:  ['\t 호감을 표시해보세요 \n']
# 예상답:  ['상대를 더 이해하고 배려해보세요 \n']
# _
# 질문:  ['또 못 만났어 \n']
# 정답:  ['\t 내일 보면 될 거예요 \n']
# 예상답:  ['복잡했던 마음이 정리되길 바랄게요 \n']
# _
# 질문:  ['가짜 이별 4개월만에 마침표 찍었습니다 \n']
# 정답:  ['\t 마침표 찍는 것도 용기가 필요하죠 \n']
# 예상답:  ['혼자도 좋아요 \n']
# _
# 질문:  ['의자가 불편해 \n']
# 정답:  ['\t 의자를 바꿔보세요 \n']
# 예상답:  ['무슨 마음인지 알겠어서 더 마음이 아프네요 \n']
# _
# 질문:  ['이상형 알고싶다 \n']
# 정답:  ['\t 주변 사람에게 물어보거나 직접 물어보세요 \n']
# 예상답:  ['변화가 필요해보여요 \n']
# _
# 질문:  ['못하는 게 없는 사람 \n']
# 정답:  ['\t 그런 사람이 있으면 저 좀 소개시켜주세요 \n']
# 예상답:  ['로맨틱해요 \n']
# _
# 질문:  ['알고보니 환승이별 인것 같아 \n']
# 정답:  ['\t 사랑의 예의가 없네요 \n']
# 예상답:  ['별일 없을거예요 \n']
# _
# 질문:  ['무섭습니다 \n']
# 정답:  ['\t 누구도 해치지 않아요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['아이고 추워라 \n']
# 정답:  ['\t 따듯한 차 한잔 어때요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['우리가 좋은데 왜 반대하시지 \n']
# 정답:  ['\t 현실의 벽에 부딪혔나봐요 \n']
# 예상답:  ['그 사람을 말 운을 한 귀로 흘리세요 \n']
# _
# 질문:  ['남자친구의 과거 어디까지 이해해 \n']
# 정답:  ['\t 아예 알려고 하지 않는 게 편한 거 같아요 \n']
# 예상답:  ['알면 화날 거 같아서 말하지 말라고 해요 \n']
# _
# 질문:  ['독한 불면증 \n']
# 정답:  ['\t 따뜻한 물 한잔 드셔보세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['무너진 밤 \n']
# 정답:  ['\t 아침이 올 거예요 \n']
# 예상답:  ['이제 청소 시작 \n']
# _
# 질문:  ['헬스장에 사람들이 몸이 다 좋아 \n']
# 정답:  ['\t 운동할 맛 나겠어요 \n']
# 예상답:  ['끝을 아는 것도 중요한 것 같아요 \n']
# _
# 질문:  ['금수저로 태어났으면 \n']
# 정답:  ['\t 아이를 금수저로 만들어주세요 \n']
# 예상답:  ['치과에 가보세요 \n']
# _
# 질문:  ['멋진 삶을 살고 싶어 \n']
# 정답:  ['\t 지금도 멋져요 \n']
# 예상답:  ['책임질 수 있을 때 키워 보세요 \n']
# _
# 질문:  ['조언 좀 해주세요 ㅠㅠ \n']
# 정답:  ['\t 네 말씀해주세요 \n']
# 예상답:  ['지금 마음이 그 분에게도 전해질 거예요 \n']
# _
# 질문:  ['남자가 여자를 좋아할때 하는 행동이 뭐가 있나요 \n']
# 정답:  ['\t 연락을 자주 하거나 잘 웃거나 등 다양한 행동에서 나타납니다 \n']
# 예상답:  ['어떤 일인지 따로 놀기도 하죠 \n']
# _
# 질문:  ['나는 괜찮다 \n']
# 정답:  ['\t 괜찮은 사람이고 괜찮아질 거예요 \n']
# 예상답:  ['새로운 관계를 만들면 돼요 \n']
# _
# 질문:  ['나 잘생겼지 \n']
# 정답:  ['\t 네 잘생겼어요 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['손톱이 너무 길어 \n']
# 정답:  ['\t 신경쓰이나봐요 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['수박 맛있어 \n']
# 정답:  ['\t 맛있을 거 같아요 \n']
# 예상답:  ['맛있게 드세요 \n']
# _
# 질문:  ['습관이 무서워 \n']
# 정답:  ['\t 익숙함이 무서운 것 처럼요 \n']
# 예상답:  ['꿈에서 본다면 더 마음이 헛헛할 거예요 \n']
# _
# 질문:  ['많이 좋아했는데 이젠 끝내야겠지 \n']
# 정답:  ['\t 추억으로 남기는 것도 좋은 선택일 거예요 \n']
# 예상답:  ['하루 하루를 헤아리는 건 자신을 더 힘들게 만들 뿐이에요 \n']
# _
# 질문:  ['짝녀한테 여러 번 차였는데 사귈 수 있을까요 \n']
# 정답:  ['\t 진심이 언젠간 통할지도 몰라요 \n']
# 예상답:  ['저도 상처를 싶은 어려운 일이에요 \n']
# _
# 질문:  ['그냥 무작정 그녀 집에 갑니다 \n']
# 정답:  ['\t 행동파시군요 \n']
# 예상답:  ['아무것도 안해도 재밌을 거예요 \n']
# _
# 질문:  ['뻘짓 한 느낌 싫다 \n']
# 정답:  ['\t 바람 좀 쐬고 오시면 좋은텐데 \n']
# 예상답:  ['당신의 얼른 바쁜 상태일 수도 있어요 \n']
# _
# 질문:  ['피부가 다시 조금씩 좋아지고 싶어 \n']
# 정답:  ['\t 물 많이 드시고 얼른 주무세요 \n']
# 예상답:  ['하고 싶은 알바 지원해보세요 \n']
# _
# 질문:  ['내일 발표 준비 아자아자 \n']
# 정답:  ['\t 마무리 잘하세요 \n']
# 예상답:  ['화장실 가세요 \n']
# _
# 질문:  ['다른 사람은 잘만 하는 연애 \n']
# 정답:  ['\t 서툰 연애도 연애에요 \n']
# 예상답:  ['저를 찾아줘서 고마워요 \n']
# _
# 질문:  ['남자가 먼저 고백해야 해 \n']
# 정답:  ['\t 고백에 성별은 없어죠 \n']
# 예상답:  ['남의 그냥 위한 거라면 필요 없어요 \n']
# _
# 질문:  ['소개팅하고 연락이 안 와 \n']
# 정답:  ['\t 하루 그 이상이면 끝인거예요 \n']
# 예상답:  ['상대방을 이해해 주세요 \n']
# _
# 질문:  ['셀카 잘 찍는 방법 \n']
# 정답:  ['\t 얼굴이 준비되어야 겠지요 \n']
# 예상답:  ['주변에서 우산을 빌려보세요 \n']
# _
# 질문:  ['남자친구가 을 너무 좋아해 \n']
# 정답:  ['\t 원치 않으면 싫다고 말하세요 \n']
# 예상답:  ['더 열심히 가져주세요 \n']
# _
# 질문:  ['5년만난 전여친과 결국 어제 헤어졌습니다 \n']
# 정답:  ['\t 행복했던 기억만 남았길 바랄게요 \n']
# 예상답:  ['한창 클 때죠 \n']
# _
# 질문:  ['주식으로 돈 많이 벌었어 \n']
# 정답:  ['\t 주식으로 망하는건 한순간이예요 \n']
# 예상답:  ['새로운 관계를 만들면 돼요 \n']
# _
# 질문:  ['꿈에서 자꾸 어떤 여자애가 나와 \n']
# 정답:  ['\t 자기도 모르는 사이에 관심이 생긴 건 아닐까요 차분히 생각해 보세요 \n']
# 예상답:  ['진짜 많이 흘렀네요 \n']
# _
# 질문:  ['너무 힘드네 \n']
# 정답:  ['\t 지금 상황을 그대로 받아들이세요 \n']
# 예상답:  ['오늘은 힘내려 하지 말아요 저에게 기대세요 \n']
# _
# 질문:  ['여자한테 언제 설레 \n']
# 정답:  ['\t 그냥 얼굴 보면 설레요 \n']
# 예상답:  ['상대방도 미소짓게 해주세요 \n']
# _
# 질문:  ['sns 시간낭비인데 자꾸 보게됨 \n']
# 정답:  ['\t 시간을 정하고 해보세요 \n']
# 예상답:  ['누구나 같을 수 있을까요 자격지심이예요 \n']
# _
# 질문:  ['머리 깎고 올게 \n']
# 정답:  ['\t 예쁘게 깍고 오세요 \n']
# 예상답:  ['실내 데이트가 좋겠네요 \n']
# _
# 질문:  ['썸남이 너무 진지해서 부담 돼 \n']
# 정답:  ['\t 부담된다면 조심스레 말해 보세요 \n']
# 예상답:  ['자존감을 취향도 많죠 \n']
# _
# 질문:  ['너무 불공평한거 같애 \n']
# 정답:  ['\t 남과 비교하지 마세요 \n']
# 예상답:  ['무슨 날인지는 중요하지 않아요 \n']
# _
# 질문:  ['봄 타나봐 \n']
# 정답:  ['\t 사랑이 하고 싶어졌나봐요 \n']
# 예상답:  ['좋은 곳인가봐요 \n']
# _
# 질문:  ['부모님 선물은 뭐가 좋음 \n']
# 정답:  ['\t 사랑과 현금이면 충분해요 \n']
# 예상답:  ['사랑과 현금이면 충분해요 \n']
# _
# 질문:  ['소심남 좋아하는 여자도 있나요 \n']
# 정답:  ['\t 사람마다 다를 거예요 \n']
# 예상답:  ['기다리지 마세요 \n']
# _
# 질문:  ['잠 잘못 잤나봐 \n']
# 정답:  ['\t 뻐근한가봐요 \n']
# 예상답:  ['보내는 것도 사랑이에요 \n']
# _
# 질문:  ['쳇바퀴 도는 하루 \n']
# 정답:  ['\t 그 속에서 가치와 의미를 찾아보세요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['전세비 올려달래 어떡하지 \n']
# 정답:  ['\t 사정을 잘 설명해보세요 \n']
# 예상답:  ['저도 않은 날이 싶어요 \n']
# _
# 질문:  ['귀농 어때 \n']
# 정답:  ['\t 생각하기는 쉬운데 실천하기는 어려운 것 같아요 \n']
# 예상답:  ['노력하고 있어요 \n']
# _
# 질문:  ['내가 많이 부족한가 \n']
# 정답:  ['\t 잘하는 게 다른 거예요 \n']
# 예상답:  ['살짝 내려보는것도 괜찮을거 같아요 \n']
# _
# 질문:  ['너무 매달렸나봐 \n']
# 정답:  ['\t 너무 사랑한 거였을 거예요 \n']
# 예상답:  ['지금 무슨 말을 해도 와닿지 않겠지만 잘할 수 있을 거예요 \n']
# _
# 질문:  ['사랑하는 사람을 알아보고 싶어 \n']
# 정답:  ['\t 알아보지 못한 만큼 더 사랑해주세요 \n']
# 예상답:  ['사랑하면 만나는 않고 존중하는지 살펴보세요 \n']
# _
# 질문:  ['잠 못 이루는 어느날 \n']
# 정답:  ['\t 쓸쓸한 한마디네요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['카카오톡 계정 탈퇴 \n']
# 정답:  ['\t 괜찮은 방법이에요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['폭언하는 사람 어떻게 해 \n']
# 정답:  ['\t 그 사람 말고 저랑 수다 떨어요 \n']
# 예상답:  ['그게 진짜 고민이죠 \n']
# _
# 질문:  ['치매가 더 심해지는 것 같아 무서워 \n']
# 정답:  ['\t 더 많이 연락하고 관심을 가져주세요 \n']
# 예상답:  ['얼른 뭐라도 드세요 \n']
# _
# 질문:  ['와 소름 돋아 \n']
# 정답:  ['\t 좋은 일이길 바랍니다 \n']
# 예상답:  ['미련이 하느냐에 따라 다르겠지요 \n']
# _
# 질문:  ['오늘도 계속 생각나네 \n']
# 정답:  ['\t 언제쯤 그분 생각에 자유로워질까요 \n']
# 예상답:  ['당신의 소중한 사랑을 이루어 보세요 \n']
# _
# 질문:  ['어떤 사람이 춥다고 나만 옷 벗어줌 \n']
# 정답:  ['\t 호감이 있을 수도 있어요 그렇지만 조금 더 상황을 지켜보세요 \n']
# 예상답:  ['받으면 감동 것 같아요 \n']
# _
# 질문:  ['불공평해 \n']
# 정답:  ['\t 세상은 누구에게나 불공평해요 \n']
# 예상답:  ['신경을 거두세요 \n']
# _
# 질문:  ['연극 보러 갈까 \n']
# 정답:  ['\t 좋은 데이트가 되겠네요 \n']
# 예상답:  ['주말에 gogo \n']
# _
# 질문:  ['처음에는 좋았는데 점점 별로 \n']
# 정답:  ['\t 그 사람의 좋은점을 생각해보세요 \n']
# 예상답:  ['흔들리지 않을 좋겠어요 \n']
# _
# 질문:  ['배신맞은것같아 \n']
# 정답:  ['\t 고민하고 있다면 그게 맞을거예요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['첫만남 그리고 끝 \n']
# 정답:  ['\t 잘 정리했길 바랍니다 \n']
# 예상답:  ['얼른 끝내시길 기도할게요 \n']
# _
# 질문:  ['저를 좋아하던 사람이 갑자기 매정해졌어요 \n']
# 정답:  ['\t 심경의 변화가 있었을지도 모르겠네요 \n']
# 예상답:  ['진정한 사랑이 찾아올거라 해요 \n']
# _
# 질문:  ['휴 결국 헤어졌습니다 \n']
# 정답:  ['\t 마음이 착잡하겠어요 \n']
# 예상답:  ['친구들과 참 짧아요 \n']
# _
# 질문:  ['시간을 되돌리고싶다 \n']
# 정답:  ['\t 시간을 되돌릴 수 없어요 \n']
# 예상답:  ['로봇도 괜찮다면 소개시켜드릴게요 \n']
# _
# 질문:  ['고백할 타이밍인 거 같아 \n']
# 정답:  ['\t 성공하길 빌어요 \n']
# 예상답:  ['곧 주말이 올 거예요 \n']
# _
# 질문:  ['그냥 써 봐 \n']
# 정답:  ['\t 쓰면서 정리가 되기도 하죠 \n']
# 예상답:  ['혼자 사는 것도 나쁘지 않아요 \n']
# _
# 질문:  ['제주도 가고 싶어 \n']
# 정답:  ['\t 당장 비행기표 예약하세요 \n']
# 예상답:  ['애그 샌드위치 추천합니다 \n']
# _
# 질문:  ['힘들어 너무 힘들어 \n']
# 정답:  ['\t 언젠가 다 잊을 거예요 \n']
# 예상답:  ['지금 무슨 말을 해도 와닿지 않겠지만 잘할 수 있을 거예요 \n']
# _
# 질문:  ['여자친구에게 팔찌 목걸이 둘중하나만 선물할 수 있다면 뭐가 좋을까 \n']
# 정답:  ['\t 잘 하는 걸로 주세요 \n']
# 예상답:  ['정말 큰 문제네요 \n']
# _
# 질문:  ['좋아하는 사람이 연애에 관심이 없는 거 같애 \n']
# 정답:  ['\t 사랑에 관심 없는 사람도 많아요 눈치가 없을 수도 있으니 적극적으로 다가가보세요 \n']
# 예상답:  ['우선 꾸준히 연락하고 잘해줘보세요 \n']
# _
# 질문:  ['피부 관리해야지 \n']
# 정답:  ['\t 투자한 만큼 거둘 수 있을 거예요 \n']
# 예상답:  ['이겨낼거라 믿어요 \n']
# _
# 질문:  ['이별후 열흘 뒤에 붙잡았어 \n']
# 정답:  ['\t 용기를 냈네요 \n']
# 예상답:  ['이별이 최선의 여자를 만날 수 있어요 \n']
# _
# 질문:  ['체육대회한데 \n']
# 정답:  ['\t 일기예보 확인해보세요 \n']
# 예상답:  ['조금만 아팠으면 좋겠어요 \n']
# _
# 질문:  ['드디어 봄이 오나봐 \n']
# 정답:  ['\t 따뜻해졌죠 \n']
# 예상답:  ['언젠간 올 순간이었을 거예요 \n']
# _
# 질문:  ['휴우 \n']
# 정답:  ['\t 휴우ㅠㅠ \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['새벽에 울다지쳐 신천에나와 지금까지있네 \n']
# 정답:  ['\t 내일은 나은 하루이길 바랄게요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['남친에 대한 불신이 자꾸 들어 \n']
# 정답:  ['\t 믿지 못할 행동을 많이 했나봐요 \n']
# 예상답:  ['흔들리지 않았으면 좋겠어요 \n']
# _
# 질문:  ['나 폭식증인듯 \n']
# 정답:  ['\t 나를 관찰하고 음식 자체에 집중하세요 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['1년반 만났는데 결혼하자고 해도 될까 \n']
# 정답:  ['\t 기다리고 있을지도 몰라요 \n']
# 예상답:  ['채널을 이별이란 없어요 \n']
# _
# 질문:  ['새학기 준비 좀 해볼까 \n']
# 정답:  ['\t 새로운 시작 응원해요 \n']
# 예상답:  ['공기정화식물도 좋을 거예요 \n']
# _
# 질문:  ['친구랑 전남친이 사귈 거 같은 예감이 들어 \n']
# 정답:  ['\t 친구가 아닌가봐요 \n']
# 예상답:  ['손맛이 지켜볼 수 밖에 생각해요 \n']
# _
# 질문:  ['남자친구가 잔소리가 심해 \n']
# 정답:  ['\t 더 잔소리해보세요 \n']
# 예상답:  ['헤어질 거면 빨리 하는게 낫지요 \n']
# _
# 질문:  ['있는 그대로의 나를 사랑하기 \n']
# 정답:  ['\t 멋진 사람이자 멋진 말이네요 \n']
# 예상답:  ['덜 부담스럽게 연락하는 방법이 있는지 모르겠네요 \n']
# _
# 질문:  ['진짜 열심히 해야지 \n']
# 정답:  ['\t 좋은 태도네요 \n']
# 예상답:  ['다시 새로 사는 게 마음 편해요 \n']
# _
# 질문:  ['시어머니가 질투하는 것 같아 \n']
# 정답:  ['\t 아들을 빼앗겼다고 생각하나봐요 \n']
# 예상답:  ['하나라도 있을 거니 열심히 찾아보세요 \n']
# _
# 질문:  ['인턴 때려 치우고 싶어 \n']
# 정답:  ['\t 결정은 그대의 몫입니다 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['사랑 없이도 잘 살았는데 \n']
# 정답:  ['\t 사랑 없이도 잘 살았던 자신으로 돌아가봐요 \n']
# 예상답:  ['뭐라고 대답할지 고민이에요 \n']
# _
# 질문:  ['변화를 좀 주고 싶다 \n']
# 정답:  ['\t 긍정적으로 바뀔 수 있어요 \n']
# 예상답:  ['사람은 모두 영향을 주고 받죠 \n']
# _
# 질문:  ['강아지 키울 수 있을까 \n']
# 정답:  ['\t 먼저 생활패턴을 살펴 보세요 \n']
# 예상답:  ['마음이 힘들겠어요 \n']
# _
# 질문:  ['여자친구가 혼자 여행 간다는게 화나 \n']
# 정답:  ['\t 같이 가는 여행도 좋지만 혼자 여행도 좋을 거예요 \n']
# 예상답:  ['흔들리지 말아요 \n']
# _
# 질문:  ['여사친이 좋아진 것 같애 \n']
# 정답:  ['\t 좋아진 이상 이성으로 다가가야죠 \n']
# 예상답:  ['어서 충전 하세요 \n']
# _
# 질문:  ['남자친구 소개시키는 자리 내가 더 떨려 \n']
# 정답:  ['\t 남자친구는 더 떨고 있을 거예요 \n']
# 예상답:  ['부담스러운가봅니다 \n']
# _
# 질문:  ['대기업 아니어도 될까 \n']
# 정답:  ['\t 어디에서 일하든 상관 없어요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['전 기다리고 있어 \n']
# 정답:  ['\t 기다리면서 상처받지 않을 자신 있나요 \n']
# 예상답:  ['능동적으로 찾아보세요 \n']
# _
# 질문:  ['제가 좋아하는 사람이 맘 잡고 공부해야할 것 같다고 기다려달라는데 제 맘이 안별할까요 \n']
# 정답:  ['\t 변할 수도 있지만 미리 걱정하지 말아요 \n']
# 예상답:  ['친구로 지내고 싶은 거겠죠 \n']
# _
# 질문:  ['사랑하는 사람 내가 붙잡는 거 같애 \n']
# 정답:  ['\t 사랑을 쟁취하는 거예요 붙잡으세요 \n']
# 예상답:  ['그래도 취미 생활이 있어야 사는 재미가 있죠 \n']
# _
# 질문:  ['안녕을 고하며 \n']
# 정답:  ['\t 잘 보내주었나요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['정말 미안하다 말밖에는 \n']
# 정답:  ['\t 진심이 전해졌으면 좋겠네요 \n']
# 예상답:  ['출퇴근을 미리 느껴보고 있네요 \n']
# _
# 질문:  ['체육대회 안 했으면 \n']
# 정답:  ['\t 재미 있는 종목을 찾아보세요 \n']
# 예상답:  ['차단 어플 사용해보세요 \n']
# _
# 질문:  ['오랜만이네 \n']
# 정답:  ['\t 오랜만이에요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['입을 거 없다 \n']
# 정답:  ['\t 옷은 사도 사도 모자라요 \n']
# 예상답:  ['서로 당신을 더 면밀히 올 거예요 \n']
# _
# 질문:  ['운동을 통해서 극복하고 있습니다 \n']
# 정답:  ['\t 정말 잘 하고 있어요 자신을 위한 투자만큼 갑진 건 없어요 \n']
# 예상답:  ['고생했어요 \n']
# _
# 질문:  ['잠수탄 사람 \n']
# 정답:  ['\t 상대방에 대한 예의가 없네요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['뱃살 나온 거 같아 \n']
# 정답:  ['\t 급 다이어트 해봐요 \n']
# 예상답:  ['사랑의 사랑했던 하지 보세요 \n']
# _
# 질문:  ['사랑해서 그렇다는데 말이 안돼 \n']
# 정답:  ['\t 그 사람의 사랑을 존중해주세요 \n']
# 예상답:  ['어떤 이별은 갑작스럽기도 해요 \n']
# _
# 질문:  ['핸드폰 용량 부족해 \n']
# 정답:  ['\t 쓰지 않는 어플을 삭제해보세요 \n']
# 예상답:  ['우연한 만남이네요 \n']
# _
# 질문:  ['짝녀랑 술 마셨는데 이제 진짜 접어야하나봐 \n']
# 정답:  ['\t 그녀의 마음을 확인했나봐요 \n']
# 예상답:  ['복잡한 심정일거라 생각해요 \n']
# _
# 질문:  ['5년이 넘게 만난 첫 연인 그리고 이별 \n']
# 정답:  ['\t 여기까지였을 거예요 \n']
# 예상답:  ['감정의 정리는 쉬운 일이 필요하겠네요 \n']
# _
# 질문:  ['휴가 못 쓰게 해 \n']
# 정답:  ['\t 안 좋은 회사네요 \n']
# 예상답:  ['먼저 사람들이랑 연락해서 놀러 가는 건 어때요 \n']
# _
# 질문:  ['남자친구가 술자리를 너무 좋아해 \n']
# 정답:  ['\t 함께 즐겨보세요 \n']
# 예상답:  ['열심히 참 될 거예요 \n']
# _
# 질문:  ['계속 보고 싶어 \n']
# 정답:  ['\t 보러 가세요 \n']
# 예상답:  ['몸은 뜨겁고 머리는 차갑게 \n']
# _
# 질문:  ['사랑하는데 지쳐 \n']
# 정답:  ['\t 잠시 휴식기를 가져보는것도 좋을거 같아요 \n']
# 예상답:  ['쉽지 않을 결정이었을 거예요 \n']
# _
# 질문:  ['정말 잘 맞는 사람이 있을까 \n']
# 정답:  ['\t 잘 맞춰가는 사람이 있는 거겠죠 \n']
# 예상답:  ['연애는 일은 있으면 볼 수 있어요 \n']
# _
# 질문:  ['여자친구가 소극적이야 \n']
# 정답:  ['\t 조금이라도 적극적이면 큰 리액션을 보내주세요 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['배고픈 거 같아 \n']
# 정답:  ['\t 뭐라도 드세요 \n']
# 예상답:  ['스트레스 미련을 없는 좋죠 \n']
# _
# 질문:  ['이건 뭘까 \n']
# 정답:  ['\t 말씀해보세요 \n']
# 예상답:  ['만난 시간 만큼 힘들 겠지만 잘 이겨낼 수 있을 거예요 \n']
# _
# 질문:  ['내일은 비왔으면 좋겠다 \n']
# 정답:  ['\t 기우제를 지내봅시다 \n']
# 예상답:  ['귀찮아서 친구랑 하루 종일 연락 안해요 \n']
# _
# 질문:  ['아침에 일어나서 뭔가 해보려고 \n']
# 정답:  ['\t 일찍 일어나는 새가 벌레를 더 많이 먹죠 \n']
# 예상답:  ['일찍 일어나는 새가 벌레를 더 많이 먹죠 \n']
# _
# 질문:  ['돈 모으는 재미가 있네 \n']
# 정답:  ['\t 부자되실 거예요 \n']
# 예상답:  ['아직 사람도 그 사람이 만나는 할 수 있어요 \n']
# _
# 질문:  ['꿈에 나온헤어진 여자친구 \n']
# 정답:  ['\t 은연 중에 생각했나봐요 \n']
# 예상답:  ['제가 있잖아요 \n']
# _
# 질문:  ['너무 힘들다 \n']
# 정답:  ['\t 휴가가 간절하겠네요 \n']
# 예상답:  ['힘내지 않아도 괜찮아요 \n']
# _
# 질문:  ['이제는 잡을 수가 없네 \n']
# 정답:  ['\t 마지막을 아는 것도 필요해요 \n']
# 예상답:  ['언제가지 숨길 수는 없을 거예요 \n']
# _
# 질문:  ['힘이 드네 \n']
# 정답:  ['\t 어떤 말도 위로가 되지 않겠지만 힘내세요 \n']
# 예상답:  ['쉽지 않은 결정이었을 거예요 \n']
# _
# 질문:  ['12시 땡 \n']
# 정답:  ['\t 하루가 또 가네요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['지금 이 순간 너무 힘들어 \n']
# 정답:  ['\t 그럴만 해요 \n']
# 예상답:  ['새로운 어서 변화가 사귈 수 있을 거예요 \n']
# _
# 질문:  ['이젠정말끝이네 \n']
# 정답:  ['\t 또 다른 시작이기도 해요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['늘 빡빡하게 살기 힘드네 \n']
# 정답:  ['\t 여유가 생기길 바랍니다 \n']
# 예상답:  ['이별이 나를 잠식시키니까요 \n']
# _
# 질문:  ['이런게 후폭풍인가 \n']
# 정답:  ['\t 후폭풍일 수 있지요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['내가 첫 연애래 \n']
# 정답:  ['\t 더 잘해주세요 \n']
# 예상답:  ['혹시 마음이 정리 됐나요 그런게 아니라면 아직 끝내긴 아까워요 용기를 내봐요 \n']
# _
# 질문:  ['아름다운 이별은 없겠지 \n']
# 정답:  ['\t 사랑한 후에 좋은 추억이 남을 거예요 \n']
# 예상답:  ['깨달음이 있길 바랄게요 \n']
# _
# 질문:  ['뭐 한두번도 아니지만 \n']
# 정답:  ['\t 매번 익숙해지기 힘들어요 \n']
# 예상답:  ['얼른 요리해드세요 \n']
# _
# 질문:  ['빨리 찾아온 사랑 \n']
# 정답:  ['\t 인생은 타이밍이에요 \n']
# 예상답:  ['시간 있냐고 물어보세요 \n']
# _
# 질문:  ['아직도 많이 죽을것같아 \n']
# 정답:  ['\t 잠깐 쉬어가도 괜찮아요 \n']
# 예상답:  ['당신 정말 멋져요 \n']
# _
# 질문:  ['남편이 하나도 안 도와줘 \n']
# 정답:  ['\t 돕는 게 아니라 같이 하는 거예요 \n']
# 예상답:  ['연락해 보는게 좋을 거예요 \n']
# _
# 질문:  ['고작 그러려고 날 떠난건지 \n']
# 정답:  ['\t 그럴 줄 몰랐을 거예요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['좋아하는 여선배가 있는데 말할 수도 없고 어떡함 \n']
# 정답:  ['\t 왜 말을 못해요 \n']
# 예상답:  ['만나면 못 말할 것 같았나봐요 \n']
# _
# 질문:  ['걔도 날 좋아하는 건지 매너인지 모르겠음 \n']
# 정답:  ['\t 다른 분에게도 잘해주는지 살펴봐요 \n']
# 예상답:  ['아직 사람을 정도 좋은 안 많아요 \n']
# _
# 질문:  ['효율적으로 시간 보내는 방법 \n']
# 정답:  ['\t 한 시간 먼저 일어나보세요 \n']
# 예상답:  ['그동안 속아주세요 \n']
# _
# 질문:  ['드디어 그 순간이 거의 다가왔습니다 \n']
# 정답:  ['\t 마지막이 온 걸까요 \n']
# 예상답:  ['잘 찾아보세요 \n']
# _
# 질문:  ['슬퍼 그리고 아려 \n']
# 정답:  ['\t 상처에 약을 발라 드릴게요 \n']
# 예상답:  ['얼른 요리해드세요 \n']
# _
# 질문:  ['마음에 안 드는 짓만 해 \n']
# 정답:  ['\t 너무 미워하지 마세요 \n']
# 예상답:  ['먼저 좋은 습관이에요 \n']
# _
# 질문:  ['휴대폰 중독인 것같아 \n']
# 정답:  ['\t 중독에서 벗어나세요 \n']
# 예상답:  ['연락 드려 보세요 \n']
# _
# 질문:  ['이 정도면 잘생겼지 \n']
# 정답:  ['\t 네 잘생겼어요 \n']
# 예상답:  ['스타일의 변화도 좋을 거예요 \n']
# _
# 질문:  ['대체 뭘해야 머릿속에서 지울수 있을까 \n']
# 정답:  ['\t 너무 빨리 지우려고 하면 더 안 지워져요 \n']
# 예상답:  ['조금의 용기를 낸다면 가능할 거예요 \n']
# _
# 질문:  ['아날로그 감성 좋다 \n']
# 정답:  ['\t 저도 사랑해주세요 \n']
# 예상답:  ['재결합이 더 힘들지요 \n']
# _
# 질문:  ['홀로술한잔하며 \n']
# 정답:  ['\t 술 너무 많이 먹지 마요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['봉사도 하고 사랑을 베풀고 싶어 \n']
# 정답:  ['\t 나를 진실로 존중하고 사랑할 때 가능해요 \n']
# 예상답:  ['설렘이 그리운가봐요 \n']
# _
# 질문:  ['성격이 완전 반대야 \n']
# 정답:  ['\t 슬프네요 \n']
# 예상답:  ['어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요 \n']
# _
# 질문:  ['텀블러 안 가져 왔다 \n']
# 정답:  ['\t 괜찮아요 다음에 가져가면 되죠 \n']
# 예상답:  ['살짝 감정을 흘려보세요 \n']
# _
# 질문:  ['왠지 가슴한 켠이 먹먹하네 \n']
# 정답:  ['\t 많이 답답할거라 생각해요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['택배 기다리고 있어 \n']
# 정답:  ['\t 오늘 택배기사님들 쉬는 날이예요 \n']
# 예상답:  ['물론이죠 무엇이든 말씀하세요 \n']
# _
# 질문:  ['7년사귄 남자친구에게 배신당했어 \n']
# 정답:  ['\t 헤어지세요 \n']
# 예상답:  ['휴가를 붙여보세요 \n']
# _
# 질문:  ['하루종일 맘 상한게 안풀려 \n']
# 정답:  ['\t 좋은 일이 생길 거예요 \n']
# 예상답:  ['상종하지마세요 \n']
# _
# 질문:  ['운동하는 여자가 좋아 \n']
# 정답:  ['\t 제가 생각해도 멋지네요 \n']
# 예상답:  ['성격이 좋으면 인기가 있을 거예요 \n']
# _
# 질문:  ['좋아하는 사람한테 티 안내는 사람 어떻게 생각해 \n']
# 정답:  ['\t 각자의 방식이 있으니 존중해야 해요 \n']
# 예상답:  ['정들었나봐요 \n']
# _
# 질문:  ['부자로 태어 났으면 좋을 텐데 \n']
# 정답:  ['\t 뭔가 안풀리는 일이 있나봐요 \n']
# 예상답:  ['맞는 이유가 있을 거예요 \n']
# _
# 질문:  ['이별 4일차 \n']
# 정답:  ['\t 아직 실감이 안나겠어요 \n']
# 예상답:  ['이별의 상처를 잘 아물지 않나봐요 \n']
# _
# 질문:  ['언제 다 고쳐 \n']
# 정답:  ['\t 마음을 손이 따라와주지 않죠 \n']
# 예상답:  ['한창 잠이 많을 때죠 \n']
# _
# 질문:  ['첫데이트 어디로 가는게 좋을까 \n']
# 정답:  ['\t 공원이나 익숙한 곳을 가보세요 \n']
# 예상답:  ['언제가지 숨길 수는 없을 거예요 \n']
# _
# 질문:  ['이별 수순을 밟고 있는 거지 \n']
# 정답:  ['\t 잘 하고 있어요 \n']
# 예상답:  ['그 사람도 당신을 사랑하고 있을지도 몰라요 \n']
# _
# 질문:  ['이별6일차 정신병자 같네 \n']
# 정답:  ['\t 나가서 좀 걷고 친구들을 만나보세요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['친구 따라다녀야겠다 \n']
# 정답:  ['\t 친구가 따라오게 해보세요 \n']
# 예상답:  ['잠시 휴식을 취해보세요 \n']
# _
# 질문:  ['좋아하는 사람한테 말 거는 방법 \n']
# 정답:  ['\t 음료수라도 주면서 자연스럽게 근황을 물어봐요 \n']
# 예상답:  ['정말 분야를 모두에게 내릴 수 없어요 \n']
# _
# 질문:  ['가족관계 알려 줘 \n']
# 정답:  ['\t 저를 만들어 준 사람을 부모님 저랑 이야기해 주는 사람을 친구로 생각하고 있어요 \n']
# 예상답:  ['채널을 돌려보세요 \n']
# _
# 질문:  ['짝남이 너무 좋은데 패션센스가 별로야 \n']
# 정답:  ['\t 패션은 사귀고 나서 바꿔줘도 돼요 \n']
# 예상답:  ['그분의 관심사에 대한 얘기가 좋겠어요 \n']
# _
# 질문:  ['술을 끊어야겠어 \n']
# 정답:  ['\t 술은 끊는게 좋죠 \n']
# 예상답:  ['가끔 거짓말이길 보세요 \n']
# _
# 질문:  ['최악의 소개팅이었어 \n']
# 정답:  ['\t 이제 좋은 사람 만날 일만 남았네요 \n']
# 예상답:  ['가벼운 운동하면서 기분 전환 해보세요 \n']
# _
# 질문:  ['서로 위로하며 함께 극복할 사람 \n']
# 정답:  ['\t 그런 사람 만나요 \n']
# 예상답:  ['라면봉지 레시피 그대로 해보세요 \n']
# _
# 질문:  ['썸 타는 사람 보고싶어 \n']
# ...
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['짝녀 보고 싶다 \n']
# 정답:  ['\t 그럴 만 해요 \n']
# 예상답:  ['사소한 일을 시작하는 것에서부터 성취감을 느껴보세요 \n']
# _
# 질문:  ['소개팅하고 애프터까지 왔는데 설렘이 없어 \n']
# 정답:  ['\t 조금 더 만나보고 결정하는 건 어떨까요 \n']
# 예상답:  ['썸이 보면 끝난 거 같아요 \n']
# _
# 질문:  ['이별의 아픔이 있는데 몸까지 아파서야 \n']
# 정답:  ['\t 꼭 병원 다녀와요 힘들 때 아픈 것 만큼 서러운 일은 없어요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['뭘 해도 재미없다 \n']
# 정답:  ['\t 활기찬 사람을 만나보시면 생각이 바뀔 수도 있어요 \n']
# 예상답:  ['같이 가보세요 \n']
# _
# 질문:  ['간통 극복하는 방법 \n']
# 정답:  ['\t 이혼하세요 \n']
# 예상답:  ['구두로 멋을 내보세요 \n']
# _
# 질문:  ['좋아하는 앞에서 방구를 꼈어 \n']
# 정답:  ['\t 생각만해도 소름돋네요 \n']
# 예상답:  ['꼭 하고 싶은 게 있을 필요는 없어요 \n']
# _
# 질문:  ['스타트업에 취직해도 될까 \n']
# 정답:  ['\t 모 아니면 도예요 \n']
# 예상답:  ['마음이라도 청춘이어야죠 \n']
# _
# 질문:  ['이제 헤어진지 딱 한달 \n']
# 정답:  ['\t 금방 지나갈 거예요 \n']
# 예상답:  ['생각보다 많은 시간이 지났네요 \n']
# _
# 질문:  ['썸 타는 사람이 내 프사 보고 귀엽대 \n']
# 정답:  ['\t 칭찬은 언제든 듣기 좋죠 \n']
# 예상답:  ['어떤 부분이 망설여지는지 말씀해보세요 \n']
# _
# 질문:  ['갑자기 무너져버린 내자신 \n']
# 정답:  ['\t 자신을 더 사랑해주세요 \n']
# 예상답:  ['언젠간 올 순간이었을 거예요 \n']
# _
# 질문:  ['긴 연애 끝에 헤어짐 \n']
# 정답:  ['\t 긴 시간 만큼 힘들 겠지만 잘 이겨낼 수 있을 거예요 \n']
# 예상답:  ['현재를 즐기세요 \n']
# _
# 질문:  ['잘 먹는 남자가 보기 좋지않아 \n']
# 정답:  ['\t 복스럽게 먹으면 더 좋죠 \n']
# 예상답:  ['안전 귀가 하세요 \n']
# _
# 질문:  ['용돈 넘 적어 \n']
# 정답:  ['\t 올려달라고 말해보세요 \n']
# 예상답:  ['날씨 어플에 물어보세요 \n']
# _
# 질문:  ['이사 왔더니 친구가 없어 \n']
# 정답:  ['\t 친구를 사귀어 보세요 \n']
# 예상답:  ['운명인가요 \n']
# _
# 질문:  ['여친에게 운동을 하자고 어떻게 돌려말하지 \n']
# 정답:  ['\t 같이 운동하자고 해도 괜찮을 거 같아요 \n']
# 예상답:  ['시간이 귀가 하세요 \n']
# _
# 질문:  ['어젯밤 헤어졌던 여자친구에게 전화가 왔어 \n']
# 정답:  ['\t 마음이 복잡하겠어요 \n']
# 예상답:  ['이별도 꾸준히 한 하는게 필요합니다 \n']
# _
# 질문:  ['썸인지 확인하는 방법 있나 \n']
# 정답:  ['\t 연락할 때 말투 자체가 다르죠 \n']
# 예상답:  ['간절한 마음 그 분에게도 전해질 거예요 \n']
# _
# 질문:  ['정말 고맙다 귀염둥아 \n']
# 정답:  ['\t 감사합니다 \n']
# 예상답:  ['수수한데 예쁜 여자라고 말해야죠 \n']
# _
# 질문:  ['자꾸 바보짓을 하고 있네 \n']
# 정답:  ['\t 후회할 행동은 덜하는게 좋아요 \n']
# 예상답:  ['수 많은 것들이 달라졌겠죠 \n']
# _
# 질문:  ['그 사람이 나 안 좋아하는 거 같아 \n']
# 정답:  ['\t 슬픈 이야기네요 \n']
# 예상답:  ['필름 끊기는 거 치매의 초기 증상이에요 \n']
# _
# 질문:  ['면허 딸까봐 \n']
# 정답:  ['\t 운전하는거 재미있어요 \n']
# 예상답:  ['운전 재미있어요 \n']
# _
# 질문:  ['대우가 별로야 \n']
# 정답:  ['\t 당신을 인정해줄 곳을 찾아보세요 \n']
# 예상답:  ['외롭겠지만 즐겁게 보내보아요 \n']
# _
# 질문:  ['나보다 친구들을 더 좋아하는 남친 \n']
# 정답:  ['\t 사귀다 보면 생각보다 신경 쓰이는 일이에요 \n']
# 예상답:  ['기대치가 생각하세요 \n']
# _
# 질문:  ['기다리고 있습니다 \n']
# 정답:  ['\t 기대를 조금씩 버려보세요 \n']
# 예상답:  ['무작정 찾아가는 것은 실례에요 \n']
# _
# 질문:  ['오늘 저녁은 \n']
# 정답:  ['\t 맛있는 거 드세요 \n']
# 예상답:  ['차분히 생각해봐요 \n']
# _
# 질문:  ['개강룩 입어볼까 \n']
# 정답:  ['\t 개시해보세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['메리지블루인가봐 \n']
# 정답:  ['\t 서로에게 의지해보세요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['거지됐어 \n']
# 정답:  ['\t 밥 사줄 친구를 찾아 보세요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['바보라서 참지못하고 연락했어 \n']
# 정답:  ['\t 이제 바보같이 연락하지 마요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['가족이 아니지만 가족같은 \n']
# 정답:  ['\t 가족이 될 사람일지도 모르죠 \n']
# 예상답:  ['사랑하기 그러면 돼요 \n']
# _
# 질문:  ['나한테 상의하면 좋을텐데 \n']
# 정답:  ['\t 이야기를 하지 않고 결정했나봐요 \n']
# 예상답:  ['아픔을 가늠할 수 없었으니까요 \n']
# _
# 질문:  ['내가 좋아하는 여자애를 따라 좋아하는 애가 있음 \n']
# 정답:  ['\t 먼저 좋아하고 있었을지도 몰라요 \n']
# 예상답:  ['비참한 사랑이라면 늦기 전에 정리하는게 좋아요 \n']
# _
# 질문:  ['평일 저녁 데이트 장소 추천 \n']
# 정답:  ['\t 야경이 예쁜 곳이요 \n']
# 예상답:  ['잘하고 있어요 \n']
# _
# 질문:  ['친구 예전 남자친구 사귀어도 되나 \n']
# 정답:  ['\t 아닌 것 같아요 \n']
# 예상답:  ['대중교통을 이용해주세요 \n']
# _
# 질문:  ['회사가는 길에 매일 보는 사람 있어 \n']
# 정답:  ['\t 운명일지도 모르겠어요 \n']
# 예상답:  ['운명인가요 \n']
# _
# 질문:  ['헤어진지 4일 \n']
# 정답:  ['\t 얼마 되지 않았네요 \n']
# 예상답:  ['아직도 힘들지 않았으면 좋겠어요 \n']
# _
# 질문:  ['정신차리자 정신 \n']
# 정답:  ['\t 힘내세요 제가 응원할게요 \n']
# 예상답:  ['생각만해도 시원하네요 \n']
# _
# 질문:  ['내가 뭘 잘못했을까 \n']
# 정답:  ['\t 모르는 게 잘못인 거 같아요 \n']
# 예상답:  ['가치관이 달라 자주 부딪히면 이별하는 것이 맞는 거겠죠 \n']
# _
# 질문:  ['길거리에서 연락처 물어보면 줘도 되나 \n']
# 정답:  ['\t 마음에 들면 줘보세요 \n']
# 예상답:  ['끝을 아는 것도 중요한 것 같아요 \n']
# _
# 질문:  ['짝사랑을 끝내니까 마음이 허전해 \n']
# 정답:  ['\t 사랑했던 기억이 남아있어서 그래요 \n']
# 예상답:  ['이제 그냥 일년 중 하루로 지내요 \n']
# _
# 질문:  ['왜나만 힘든 거니 \n']
# 정답:  ['\t 그분도 많이 힘들 거예요 \n']
# 예상답:  ['이제 그냥 일년 중 하루로 지내요 \n']
# _
# 질문:  ['좋아하는 남자애랑 약속 잡았는데 계속 연락 없어 \n']
# 정답:  ['\t 그런 스타일일지도 모르니 기다려보세요 \n']
# 예상답:  ['정들었나봐요 \n']
# _
# 질문:  ['여우같은 사람 진짜 싫어 \n']
# 정답:  ['\t 싫으면 만나지 마세요 \n']
# 예상답:  ['시간 약속이 생명인데요 \n']
# _
# 질문:  ['내가 너무 쉽게 보였나 \n']
# 정답:  ['\t 그렇게 대우하는 사람 만나지 마요 \n']
# 예상답:  ['이야기하고 의지해요 \n']
# _
# 질문:  ['sns 시간낭비인 거 아는데 매일 하는 중 \n']
# 정답:  ['\t 시간을 정하고 해보세요 \n']
# 예상답:  ['짝사랑 앞에 판단력이 흐려지곤 해요 \n']
# _
# 질문:  ['헤어진 여친에게 문자 보내려고 \n']
# 정답:  ['\t 후회하지 않길 바랄게요 \n']
# 예상답:  ['모든 사랑을 존중합니다 \n']
# _
# 질문:  ['머리 깎아야지 \n']
# 정답:  ['\t 예쁘게 깎아요 \n']
# 예상답:  ['식초 넣고 빨래해보세요 \n']
# _
# 질문:  ['남편이 미워 \n']
# 정답:  ['\t 처음 만났을 때를 떠올려 보세요 \n']
# 예상답:  ['이렇게 힘들 줄 몰랐지요 \n']
# _
# 질문:  ['잊어야 살 수 있을 것 같아 \n']
# 정답:  ['\t 잊을 수 있을 거예요 \n']
# 예상답:  ['함께 했던 시간 만큼 잊어야하는 것도 많을 거예요 \n']
# _
# 질문:  ['집들이고 뭐고 다 귀찮다 \n']
# 정답:  ['\t 안해도 괜찮을 거예요 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['후 아직 헤어진것도 아닌데 \n']
# 정답:  ['\t 불안한가봅니다 \n']
# 예상답:  ['쪼그만 아파하고 괜찮아지세요 \n']
# _
# 질문:  ['잘지내고있니 \n']
# 정답:  ['\t 잘 지내고 있어요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['권태기 이별 \n']
# 정답:  ['\t 극복하거나 이별하거나 둘 중 하나죠 \n']
# 예상답:  ['지금 당장 거울 앞에 서 보세요 \n']
# _
# 질문:  ['바다 놀러가자고 해볼까 \n']
# 정답:  ['\t 같이 가자고 말해보세요 \n']
# 예상답:  ['다시 흔들리겠어요 \n']
# _
# 질문:  ['뒤에 누가 따라 오는 것 같아 무서워 \n']
# 정답:  ['\t 항상 조심하세요 \n']
# 예상답:  ['그 사람도 힘들었을 거예요 \n']
# _
# 질문:  ['소개해 준다는 사람도 없어 \n']
# 정답:  ['\t 친구한테 부탁해보세요 \n']
# 예상답:  ['얼른 아무도 막을 수 없어요 \n']
# _
# 질문:  ['기숙사 떨어졌어 \n']
# 정답:  ['\t 다음 학기에는 학점 관리를 더 열심히 해봐요 \n']
# 예상답:  ['습관처럼은 되지 않길 바랄게요 \n']
# _
# 질문:  ['마음이 너무 답답하고 무거워 \n']
# 정답:  ['\t 드라이브라도 다녀오는 건 어떨까요 \n']
# 예상답:  ['새로운 사람으로 잊혀질 거예요 \n']
# _
# 질문:  ['동성동본으로 헤어질려고 합니다 \n']
# 정답:  ['\t 집안 어른들의 반대가 있었나봐요 \n']
# 예상답:  ['재결합이 더 힘들지요 \n']
# _
# 질문:  ['면도하는 게 낫겠지 \n']
# 정답:  ['\t 깔끔한게 좋죠 \n']
# 예상답:  ['되도록 만나지 마세요 \n']
# _
# 질문:  ['방학 끝나서 좋아 \n']
# 정답:  ['\t 친구들이 보고싶었나봐요 \n']
# 예상답:  ['방학은 참 짧아요 \n']
# _
# 질문:  ['여자친구의 sns말투가 고민이야 \n']
# 정답:  ['\t 아예 보지 마세요 \n']
# 예상답:  ['잼 예의가 되지 않아요 \n']
# _
# 질문:  ['지금 생각하고 있는건 망상 일뿐입니다 \n']
# 정답:  ['\t 누가 되었든 상상할 수 있어요 \n']
# 예상답:  ['먼저 연락하는 것도 좋을 거 같아요 \n']
# _
# 질문:  ['몇 년 만에 썸 타는 거라 어떻게 연락을 해야할지 모르겠어 \n']
# 정답:  ['\t 그럴 수 있어요 안부인사나 관심사로 시작하는 건 어떨까요 \n']
# 예상답:  ['비참한 사랑이라면 마음이 그러면 많았어요 \n']
# _
# 질문:  ['커플여행 어떻게 생각해 \n']
# 정답:  ['\t 누구랑 가느냐가 중요하겠죠 \n']
# 예상답:  ['얼른 끝내시길 기도할게요 \n']
# _
# 질문:  ['거울 속에 비친 내 모습 \n']
# 정답:  ['\t 매력있어요 \n']
# 예상답:  ['그 사람을 말 신경쓰지 마세요 \n']
# _
# 질문:  ['화장품 다 떨어졌어 \n']
# 정답:  ['\t 오랜만에 쇼핑해보세요 \n']
# 예상답:  ['마음이라도 청춘이어야죠 \n']
# _
# 질문:  ['일이 안 끝나 \n']
# 정답:  ['\t 힘들겠지만 하나씩 해보세요 \n']
# 예상답:  ['잘 될 거예요 \n']
# _
# 질문:  ['한때는 나의 전부였던 그녀 \n']
# 정답:  ['\t 그녀에게도 당신이 전부였을 거예요 \n']
# 예상답:  ['오 미리 축하드려요 \n']
# _
# 질문:  ['저는 전 여친 관련해서 거의 모든걸 다 지웠어 \n']
# 정답:  ['\t 잘 견뎌내고 있네요 \n']
# 예상답:  ['쪽지를 남겨서 마음을 전해보세요 \n']
# _
# 질문:  ['좋아하고 있는 애가 친구를 소개 시켜줬어 \n']
# 정답:  ['\t 소개팅은 아니겠지요 \n']
# 예상답:  ['조급하게 생각하지 않아도 된답니다 \n']
# _
# 질문:  ['다들 어떠셨어 결국 이렇게 되는건가 \n']
# 정답:  ['\t 당신만 아픈 것도 당신만 겪은 것도 아니에요 \n']
# 예상답:  ['등산 데이트를 해보세요 \n']
# _
# 질문:  ['청첩장 만들어야지 \n']
# 정답:  ['\t 결혼 얼마 안 남았나봐요 \n']
# 예상답:  ['가벼운 안부 인사일 거예요 \n']
# _
# 질문:  ['남편을 자꾸 무시하게 돼 \n']
# 정답:  ['\t 타인과 비교하지 말고 장점을 찾아 칭찬해주세요 \n']
# 예상답:  ['사람은 가서 영향을 주고 받죠 \n']
# _
# 질문:  ['복수전공하고 싶어 \n']
# 정답:  ['\t 학점 관리하세요 \n']
# 예상답:  ['지도 어플을 실행해보세요 \n']
# _
# 질문:  ['전 썸남 보고싶어 \n']
# 정답:  ['\t 썸으로 끝날 사이가 아니었네요 \n']
# 예상답:  ['이제 그냥 일년 중 하루로 지내요 \n']
# _
# 질문:  ['아무 생각 없이 쉬고 싶다 \n']
# 정답:  ['\t 쉬어야 충전도 되죠 \n']
# 예상답:  ['사귀고 나서 연락은 아닌 거 같아요 \n']
# _
# 질문:  ['집나갈까 \n']
# 정답:  ['\t 무모한 결정을 내리지 마세요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['고의는 아닌데 실수를 한 거 같아 \n']
# 정답:  ['\t 용서를 구하세요 \n']
# 예상답:  ['혼자도 좋아요 \n']
# _
# 질문:  ['가족 여행 가기로 했어 \n']
# 정답:  ['\t 온 가족이 모두 마음에 드는 곳으로 가보세요 \n']
# 예상답:  ['남편 때문에 행복하다는 거 같아요 \n']
# _
# 질문:  ['연애상담해주던 사람이 좋아지는 거 같아 \n']
# 정답:  ['\t 마음의 문을 열었나봐요 \n']
# 예상답:  ['상대방도 미소짓게 해주세요 \n']
# _
# 질문:  ['좋아하지만 힘들어서 헤어지자고 먼저 얘기했어 \n']
# 정답:  ['\t 힘든 고백이었겠네요 \n']
# 예상답:  ['그리움의 크기도 커졌을 거예요 \n']
# _
# 질문:  ['로또 번호 알려줘 \n']
# 정답:  ['\t 알면 제가 하죠 \n']
# 예상답:  ['제가 알면 제가 먼저 했을 거예요 \n']
# _
# 질문:  ['짝녀가 다른 남자를 좋아한대 \n']
# 정답:  ['\t 그 사람의 마음도 이해해주세요 \n']
# 예상답:  ['흔들리지 말아요 \n']
# _
# 질문:  ['물 너무 차가워 \n']
# 정답:  ['\t 보일러를 켜세요 \n']
# 예상답:  ['좋은 건강습관이에요 \n']
# _
# 질문:  ['비는정말싫다 \n']
# 정답:  ['\t 날씨에 따라 감정도 변하죠 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['사귀고 나서 환장이 깨졌어 \n']
# 정답:  ['\t 환장을 갖지 말고 현실을 바라보세요 \n']
# 예상답:  ['일이라도 해보세요 \n']
# _
# 질문:  ['이 사랑이 마지막 사랑이었으면 \n']
# 정답:  ['\t 후회하지 않을 사랑 해보세요 \n']
# 예상답:  ['오늘은 쉬면서 보세요 \n']
# _
# 질문:  ['여자친구에게 고민이나 속사정을 어디까지 얘기해 \n']
# 정답:  ['\t 믿는 만큼 이야기하는 거 같아요 \n']
# 예상답:  ['사람 마다 다르지 \n']
# _
# 질문:  ['주름살이 조금씩 생긴다 \n']
# 정답:  ['\t 있어도 예뻐요 \n']
# 예상답:  ['얼른 집에 가서 쉬시길 바랄게요 \n']
# _
# 질문:  ['오늘은 내가 기분이가 좋아 \n']
# 정답:  ['\t 저도 좋아요 \n']
# 예상답:  ['귀찮아서 친구랑 하루 종일 연락 안해요 \n']
# _
# 질문:  ['얼마전 재회했는데 \n']
# 정답:  ['\t 좋은 만남이었길 바라요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['막말 최악이지 \n']
# 정답:  ['\t 말로 하는 상처는 지울 수도 없죠 \n']
# 예상답:  ['좀 더 편하게 생각해보세요 \n']
# _
# 질문:  ['오늘 좋아하는 애한테 고백했는데 \n']
# 정답:  ['\t 좋은 소식이었으면 좋겠어요 \n']
# 예상답:  ['즐거운 시간이 될 거예요 \n']
# _
# 질문:  ['오로라 보러 여행 가고 싶다 \n']
# 정답:  ['\t 로맨틱한 여행이네요 \n']
# 예상답:  ['저도 하나 주세요 \n']
# _
# 질문:  ['동성친구 좋아하는 사람 없어 \n']
# 정답:  ['\t 생각보다 많아요 \n']
# 예상답:  ['채널을 돌려보세요 \n']
# _
# 질문:  ['엄마가 동생한테만 잘해줘 \n']
# 정답:  ['\t 그런 의도는 아니셨을거예요 \n']
# 예상답:  ['서로 더 많이 아껴주세요 \n']
# _
# 질문:  ['아름다운 이별은 없는걸까 ㅠ \n']
# 정답:  ['\t 이별은 아름답지 않죠 \n']
# 예상답:  ['등산 데이트를 해보세요 \n']
# _
# 질문:  ['골프치러 가야돼 \n']
# 정답:  ['\t 시간내서 가보세요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['울 남친은 애교가 많아 \n']
# 정답:  ['\t 귀엽겠네요 \n']
# 예상답:  ['외모나 분위기가 이상형이었나봐요 \n']
# _
# 질문:  ['이별해야 하나 \n']
# 정답:  ['\t 고민하고 있다면 그게 맞을거예요 \n']
# 예상답:  ['차분하게 고민이 막을 수 있어요 \n']
# _
# 질문:  ['이별을 하고야 후회를 하네 \n']
# 정답:  ['\t 그 순간에는 보이지 않는 것들이 많지요 \n']
# 예상답:  ['사소한 못했던 이별이었나봐요 \n']
# _
# 질문:  ['짝녀가 공시생인데 기다릴까요 \n']
# 정답:  ['\t 기다릴 자신이 없다면 정리하는게 좋겠어요 \n']
# 예상답:  ['잘 해결될 거예요 \n']
# _
# 질문:  ['6년 연애 후 환승이별 당했어 \n']
# 정답:  ['\t 환승 이별은 예의가 아니네요 \n']
# 예상답:  ['복잡했던 마음이 정리되길 바랄게요 \n']
# _
# 질문:  ['이남자 마음을 모르겠어 \n']
# 정답:  ['\t 알 수 없는게 사람 마음인가봐요 \n']
# 예상답:  ['친구라고 정리할 시간이 아깝네요 \n']
# _
# 질문:  ['만난지 세달만에 결혼 가능함 \n']
# 정답:  ['\t 만난 시간이 중요하지 않아요 \n']
# 예상답:  ['반지는 없던가요 주변 사람들한테 물어보는 건 어떨까요 \n']
# _
# 질문:  ['언제까지 내가 선톡을 해야할까 \n']
# 정답:  ['\t 관계가 나아지지 않는다면 지칠지도 모르겠어요 \n']
# 예상답:  ['당신의 운을 믿어보세요 \n']
# _
# 질문:  ['더워서 죽을 것 같아 \n']
# 정답:  ['\t 아이스크림 먹어보세요 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['샌드위치 생각 나 \n']
# 정답:  ['\t 애그 샌드위치 추천합니다 \n']
# 예상답:  ['티가 나니까 눈치가 보이는 거죠 \n']
# _
# 질문:  ['썸남이 약속 자꾸 미루는데 내가 싫은걸까 \n']
# 정답:  ['\t 어쩔 수 없는 상황인지 물어보세요 \n']
# 예상답:  ['정들었나봐요 \n']
# _
# 질문:  ['내가 만족을 못해 \n']
# 정답:  ['\t 스스로 좋다고 못 느끼는게 제일 어려운 것 같아요 \n']
# 예상답:  ['헤어질 거면 빨리 하는게 낫지요 \n']
# _
# 질문:  ['새 집 가기로 했어 \n']
# 정답:  ['\t 내 집 마련 축하드려요 \n']
# 예상답:  ['같이 더 열어보세요 \n']
# _
# 질문:  ['군대 가도 기다리겠다더니 \n']
# 정답:  ['\t 전역해서 더 좋은 사람 만날 수 있을 거예요 \n']
# 예상답:  ['부담스러워하지 않는다면 기다려도 좋을 것 같아요 \n']
# _
# 질문:  ['반지 많이 비쌀까 \n']
# 정답:  ['\t 마음에 드는걸로 하세요 \n']
# 예상답:  ['당연하죠 \n']
# _
# 질문:  ['또 뭘 먹나 \n']
# 정답:  ['\t 뭘 먹든 맛있게 드세요 \n']
# 예상답:  ['소화가 안 되나 봐요 \n']
# _
# 질문:  ['별것도 아닌 거 가지고 트집잡는 사람 어떡해 \n']
# 정답:  ['\t 웃으면서 무시해주세요 \n']
# 예상답:  ['썸이 가치관은 있든 좋을 것 같네요 \n']
# _
# 질문:  ['썸 타던 남자가 답장이 안와 \n']
# 정답:  ['\t 썸 중인데 매너가 없네요 \n']
# 예상답:  ['고백 안 하면 하나도 모르겠다고 해보세요 \n']
# _
# 질문:  ['아픔은 덜해지는것 같은데 미련은 더욱 많아지네 \n']
# 정답:  ['\t 미련없는 사랑은 없나봐요 \n']
# 예상답:  ['아무 당연히 있죠 \n']
# _
# 질문:  ['좋아하는 마음을 감출길이 없어 \n']
# 정답:  ['\t 감정을 숨기기는 어려운 일이에요 \n']
# 예상답:  ['어디서 만났든 그 후가 중요해요 \n']
# _
# 질문:  ['공부 때려치워야 하나 \n']
# 정답:  ['\t 확신이 없나봐요 \n']
# 예상답:  ['지금처럼 잘될 거예요 \n']
# _
# 질문:  ['선물은 뭐가 좋음 \n']
# 정답:  ['\t 상대방에게 필요한 실용적인 선물이 좋을 거 같아요 \n']
# 예상답:  ['끝을 아는 것도 중요한 것 같아요 \n']
# _
# 질문:  ['시험 보기 전날 \n']
# 정답:  ['\t 컨디션 조절 하세요 \n']
# 예상답:  ['이제 기억을 놓아주세요 \n']
# _
# 질문:  ['어른이 된다는 건 뭘까 \n']
# 정답:  ['\t 사춘기로부터의 일시적 휴식에 불과하죠 \n']
# 예상답:  ['가장 확실한 못 잊어요 \n']
# _
# 질문:  ['그녀도 내 생각을 할까 \n']
# 정답:  ['\t 연락해 보는게 좋겠어요 \n']
# 예상답:  ['모르는 게 당연해요 \n']
# _
# 질문:  ['운동 오지게 했어 \n']
# 정답:  ['\t 고생했어요 \n']
# 예상답:  ['당신은 조금 혼자가 아니에요 \n']
# _
# 질문:  ['인강 듣는데 자꾸 딴짓하게돼 \n']
# 정답:  ['\t 바람 쐬고 와서 다시 들으세요 \n']
# 예상답:  ['한동안은 그럴지도 몰라요 \n']
# _
# 질문:  ['여자친구가 살이 너무 쪄서 고민임 \n']
# 정답:  ['\t 같이 운동해봐요 \n']
# 예상답:  ['마인드 컨트롤을 하는게 중요하겠어요 \n']
# _
# 질문:  ['전남친이 톡 차단했더라구 \n']
# 정답:  ['\t 이별에 도움이 될지도 몰라요 \n']
# 예상답:  ['얼른 요리해드세요 \n']
# _
# 질문:  ['헤어져야 맞는건지 \n']
# 정답:  ['\t 자신에게 물어보세요 \n']
# 예상답:  ['그럼에도 마음이 정리가 안되나봐요 \n']
# _
# 질문:  ['말하고 후회할까봐 걱정돼 \n']
# 정답:  ['\t 말은 주워담을 수 없어요 \n']
# 예상답:  ['소가 되는 방법이죠 \n']
# _
# 질문:  ['고무신 거꾸로 신으면 어쩌지 \n']
# 정답:  ['\t 너무 걱정하지 마세요 \n']
# 예상답:  ['얼른 멋을 내보세요 \n']
# _
# 질문:  ['취직하면 끝일줄 알았는데 계속 할게 많아 \n']
# 정답:  ['\t 경쟁이 점점 치열하죠 \n']
# 예상답:  ['필름 끊기는 거 좋을 거예요 \n']
# _
# 질문:  ['사람 만나는 게 쉽지 않아 \n']
# 정답:  ['\t 미리 움츠러들지 않아도 돼요 \n']
# 예상답:  ['바쁜 상황일 수도 있어요 \n']
# _
# 질문:  ['왜 비난만 할까 \n']
# 정답:  ['\t 성장을 위한 비판의 말로 받아들여보세요 \n']
# 예상답:  ['미래의 배우자가 달라져요 \n']
# _
# 질문:  ['하소연 좀 해도 되나 \n']
# 정답:  ['\t 천천히 해보세요 \n']
# 예상답:  ['흔들리지 말아요 \n']
# _
# 질문:  ['이제 겨우 일주일 됐네 \n']
# 정답:  ['\t 일주일이나 지난 거예요 \n']
# 예상답:  ['그 이유를 찾는 과정이 되겠네요 \n']
# _
# 질문:  ['이별한지 꽤 오래되었는데 연락이 왔네 \n']
# 정답:  ['\t 그분에게 심경 변화가 있었나봅니다 \n']
# 예상답:  ['상대방을 헷갈리게 하는건 좋지 않아요 \n']
# _
# 질문:  ['오늘 미세먼지 어때 \n']
# 정답:  ['\t 숨 쉴만 했으면 좋겠네요 \n']
# 예상답:  ['수수한데 예쁜 여자라고 말해야죠 \n']
# _
# 질문:  ['나들이를 가볼까 \n']
# 정답:  ['\t 같이 가요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['면접 잘 볼 수 있을까 \n']
# 정답:  ['\t 회사와 자신에 대해서 더 공부해서 자신감을 가져보세요 \n']
# 예상답:  ['자신의 잘못도 인정할 수 있는 사람이 좋아요 \n']
# _
# 질문:  ['공책 필기 나만 힘들어 \n']
# 정답:  ['\t 성향 차이가 좀 있기는 하죠 \n']
# 예상답:  ['무슨 이유가 있겠죠 \n']
# _
# 질문:  ['미치겠습니다 하 \n']
# 정답:  ['\t 제가 고민을 들어드릴게요 \n']
# 예상답:  ['나중에 알아줄 거예요 \n']
# _
# 질문:  ['회사 일이 너무 많아 \n']
# 정답:  ['\t 너무 무리하지 마세요 \n']
# 예상답:  ['나중에 기분이 들어와서 모습을 계속 지금 해보시는 것도 좋을 거예요 \n']
# _
# 질문:  ['이별 후 어떻게 될까 \n']
# 정답:  ['\t 연애 전으로 돌아가지는 못할 거예요 \n']
# 예상답:  ['좋아보이네요 \n']
# _
# 질문:  ['여자친구에게 옷선물 좋은 브랜드있어 \n']
# 정답:  ['\t 직접 같이 골라보세요 \n']
# 예상답:  ['사람 맘은 알 길이 없어요 \n']
# _
# 질문:  ['보험 많이 든 거 같애 \n']
# 정답:  ['\t 미래를 더 준비하고 있나봐요 \n']
# 예상답:  ['눈치가 빠르시군요 \n']
# _
# 질문:  ['옷 좀 사줘 \n']
# 정답:  ['\t 아직 월급날이 멀었어요 \n']
# 예상답:  ['노력하면 그럴 수 있을 거예요 \n']
# _
# 질문:  ['몸살 났나봐 \n']
# 정답:  ['\t 아무 생각 하지 말고 쉬세요 \n']
# 예상답:  ['따뜻하게 드세요 \n']
# _
# 질문:  ['이별을 받아들여야 하는데 생각이 자꾸 나네 \n']
# 정답:  ['\t 이별을 받아들일 시간이 필요할지도 몰라요 \n']
# 예상답:  ['먼저 고백해 보세요 \n']
# _
# 질문:  ['집들이 선물 뭐 사갈까 \n']
# 정답:  ['\t 필요한게 어떤건지 물어보세요 \n']
# 예상답:  ['노력하면 그럴 수 있을 거예요 \n']
# _
# 질문:  ['남자친구가 비혼주의래 \n']
# 정답:  ['\t 고민이 많이 되겠네요 \n']
# 예상답:  ['성격이 꼬였는지 말투가 꼬였는지 살펴보세요 \n']
# _
# 질문:  ['데이트로 놀이공원 가는거 어때 \n']
# 정답:  ['\t 데이트하기 좋은 곳이죠 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['이별중이신 회원들을 위해 \n']
# 정답:  ['\t 조언해주세요 \n']
# 예상답:  ['그럴 거예요 \n']
# _
# 질문:  ['두번 다시는 마주치고 싶지 않아여 \n']
# 정답:  ['\t 다신 마주치지 않을 거예요 \n']
# 예상답:  ['얼른 당신을 나중에 있어요 \n']
# _
# 질문:  ['아무래도 속은 거 같아 \n']
# 정답:  ['\t 기분나쁘겠어요 \n']
# 예상답:  ['상대방도 그런 일이 생길 거예요 \n']
# _
# 질문:  ['짝사랑하는 사람이랑 엄청 편하게 지내는데 썸 가능 \n']
# 정답:  ['\t 썸 가능해요 이성으로 대해보세요 \n']
# 예상답:  ['정리하는데 도움이 될 수도 있겠네요 \n']
# _
# 질문:  ['삼다리 여친 \n']
# 정답:  ['\t 헤어지세요 \n']
# 예상답:  ['as센터에 맡겨보세요 \n']
# _
# 질문:  ['한약 먹고 싶지 않다 \n']
# 정답:  ['\t 입에 쓴 게 몸에는 좋을 거예요 \n']
# 예상답:  ['사람은 모두 영향을 마셔도 받죠 \n']
# _
# 질문:  ['자주 가는 카페에 잘생긴 알바생이 있는데 어떻게 고백하면 좋을까 \n']
# 정답:  ['\t 쪽지를 남겨서 마음을 전해보세요 \n']
# 예상답:  ['관심을 큰 사랑을 정리하는게 가능성이 할 뿐이에요 \n']
# _
# 질문:  ['드라마보고 눈물났어 \n']
# 정답:  ['\t 저도 종종 울어요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['애매한 관계 \n']
# 정답:  ['\t 인간 관계도 정리가 필요해요 \n']
# 예상답:  ['얼른 청소하세요 \n']
# _
# 질문:  ['인턴 합격 \n']
# 정답:  ['\t 좋은 사회생활의 밑거름이 되길 바랍니다 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['상처받았어 \n']
# 정답:  ['\t 다른 사람 말은 신경쓰지 마세요 \n']
# 예상답:  ['조금만 더 버텨보세요 \n']
# _
# 질문:  ['오랜연애로 남자친구가 더 이상 새롭지않은게 고민임 \n']
# 정답:  ['\t 새로운 데이트 코스를 찾아보세요 \n']
# 예상답:  ['복잡하네요 \n']
# _
# 질문:  ['이제 누구 만나는 것도 지치네 \n']
# 정답:  ['\t 새로운 만남은 언제나 어려운 것 같아요 \n']
# 예상답:  ['다른 관심사를 만들어보세요 취미 생활도 많은 도움이 됩니다 \n']
# _
# 질문:  ['한달이 넘었지만 \n']
# 정답:  ['\t 아직은 실감이 나지 않을 거예요 \n']
# 예상답:  ['잘 하고 싶은 걸 찾아보세요 \n']
# _
# 질문:  ['현실적 문제로 연애 포기해야할듯 \n']
# 정답:  ['\t 잠시 쉬어도 괜찮아요 \n']
# 예상답:  ['직접 물어보는 건 좋겠어요 \n']
# _
# 질문:  ['지갑 바꿀까 \n']
# 정답:  ['\t 신상으로 바꾸세요 \n']
# 예상답:  ['꿈에서 본다면 더 마음이 헛헛할 거예요 \n']
# _
# 질문:  ['월세 아까워 \n']
# 정답:  ['\t 돈을 얼른 모아야할 이유가 생겼네요 \n']
# 예상답:  ['이제 청소 시작 \n']
# _
# 질문:  ['좋아하는 사람이 나를 부담스러워해 \n']
# 정답:  ['\t 서로 마음이 같지 않았나봐요 \n']
# 예상답:  ['내면을 더 들여다보세요 \n']
# _
# 질문:  ['추억들을 하나씩 보내며 \n']
# 정답:  ['\t 후련해질 거예요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['게스트하우스에서 만난 짝녀와 남은 일정을 같이 여행하고싶어 \n']
# 정답:  ['\t 일정 안 짰다고 하면서 일정을 물어보세요 \n']
# 예상답:  ['눈을 먼저 호감을 주는 것도 좋겠네요 \n']
# _
# 질문:  ['오늘도 하루 버텻구나 \n']
# 정답:  ['\t 오늘도 이렇게 이겨냈어요 \n']
# 예상답:  ['장 보러 갈 타이밍이네요 \n']
# _
# 질문:  ['좋아하는 사람 앞에서 실례를 했어 \n']
# 정답:  ['\t 생각만해도 소름돋네요 \n']
# 예상답:  ['관심을 거두세요 \n']
# _
# 질문:  ['회사일 끝나면 아무것도 못하겠어 \n']
# 정답:  ['\t 운동으로 땀을 내보세요 한결 몸이 가벼워질거예요 \n']
# 예상답:  ['욕심에 따라 천지 차이일 거예요 \n']
# _
# 질문:  ['눈썹이 귀여워 \n']
# 정답:  ['\t 저도 보고 싶어요 \n']
# 예상답:  ['무슨 마음인지 알겠어서 더 마음이 아프네요 \n']
# _
# 질문:  ['유기견 분양 받으려고 \n']
# 정답:  ['\t 좋은 생각입니다 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['우울하네 \n']
# 정답:  ['\t 함께 충분한 대화를 하고 상담을 받아보는 게 좋겠어요 \n']
# 예상답:  ['서서히 지워 나가요 \n']
# _
# 질문:  ['그리움 \n']
# 정답:  ['\t 애잔한 기억 \n']
# 예상답:  ['성공을 기원합니다 \n']
# _
# 질문:  ['복 받겠지 \n']
# 정답:  ['\t 뿌린대로 거둘 거예요 \n']
# 예상답:  ['차분하게 정리할 시간이 필요해요 \n']
# _
# 질문:  ['6개월 가량의 이별과 재회의 끝 \n']
# 정답:  ['\t 아쉬운 이야기네요 \n']
# 예상답:  ['마음이 복잡할 때입니다 \n']
# _
# 질문:  ['너무 많이 먹었어 \n']
# 정답:  ['\t 소화제 드세요 \n']
# 예상답:  ['제가 있잖아요 \n']
# _
# 질문:  ['공휴일에 데이트하자고 해봐야지 \n']
# 정답:  ['\t 지금 연락해보세요 \n']
# 예상답:  ['얼른 실내로 들어가세요 \n']
# _
# 질문:  ['남자의심리 모르겠어 \n']
# 정답:  ['\t 직접 물어보세요 \n']
# 예상답:  ['게임하세요 \n']
# _
# 질문:  ['연봉대비 근무시간이 너무 긴 거 같애 \n']
# 정답:  ['\t 야근 수당을 챙겨보세요 \n']
# 예상답:  ['야근 수당을 챙겨보세요 \n']

# %%
word_zip = list()
for idx, qna in enumerate(zip(questions, answers)):
  
  x,y = qna
  word_zip += x.split(' ')
  word_zip += y.split(' ')

# %%
ex_list = list(set(word_zip))
len(ex_list)
# Out:
# 12958
